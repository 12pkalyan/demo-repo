# %% [markdown]
# <a href="https://www.kaggle.com/code/princekalyan/notebook1?scriptVersionId=263266629" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !pip3 install indic-nlp-library
# Out:
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl.metadata (5.7 kB)
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.5.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.2.4)
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (8.2.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.32.4)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (25.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->indic-nlp-library) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2025.6.15)
# Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.7 MB/s eta 0:00:00
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Downloading sphinx_argparse-0.5.2-py3-none-any.whl (12 kB)
# Installing collected packages: morfessor, sphinx-argparse, indic-nlp-library
# Successfully installed indic-nlp-library-0.92 morfessor-2.0.6 sphinx-argparse-0.5.2

# %%
# !pip3 install indic-nlp-library
# Out:
# Requirement already satisfied: indic-nlp-library in /usr/local/lib/python3.11/dist-packages (0.92)
# Requirement already satisfied: sphinx-argparse in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.5.2)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.2.4)
# Requirement already satisfied: morfessor in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (8.2.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.32.4)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (25.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->indic-nlp-library) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2025.6.15)

# %%
import pandas as pd
import numpy as np
from transformers import AutoTokenizer
import torch
from indicnlp.tokenize import indic_tokenize

# %%
data = pd.read_csv("https://raw.githubusercontent.com/aimlrl/sample-dataset/refs/heads/master/Sentence%20pairs%20in%20English-Hindi%20-%202025-02-11.tsv",
                  sep="\t",header=None,names=["SrcSentID","SrcSent","DstSentID","DstSent"])

# %%
data.head()
# Out:
#    SrcSentID                                  SrcSent  DstSentID  \
# 0       1282                       Muiriel is 20 now.     485968
# 1       1282                       Muiriel is 20 now.    2060319
# 2       1294  Education in this world disappoints me.     485564
# 3       1302                       That won't happen.    2060320
# 4       1308                              I miss you.    2060321
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
data.drop(labels=[data.columns[0],data.columns[2]],axis=1,inplace=True)

# %%
data.head()
# Out:
#                                    SrcSent  \
# 0                       Muiriel is 20 now.
# 1                       Muiriel is 20 now.
# 2  Education in this world disappoints me.
# 3                       That won't happen.
# 4                              I miss you.
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
src_sent_tokenizer = AutoTokenizer.from_pretrained("google-T5/T5-base")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
data["SrcSent"] = data["SrcSent"].apply(lambda x: src_sent_tokenizer.tokenize(x))

# %%
data.head()
# Out:
#                                              SrcSent  \
# 0                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 1                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 2  [▁Education, ▁in, ▁this, ▁world, ▁disappoint, ...
# 3                    [▁That, ▁won, ', t, ▁happen, .]
# 4                               [▁I, ▁miss, ▁you, .]
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
data["DstSent"] = data["DstSent"].apply(lambda x: indic_tokenize.trivial_tokenize(x,lang="hi"))

# %%
data["SrcSent"] = data["SrcSent"].apply(src_sent_tokenizer.convert_tokens_to_ids)

# %%
Vs = src_sent_tokenizer.get_vocab()

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent
# 0        [म्यूरियल, अब, बीस, साल, की, हो, गई, है, ।]
# 1                [म्यूरियल, अब, बीस, साल, की, है, ।]
# 2  [मैं, इस, दुनिया, में, शिक्षा, पर, बहुत, निराश...
# 3                              [वैसा, नहीं, होगा, ।]
# 4              [मुझें, तुम्हारी, याद, आ, रही, है, ।]

# %%
hindi_vocab = set()

for tokenized_hindi_sent in data["DstSent"]:
    hindi_vocab.update(tokenized_hindi_sent)

# %%
Vd = dict()
for idx, token in enumerate(hindi_vocab):
    Vd[token] = idx + 3
Vd["<PAD>"] = 0
Vd["<SOS>"] = 1
Vd["<EOS>"] = 2

# %%
def convert_hindi_tokens_to_ids(hindi_sent):
    return [Vd[token] for token in hindi_sent]

# %%
data["DstSent"] = data["DstSent"].apply(lambda x: convert_hindi_tokens_to_ids(x))

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent
# 0  [2927, 131, 5711, 445, 4835, 3791, 3369, 2427,...
# 1            [2927, 131, 5711, 445, 4835, 2427, 109]
# 2  [3671, 4932, 3486, 3776, 5152, 1377, 82, 4241,...
# 3                            [1762, 1982, 2440, 109]
# 4           [2412, 4092, 402, 2901, 3685, 2427, 109]

# %%
def insert_sos_token_id(hindi_sent_token_ids):
    return [1] + hindi_sent_token_ids

# %%
data["DstSentInput"] = data["DstSent"].apply(lambda x: insert_sos_token_id(x))

# %%
def insert_eos_token_id(hindi_sent_token_ids):
    return hindi_sent_token_ids + [2]

# %%
data["DstSentLabel"] = data["DstSent"].apply(lambda x: insert_eos_token_id(x))

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent  \
# 0  [2927, 131, 5711, 445, 4835, 3791, 3369, 2427,...
# 1            [2927, 131, 5711, 445, 4835, 2427, 109]
# 2  [3671, 4932, 3486, 3776, 5152, 1377, 82, 4241,...
# 3                            [1762, 1982, 2440, 109]
# 4           [2412, 4092, 402, 2901, 3685, 2427, 109]
#
#                                         DstSentInput  \
# 0  [1, 2927, 131, 5711, 445, 4835, 3791, 3369, 24...
# 1         [1, 2927, 131, 5711, 445, 4835, 2427, 109]
# 2  [1, 3671, 4932, 3486, 3776, 5152, 1377, 82, 42...
# 3                         [1, 1762, 1982, 2440, 109]
# 4        [1, 2412, 4092, 402, 2901, 3685, 2427, 109]
#
#                                         DstSentLabel
# 0  [2927, 131, 5711, 445, 4835, 3791, 3369, 2427,...
# 1         [2927, 131, 5711, 445, 4835, 2427, 109, 2]
# 2  [3671, 4932, 3486, 3776, 5152, 1377, 82, 4241,...
# 3                         [1762, 1982, 2440, 109, 2]
# 4        [2412, 4092, 402, 2901, 3685, 2427, 109, 2]

# %%
data.drop(labels=[data.columns[1]],axis=1,inplace=True)

# %%
X = list(data["SrcSent"])
Y_input = list(data["DstSentInput"])
Y_label = list(data["DstSentLabel"])

# %%
X_tensor = [torch.tensor(tokenized_eng_sent_ids) for tokenized_eng_sent_ids in X]
Y_input_tensor = [torch.tensor(tokenized_hin_sent_ids) for tokenized_hin_sent_ids in Y_input]
Y_label_tensor = [torch.tensor(tokenized_hin_sent_ids) for tokenized_hin_sent_ids in Y_label]

# %%
X_padded = torch.nn.utils.rnn.pad_sequence(X_tensor,batch_first=True)
Y_padded_input = torch.nn.utils.rnn.pad_sequence(Y_input_tensor,batch_first=True)
Y_padded_label = torch.nn.utils.rnn.pad_sequence(Y_label_tensor,batch_first=True)

# %%
Ns = X_padded.shape[1]
Nd = Y_padded_label.shape[1]

# %%
class Encoder(torch.nn.Module):

    def __init__(self,src_lang_vocab_size,word_embedding_dim):
        super(Encoder,self).__init__()
        self.first_embedding_layer = torch.nn.Embedding(num_embeddings=src_lang_vocab_size,
                                                       embedding_dim=word_embedding_dim)
        self.second_lstm_layer = torch.nn.LSTM(input_size=word_embedding_dim,
                                               hidden_size=word_embedding_dim,
                                              batch_first=True)

    def forward(self,X_padded_mini_batch):

        first_embedding_layer_out = self.first_embedding_layer(X_padded_mini_batch)
        encoder_output, (final_encoder_output,final_cell_state) = self.second_lstm_layer(first_embedding_layer_out)

        return encoder_output, (final_encoder_output,final_cell_state)

# %%
class Decoder(torch.nn.Module):

    def __init__(self,dst_lang_vocab_size,word_embedding_dim):
        super(Decoder,self).__init__()

        self.first_embedding_layer = torch.nn.Embedding(num_embeddings=dst_lang_vocab_size,
                                                       embedding_dim=word_embedding_dim)
        self.second_lstm_layer = torch.nn.LSTM(input_size=word_embedding_dim,
                                               hidden_size=word_embedding_dim,
                                              batch_first=True)
        self.prediction_layer = torch.nn.Linear(in_features=word_embedding_dim,out_features=dst_lang_vocab_size)
        self.prediction_layer_activation = torch.nn.Softmax(dim=2)

    def forward(self,Y_padded_input_mini_batch,final_encoder_output,final_cell_state):

        first_embedding_layer_out = self.first_embedding_layer(Y_padded_input_mini_batch)
        decoder_lstm_layer_out, (final_decoder_lstm_layer_out, final_cell_state) = self.second_lstm_layer(first_embedding_layer_out,
                                                                                                         (final_encoder_output,
                                                                                                          final_cell_state))
        prediction = self.prediction_layer_activation(self.prediction_layer(decoder_lstm_layer_out))

        return prediction, (final_decoder_lstm_layer_out, final_cell_state)

# %%
class Seq2SeqEncDec(torch.nn.Module):

    def __init__(self,src_lang_vocab_size,dst_lang_vocab_size,word_embedding_dim):
        super(Seq2SeqEncDec,self).__init__()

        self.encoder = Encoder(src_lang_vocab_size,word_embedding_dim)
        self.decoder = Decoder(dst_lang_vocab_size,word_embedding_dim)

    def forward(self,X_padded_mini_batch,Y_padded_input_mini_batch):

        encoder_output, (final_encoder_output,final_cell_state) = self.encoder(X_padded_mini_batch)
        y_hat_mini_batch = self.decoder(Y_padded_input_mini_batch,
                                        final_encoder_output,final_cell_state)

        return y_hat_mini_batch

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print(device)
# Out:
# cpu

# %%
X_padded_train = X_padded[0:13000]
Y_padded_input_train = Y_padded_input[0:13000]
Y_padded_label_train = Y_padded_label[0:13000]

X_padded_test = X_padded[13000:]
Y_padded_input_test = Y_padded_input[13000:]
Y_padded_label_test = Y_padded_label[13000:]

# %%
network = Seq2SeqEncDec(len(Vs),len(Vd),128).to(device)
loss_fn = torch.nn.CrossEntropyLoss(ignore_index=0)
optimizer = torch.optim.Adam(network.parameters())
num_epochs = 25
mb_size = 65

for epoch in range(num_epochs):
    for i in range(X_padded_train.shape[0]//mb_size):

        X_train_mb = X_padded_train[i*mb_size:(i+1)*mb_size]
        Y_input_mb = Y_padded_input_train[i*mb_size:(i+1)*mb_size]
        Y_label_mb = Y_padded_label_train[i*mb_size:(i+1)*mb_size]
        Y_label_mb = Y_label_mb.reshape(Y_label_mb.shape[0]*Y_label_mb.shape[1],)

        X_train_mb, Y_input_mb, Y_label_mb = X_train_mb.to(device), Y_input_mb.to(device), Y_label_mb.to(device)

        y_hat_train_mb = network(X_train_mb,Y_input_mb)
        y_hat_train_mb = y_hat_train_mb[0]
        y_hat_train_mb = y_hat_train_mb.reshape(y_hat_train_mb.shape[0]*y_hat_train_mb.shape[1],
                                                y_hat_train_mb.shape[2])

        loss_fn_value = loss_fn(y_hat_train_mb,Y_label_mb)

        loss_fn_value.backward()
        torch.nn.utils.clip_grad_norm_(network.parameters(),max_norm=1.0)
        optimizer.step()
        optimizer.zero_grad()

        print("Epoch # {}, Time Step # {}, Loss Value = {}".format(epoch,i,loss_fn_value))
# Out:
# Epoch # 0, Time Step # 0, Loss Value = 8.863898277282715
# Epoch # 0, Time Step # 1, Loss Value = 8.86389446258545
# Epoch # 0, Time Step # 2, Loss Value = 8.8638916015625
# Epoch # 0, Time Step # 3, Loss Value = 8.863889694213867
# Epoch # 0, Time Step # 4, Loss Value = 8.863883972167969
# Epoch # 0, Time Step # 5, Loss Value = 8.863877296447754
# Epoch # 0, Time Step # 6, Loss Value = 8.863874435424805
# Epoch # 0, Time Step # 7, Loss Value = 8.863865852355957
# Epoch # 0, Time Step # 8, Loss Value = 8.863861083984375
# Epoch # 0, Time Step # 9, Loss Value = 8.863847732543945
# Epoch # 0, Time Step # 10, Loss Value = 8.863848686218262
# Epoch # 0, Time Step # 11, Loss Value = 8.8638277053833
# Epoch # 0, Time Step # 12, Loss Value = 8.863787651062012
# Epoch # 0, Time Step # 13, Loss Value = 8.863783836364746
# Epoch # 0, Time Step # 14, Loss Value = 8.863746643066406
# Epoch # 0, Time Step # 15, Loss Value = 8.863718032836914
# Epoch # 0, Time Step # 16, Loss Value = 8.863665580749512
# Epoch # 0, Time Step # 17, Loss Value = 8.86361026763916
# Epoch # 0, Time Step # 18, Loss Value = 8.863423347473145
# Epoch # 0, Time Step # 19, Loss Value = 8.863348007202148
# Epoch # 0, Time Step # 20, Loss Value = 8.86327075958252
# Epoch # 0, Time Step # 21, Loss Value = 8.862730979919434
# Epoch # 0, Time Step # 22, Loss Value = 8.86294174194336
# Epoch # 0, Time Step # 23, Loss Value = 8.861757278442383
# Epoch # 0, Time Step # 24, Loss Value = 8.860702514648438
# Epoch # 0, Time Step # 25, Loss Value = 8.85795783996582
# Epoch # 0, Time Step # 26, Loss Value = 8.855615615844727
# Epoch # 0, Time Step # 27, Loss Value = 8.852651596069336
# Epoch # 0, Time Step # 28, Loss Value = 8.845542907714844
# Epoch # 0, Time Step # 29, Loss Value = 8.838309288024902
# Epoch # 0, Time Step # 30, Loss Value = 8.8283052444458
# Epoch # 0, Time Step # 31, Loss Value = 8.818856239318848
# Epoch # 0, Time Step # 32, Loss Value = 8.80801010131836
# Epoch # 0, Time Step # 33, Loss Value = 8.799964904785156
# Epoch # 0, Time Step # 34, Loss Value = 8.802811622619629
# Epoch # 0, Time Step # 35, Loss Value = 8.798165321350098
# Epoch # 0, Time Step # 36, Loss Value = 8.778193473815918
# Epoch # 0, Time Step # 37, Loss Value = 8.780628204345703
# Epoch # 0, Time Step # 38, Loss Value = 8.774291038513184
# Epoch # 0, Time Step # 39, Loss Value = 8.761431694030762
# Epoch # 0, Time Step # 40, Loss Value = 8.764623641967773
# Epoch # 0, Time Step # 41, Loss Value = 8.753643989562988
# Epoch # 0, Time Step # 42, Loss Value = 8.743735313415527
# Epoch # 0, Time Step # 43, Loss Value = 8.745810508728027
# Epoch # 0, Time Step # 44, Loss Value = 8.740657806396484
# Epoch # 0, Time Step # 45, Loss Value = 8.734638214111328
# Epoch # 0, Time Step # 46, Loss Value = 8.740910530090332
# Epoch # 0, Time Step # 47, Loss Value = 8.728926658630371
# Epoch # 0, Time Step # 48, Loss Value = 8.722210884094238
# Epoch # 0, Time Step # 49, Loss Value = 8.722088813781738
# Epoch # 0, Time Step # 50, Loss Value = 8.699734687805176
# Epoch # 0, Time Step # 51, Loss Value = 8.694962501525879
# Epoch # 0, Time Step # 52, Loss Value = 8.698168754577637
# Epoch # 0, Time Step # 53, Loss Value = 8.707474708557129
# Epoch # 0, Time Step # 54, Loss Value = 8.69983959197998
# Epoch # 0, Time Step # 55, Loss Value = 8.723058700561523
# Epoch # 0, Time Step # 56, Loss Value = 8.698982238769531
# Epoch # 0, Time Step # 57, Loss Value = 8.704119682312012
# Epoch # 0, Time Step # 58, Loss Value = 8.689427375793457
# Epoch # 0, Time Step # 59, Loss Value = 8.670099258422852
# Epoch # 0, Time Step # 60, Loss Value = 8.685323715209961
# Epoch # 0, Time Step # 61, Loss Value = 8.66274356842041
# Epoch # 0, Time Step # 62, Loss Value = 8.699034690856934
# Epoch # 0, Time Step # 63, Loss Value = 8.721857070922852
# Epoch # 0, Time Step # 64, Loss Value = 8.657415390014648
# Epoch # 0, Time Step # 65, Loss Value = 8.66769027709961
# Epoch # 0, Time Step # 66, Loss Value = 8.684264183044434
# Epoch # 0, Time Step # 67, Loss Value = 8.676203727722168
# Epoch # 0, Time Step # 68, Loss Value = 8.669121742248535
# Epoch # 0, Time Step # 69, Loss Value = 8.681127548217773
# Epoch # 0, Time Step # 70, Loss Value = 8.673454284667969
# Epoch # 0, Time Step # 71, Loss Value = 8.687471389770508
# Epoch # 0, Time Step # 72, Loss Value = 8.669027328491211
# Epoch # 0, Time Step # 73, Loss Value = 8.684597969055176
# Epoch # 0, Time Step # 74, Loss Value = 8.671609878540039
# Epoch # 0, Time Step # 75, Loss Value = 8.658921241760254
# Epoch # 0, Time Step # 76, Loss Value = 8.655634880065918
# Epoch # 0, Time Step # 77, Loss Value = 8.648163795471191
# Epoch # 0, Time Step # 78, Loss Value = 8.645918846130371
# Epoch # 0, Time Step # 79, Loss Value = 8.668445587158203
# Epoch # 0, Time Step # 80, Loss Value = 8.63749885559082
# Epoch # 0, Time Step # 81, Loss Value = 8.652226448059082
# Epoch # 0, Time Step # 82, Loss Value = 8.593484878540039
# Epoch # 0, Time Step # 83, Loss Value = 8.646221160888672
# Epoch # 0, Time Step # 84, Loss Value = 8.632423400878906
# Epoch # 0, Time Step # 85, Loss Value = 8.572558403015137
# Epoch # 0, Time Step # 86, Loss Value = 8.570515632629395
# Epoch # 0, Time Step # 87, Loss Value = 8.569997787475586
# Epoch # 0, Time Step # 88, Loss Value = 8.605765342712402
# Epoch # 0, Time Step # 89, Loss Value = 8.58928108215332
# Epoch # 0, Time Step # 90, Loss Value = 8.55029010772705
# Epoch # 0, Time Step # 91, Loss Value = 8.5039644241333
# Epoch # 0, Time Step # 92, Loss Value = 8.657428741455078
# Epoch # 0, Time Step # 93, Loss Value = 8.660394668579102
# Epoch # 0, Time Step # 94, Loss Value = 8.656429290771484
# Epoch # 0, Time Step # 95, Loss Value = 8.724711418151855
# Epoch # 0, Time Step # 96, Loss Value = 8.749271392822266
# Epoch # 0, Time Step # 97, Loss Value = 8.65127182006836
# Epoch # 0, Time Step # 98, Loss Value = 8.619922637939453
# Epoch # 0, Time Step # 99, Loss Value = 8.623150825500488
# Epoch # 0, Time Step # 100, Loss Value = 8.64844799041748
# Epoch # 0, Time Step # 101, Loss Value = 8.589786529541016
# Epoch # 0, Time Step # 102, Loss Value = 8.582846641540527
# Epoch # 0, Time Step # 103, Loss Value = 8.647625923156738
# Epoch # 0, Time Step # 104, Loss Value = 8.62217903137207
# Epoch # 0, Time Step # 105, Loss Value = 8.620121955871582
# Epoch # 0, Time Step # 106, Loss Value = 8.620329856872559
# Epoch # 0, Time Step # 107, Loss Value = 8.608159065246582
# Epoch # 0, Time Step # 108, Loss Value = 8.584199905395508
# Epoch # 0, Time Step # 109, Loss Value = 8.614836692810059
# Epoch # 0, Time Step # 110, Loss Value = 8.639021873474121
# Epoch # 0, Time Step # 111, Loss Value = 8.69165325164795
# Epoch # 0, Time Step # 112, Loss Value = 8.675400733947754
# Epoch # 0, Time Step # 113, Loss Value = 8.639530181884766
# Epoch # 0, Time Step # 114, Loss Value = 8.616358757019043
# Epoch # 0, Time Step # 115, Loss Value = 8.634618759155273
# Epoch # 0, Time Step # 116, Loss Value = 8.655900955200195
# Epoch # 0, Time Step # 117, Loss Value = 8.632450103759766
# Epoch # 0, Time Step # 118, Loss Value = 8.600308418273926
# Epoch # 0, Time Step # 119, Loss Value = 8.612479209899902
# Epoch # 0, Time Step # 120, Loss Value = 8.684871673583984
# Epoch # 0, Time Step # 121, Loss Value = 8.617220878601074
# Epoch # 0, Time Step # 122, Loss Value = 8.63498306274414
# Epoch # 0, Time Step # 123, Loss Value = 8.637574195861816
# Epoch # 0, Time Step # 124, Loss Value = 8.602127075195312
# Epoch # 0, Time Step # 125, Loss Value = 8.642853736877441
# Epoch # 0, Time Step # 126, Loss Value = 8.608704566955566
# Epoch # 0, Time Step # 127, Loss Value = 8.541553497314453
# Epoch # 0, Time Step # 128, Loss Value = 8.656478881835938
# Epoch # 0, Time Step # 129, Loss Value = 8.677807807922363
# Epoch # 0, Time Step # 130, Loss Value = 8.66966438293457
# Epoch # 0, Time Step # 131, Loss Value = 8.647615432739258
# Epoch # 0, Time Step # 132, Loss Value = 8.61125659942627
# Epoch # 0, Time Step # 133, Loss Value = 8.61586856842041
# Epoch # 0, Time Step # 134, Loss Value = 8.613102912902832
# Epoch # 0, Time Step # 135, Loss Value = 8.62468433380127
# Epoch # 0, Time Step # 136, Loss Value = 8.6509370803833
# Epoch # 0, Time Step # 137, Loss Value = 8.652731895446777
# Epoch # 0, Time Step # 138, Loss Value = 8.604680061340332
# Epoch # 0, Time Step # 139, Loss Value = 8.663605690002441
# Epoch # 0, Time Step # 140, Loss Value = 8.642470359802246
# Epoch # 0, Time Step # 141, Loss Value = 8.569273948669434
# Epoch # 0, Time Step # 142, Loss Value = 8.598493576049805
# Epoch # 0, Time Step # 143, Loss Value = 8.622394561767578
# Epoch # 0, Time Step # 144, Loss Value = 8.588778495788574
# Epoch # 0, Time Step # 145, Loss Value = 8.645845413208008
# Epoch # 0, Time Step # 146, Loss Value = 8.618024826049805
# Epoch # 0, Time Step # 147, Loss Value = 8.62424087524414
# Epoch # 0, Time Step # 148, Loss Value = 8.606297492980957
# Epoch # 0, Time Step # 149, Loss Value = 8.637046813964844
# Epoch # 0, Time Step # 150, Loss Value = 8.584073066711426
# Epoch # 0, Time Step # 151, Loss Value = 8.62263011932373
# Epoch # 0, Time Step # 152, Loss Value = 8.633337020874023
# Epoch # 0, Time Step # 153, Loss Value = 8.61395263671875
# Epoch # 0, Time Step # 154, Loss Value = 8.629937171936035
# Epoch # 0, Time Step # 155, Loss Value = 8.590462684631348
# Epoch # 0, Time Step # 156, Loss Value = 8.593877792358398
# Epoch # 0, Time Step # 157, Loss Value = 8.614787101745605
# Epoch # 0, Time Step # 158, Loss Value = 8.60122299194336
# Epoch # 0, Time Step # 159, Loss Value = 8.658151626586914
# Epoch # 0, Time Step # 160, Loss Value = 8.668229103088379
# Epoch # 0, Time Step # 161, Loss Value = 8.624734878540039
# Epoch # 0, Time Step # 162, Loss Value = 8.597996711730957
# Epoch # 0, Time Step # 163, Loss Value = 8.576654434204102
# Epoch # 0, Time Step # 164, Loss Value = 8.477072715759277
# Epoch # 0, Time Step # 165, Loss Value = 8.631026268005371
# Epoch # 0, Time Step # 166, Loss Value = 8.590228080749512
# Epoch # 0, Time Step # 167, Loss Value = 8.637359619140625
# Epoch # 0, Time Step # 168, Loss Value = 8.603644371032715
# Epoch # 0, Time Step # 169, Loss Value = 8.660524368286133
# Epoch # 0, Time Step # 170, Loss Value = 8.67151165008545
# Epoch # 0, Time Step # 171, Loss Value = 8.67058277130127
# Epoch # 0, Time Step # 172, Loss Value = 8.680938720703125
# Epoch # 0, Time Step # 173, Loss Value = 8.657651901245117
# Epoch # 0, Time Step # 174, Loss Value = 8.668732643127441
# Epoch # 0, Time Step # 175, Loss Value = 8.623440742492676
# Epoch # 0, Time Step # 176, Loss Value = 8.598938941955566
# Epoch # 0, Time Step # 177, Loss Value = 8.616317749023438
# Epoch # 0, Time Step # 178, Loss Value = 8.59692668914795
# Epoch # 0, Time Step # 179, Loss Value = 8.574114799499512
# Epoch # 0, Time Step # 180, Loss Value = 8.642809867858887
# Epoch # 0, Time Step # 181, Loss Value = 8.604872703552246
# Epoch # 0, Time Step # 182, Loss Value = 8.602652549743652
# Epoch # 0, Time Step # 183, Loss Value = 8.614795684814453
# Epoch # 0, Time Step # 184, Loss Value = 8.6097412109375
# Epoch # 0, Time Step # 185, Loss Value = 8.614089965820312
# Epoch # 0, Time Step # 186, Loss Value = 8.578536033630371
# Epoch # 0, Time Step # 187, Loss Value = 8.701943397521973
# Epoch # 0, Time Step # 188, Loss Value = 8.626235961914062
# Epoch # 0, Time Step # 189, Loss Value = 8.649604797363281
# Epoch # 0, Time Step # 190, Loss Value = 8.623876571655273
# Epoch # 0, Time Step # 191, Loss Value = 8.647513389587402
# Epoch # 0, Time Step # 192, Loss Value = 8.65960693359375
# Epoch # 0, Time Step # 193, Loss Value = 8.612225532531738
# Epoch # 0, Time Step # 194, Loss Value = 8.623068809509277
# Epoch # 0, Time Step # 195, Loss Value = 8.610321998596191
# Epoch # 0, Time Step # 196, Loss Value = 8.639952659606934
# Epoch # 0, Time Step # 197, Loss Value = 8.631516456604004
# Epoch # 0, Time Step # 198, Loss Value = 8.50755500793457
# Epoch # 0, Time Step # 199, Loss Value = 8.666203498840332
# Epoch # 1, Time Step # 0, Loss Value = 8.611529350280762
# Epoch # 1, Time Step # 1, Loss Value = 8.674980163574219
# Epoch # 1, Time Step # 2, Loss Value = 8.68046760559082
# Epoch # 1, Time Step # 3, Loss Value = 8.653051376342773
# Epoch # 1, Time Step # 4, Loss Value = 8.661537170410156
# Epoch # 1, Time Step # 5, Loss Value = 8.64849853515625
# Epoch # 1, Time Step # 6, Loss Value = 8.673274993896484
# Epoch # 1, Time Step # 7, Loss Value = 8.635498046875
# Epoch # 1, Time Step # 8, Loss Value = 8.677907943725586
# Epoch # 1, Time Step # 9, Loss Value = 8.659531593322754
# Epoch # 1, Time Step # 10, Loss Value = 8.688309669494629
# Epoch # 1, Time Step # 11, Loss Value = 8.6662015914917
# Epoch # 1, Time Step # 12, Loss Value = 8.651581764221191
# Epoch # 1, Time Step # 13, Loss Value = 8.675638198852539
# Epoch # 1, Time Step # 14, Loss Value = 8.653472900390625
# Epoch # 1, Time Step # 15, Loss Value = 8.66688346862793
# Epoch # 1, Time Step # 16, Loss Value = 8.670233726501465
# Epoch # 1, Time Step # 17, Loss Value = 8.689165115356445
# Epoch # 1, Time Step # 18, Loss Value = 8.665059089660645
# Epoch # 1, Time Step # 19, Loss Value = 8.680791854858398
# Epoch # 1, Time Step # 20, Loss Value = 8.685969352722168
# Epoch # 1, Time Step # 21, Loss Value = 8.668912887573242
# Epoch # 1, Time Step # 22, Loss Value = 8.713823318481445
# Epoch # 1, Time Step # 23, Loss Value = 8.678839683532715
# Epoch # 1, Time Step # 24, Loss Value = 8.679499626159668
# Epoch # 1, Time Step # 25, Loss Value = 8.642607688903809
# Epoch # 1, Time Step # 26, Loss Value = 8.666678428649902
# Epoch # 1, Time Step # 27, Loss Value = 8.661503791809082
# Epoch # 1, Time Step # 28, Loss Value = 8.651652336120605
# Epoch # 1, Time Step # 29, Loss Value = 8.647467613220215
# Epoch # 1, Time Step # 30, Loss Value = 8.611042976379395
# Epoch # 1, Time Step # 31, Loss Value = 8.61384391784668
# Epoch # 1, Time Step # 32, Loss Value = 8.601666450500488
# Epoch # 1, Time Step # 33, Loss Value = 8.605477333068848
# Epoch # 1, Time Step # 34, Loss Value = 8.673969268798828
# Epoch # 1, Time Step # 35, Loss Value = 8.6804838180542
# Epoch # 1, Time Step # 36, Loss Value = 8.657401084899902
# Epoch # 1, Time Step # 37, Loss Value = 8.67253303527832
# Epoch # 1, Time Step # 38, Loss Value = 8.677007675170898
# Epoch # 1, Time Step # 39, Loss Value = 8.65538501739502
# Epoch # 1, Time Step # 40, Loss Value = 8.662243843078613
# Epoch # 1, Time Step # 41, Loss Value = 8.645788192749023
# Epoch # 1, Time Step # 42, Loss Value = 8.641716003417969
# Epoch # 1, Time Step # 43, Loss Value = 8.656027793884277
# Epoch # 1, Time Step # 44, Loss Value = 8.646198272705078
# Epoch # 1, Time Step # 45, Loss Value = 8.642912864685059
# Epoch # 1, Time Step # 46, Loss Value = 8.662793159484863
# Epoch # 1, Time Step # 47, Loss Value = 8.656476020812988
# Epoch # 1, Time Step # 48, Loss Value = 8.655365943908691
# Epoch # 1, Time Step # 49, Loss Value = 8.656866073608398
# Epoch # 1, Time Step # 50, Loss Value = 8.646649360656738
# Epoch # 1, Time Step # 51, Loss Value = 8.653220176696777
# Epoch # 1, Time Step # 52, Loss Value = 8.659747123718262
# Epoch # 1, Time Step # 53, Loss Value = 8.655404090881348
# Epoch # 1, Time Step # 54, Loss Value = 8.655622482299805
# Epoch # 1, Time Step # 55, Loss Value = 8.663643836975098
# Epoch # 1, Time Step # 56, Loss Value = 8.647290229797363
# Epoch # 1, Time Step # 57, Loss Value = 8.660477638244629
# Epoch # 1, Time Step # 58, Loss Value = 8.63455867767334
# Epoch # 1, Time Step # 59, Loss Value = 8.600298881530762
# Epoch # 1, Time Step # 60, Loss Value = 8.618597030639648
# Epoch # 1, Time Step # 61, Loss Value = 8.629829406738281
# Epoch # 1, Time Step # 62, Loss Value = 8.6586275100708
# Epoch # 1, Time Step # 63, Loss Value = 8.694463729858398
# Epoch # 1, Time Step # 64, Loss Value = 8.619987487792969
# Epoch # 1, Time Step # 65, Loss Value = 8.638763427734375
# Epoch # 1, Time Step # 66, Loss Value = 8.6647310256958
# Epoch # 1, Time Step # 67, Loss Value = 8.663640022277832
# Epoch # 1, Time Step # 68, Loss Value = 8.636064529418945
# Epoch # 1, Time Step # 69, Loss Value = 8.664207458496094
# Epoch # 1, Time Step # 70, Loss Value = 8.651432991027832
# Epoch # 1, Time Step # 71, Loss Value = 8.673113822937012
# Epoch # 1, Time Step # 72, Loss Value = 8.639501571655273
# Epoch # 1, Time Step # 73, Loss Value = 8.658905029296875
# Epoch # 1, Time Step # 74, Loss Value = 8.660041809082031
# Epoch # 1, Time Step # 75, Loss Value = 8.647165298461914
# Epoch # 1, Time Step # 76, Loss Value = 8.642251968383789
# Epoch # 1, Time Step # 77, Loss Value = 8.63243293762207
# Epoch # 1, Time Step # 78, Loss Value = 8.628897666931152
# Epoch # 1, Time Step # 79, Loss Value = 8.659867286682129
# Epoch # 1, Time Step # 80, Loss Value = 8.623892784118652
# Epoch # 1, Time Step # 81, Loss Value = 8.641890525817871
# Epoch # 1, Time Step # 82, Loss Value = 8.583725929260254
# Epoch # 1, Time Step # 83, Loss Value = 8.633950233459473
# Epoch # 1, Time Step # 84, Loss Value = 8.620046615600586
# Epoch # 1, Time Step # 85, Loss Value = 8.549278259277344
# Epoch # 1, Time Step # 86, Loss Value = 8.562036514282227
# Epoch # 1, Time Step # 87, Loss Value = 8.561567306518555
# Epoch # 1, Time Step # 88, Loss Value = 8.598381996154785
# Epoch # 1, Time Step # 89, Loss Value = 8.580403327941895
# Epoch # 1, Time Step # 90, Loss Value = 8.542531967163086
# Epoch # 1, Time Step # 91, Loss Value = 8.49505615234375
# Epoch # 1, Time Step # 92, Loss Value = 8.648822784423828
# Epoch # 1, Time Step # 93, Loss Value = 8.655722618103027
# Epoch # 1, Time Step # 94, Loss Value = 8.65335464477539
# Epoch # 1, Time Step # 95, Loss Value = 8.720307350158691
# Epoch # 1, Time Step # 96, Loss Value = 8.747556686401367
# Epoch # 1, Time Step # 97, Loss Value = 8.644140243530273
# Epoch # 1, Time Step # 98, Loss Value = 8.614670753479004
# Epoch # 1, Time Step # 99, Loss Value = 8.619479179382324
# Epoch # 1, Time Step # 100, Loss Value = 8.640521049499512
# Epoch # 1, Time Step # 101, Loss Value = 8.58637523651123
# Epoch # 1, Time Step # 102, Loss Value = 8.576105117797852
# Epoch # 1, Time Step # 103, Loss Value = 8.64246940612793
# Epoch # 1, Time Step # 104, Loss Value = 8.615723609924316
# Epoch # 1, Time Step # 105, Loss Value = 8.617425918579102
# Epoch # 1, Time Step # 106, Loss Value = 8.617834091186523
# Epoch # 1, Time Step # 107, Loss Value = 8.605154037475586
# Epoch # 1, Time Step # 108, Loss Value = 8.584135055541992
# Epoch # 1, Time Step # 109, Loss Value = 8.612428665161133
# Epoch # 1, Time Step # 110, Loss Value = 8.637252807617188
# Epoch # 1, Time Step # 111, Loss Value = 8.69000244140625
# Epoch # 1, Time Step # 112, Loss Value = 8.67382526397705
# Epoch # 1, Time Step # 113, Loss Value = 8.63691234588623
# Epoch # 1, Time Step # 114, Loss Value = 8.6109037399292
# Epoch # 1, Time Step # 115, Loss Value = 8.62884521484375
# Epoch # 1, Time Step # 116, Loss Value = 8.652271270751953
# Epoch # 1, Time Step # 117, Loss Value = 8.629146575927734
# Epoch # 1, Time Step # 118, Loss Value = 8.591994285583496
# Epoch # 1, Time Step # 119, Loss Value = 8.606069564819336
# Epoch # 1, Time Step # 120, Loss Value = 8.683320045471191
# Epoch # 1, Time Step # 121, Loss Value = 8.61355972290039
# Epoch # 1, Time Step # 122, Loss Value = 8.630127906799316
# Epoch # 1, Time Step # 123, Loss Value = 8.634639739990234
# Epoch # 1, Time Step # 124, Loss Value = 8.59501838684082
# Epoch # 1, Time Step # 125, Loss Value = 8.634413719177246
# Epoch # 1, Time Step # 126, Loss Value = 8.60527515411377
# Epoch # 1, Time Step # 127, Loss Value = 8.534650802612305
# Epoch # 1, Time Step # 128, Loss Value = 8.649209022521973
# Epoch # 1, Time Step # 129, Loss Value = 8.666056632995605
# Epoch # 1, Time Step # 130, Loss Value = 8.667038917541504
# Epoch # 1, Time Step # 131, Loss Value = 8.639392852783203
# Epoch # 1, Time Step # 132, Loss Value = 8.60807991027832
# Epoch # 1, Time Step # 133, Loss Value = 8.614051818847656
# Epoch # 1, Time Step # 134, Loss Value = 8.61137866973877
# Epoch # 1, Time Step # 135, Loss Value = 8.619236946105957
# Epoch # 1, Time Step # 136, Loss Value = 8.64950180053711
# Epoch # 1, Time Step # 137, Loss Value = 8.63377857208252
# Epoch # 1, Time Step # 138, Loss Value = 8.598146438598633
# Epoch # 1, Time Step # 139, Loss Value = 8.656088829040527
# Epoch # 1, Time Step # 140, Loss Value = 8.6337308883667
# Epoch # 1, Time Step # 141, Loss Value = 8.564597129821777
# Epoch # 1, Time Step # 142, Loss Value = 8.596877098083496
# Epoch # 1, Time Step # 143, Loss Value = 8.619782447814941
# Epoch # 1, Time Step # 144, Loss Value = 8.586345672607422
# Epoch # 1, Time Step # 145, Loss Value = 8.642297744750977
# Epoch # 1, Time Step # 146, Loss Value = 8.58859920501709
# Epoch # 1, Time Step # 147, Loss Value = 8.544415473937988
# Epoch # 1, Time Step # 148, Loss Value = 8.603349685668945
# Epoch # 1, Time Step # 149, Loss Value = 8.634859085083008
# Epoch # 1, Time Step # 150, Loss Value = 8.581024169921875
# Epoch # 1, Time Step # 151, Loss Value = 8.61890983581543
# Epoch # 1, Time Step # 152, Loss Value = 8.629687309265137
# Epoch # 1, Time Step # 153, Loss Value = 8.608366966247559
# Epoch # 1, Time Step # 154, Loss Value = 8.625625610351562
# Epoch # 1, Time Step # 155, Loss Value = 8.584799766540527
# Epoch # 1, Time Step # 156, Loss Value = 8.58938980102539
# Epoch # 1, Time Step # 157, Loss Value = 8.612292289733887
# Epoch # 1, Time Step # 158, Loss Value = 8.596364974975586
# Epoch # 1, Time Step # 159, Loss Value = 8.65432071685791
# Epoch # 1, Time Step # 160, Loss Value = 8.665538787841797
# Epoch # 1, Time Step # 161, Loss Value = 8.618107795715332
# Epoch # 1, Time Step # 162, Loss Value = 8.590209007263184
# Epoch # 1, Time Step # 163, Loss Value = 8.57183837890625
# Epoch # 1, Time Step # 164, Loss Value = 8.46789264678955
# Epoch # 1, Time Step # 165, Loss Value = 8.626164436340332
# Epoch # 1, Time Step # 166, Loss Value = 8.58669662475586
# Epoch # 1, Time Step # 167, Loss Value = 8.633918762207031
# Epoch # 1, Time Step # 168, Loss Value = 8.600502014160156
# Epoch # 1, Time Step # 169, Loss Value = 8.658862113952637
# Epoch # 1, Time Step # 170, Loss Value = 8.670002937316895
# Epoch # 1, Time Step # 171, Loss Value = 8.665728569030762
# Epoch # 1, Time Step # 172, Loss Value = 8.67927360534668
# Epoch # 1, Time Step # 173, Loss Value = 8.655744552612305
# Epoch # 1, Time Step # 174, Loss Value = 8.666177749633789
# Epoch # 1, Time Step # 175, Loss Value = 8.621455192565918
# Epoch # 1, Time Step # 176, Loss Value = 8.597452163696289
# Epoch # 1, Time Step # 177, Loss Value = 8.615013122558594
# Epoch # 1, Time Step # 178, Loss Value = 8.59581184387207
# Epoch # 1, Time Step # 179, Loss Value = 8.572946548461914
# Epoch # 1, Time Step # 180, Loss Value = 8.641291618347168
# Epoch # 1, Time Step # 181, Loss Value = 8.603824615478516
# Epoch # 1, Time Step # 182, Loss Value = 8.601614952087402
# Epoch # 1, Time Step # 183, Loss Value = 8.613690376281738
# Epoch # 1, Time Step # 184, Loss Value = 8.6087646484375
# Epoch # 1, Time Step # 185, Loss Value = 8.613031387329102
# Epoch # 1, Time Step # 186, Loss Value = 8.577423095703125
# Epoch # 1, Time Step # 187, Loss Value = 8.701384544372559
# Epoch # 1, Time Step # 188, Loss Value = 8.624013900756836
# Epoch # 1, Time Step # 189, Loss Value = 8.648832321166992
# Epoch # 1, Time Step # 190, Loss Value = 8.622916221618652
# Epoch # 1, Time Step # 191, Loss Value = 8.646599769592285
# Epoch # 1, Time Step # 192, Loss Value = 8.658763885498047
# Epoch # 1, Time Step # 193, Loss Value = 8.611595153808594
# Epoch # 1, Time Step # 194, Loss Value = 8.622244834899902
# Epoch # 1, Time Step # 195, Loss Value = 8.609091758728027
# Epoch # 1, Time Step # 196, Loss Value = 8.639442443847656
# Epoch # 1, Time Step # 197, Loss Value = 8.628321647644043
# Epoch # 1, Time Step # 198, Loss Value = 8.492135047912598
# Epoch # 1, Time Step # 199, Loss Value = 8.665645599365234
# Epoch # 2, Time Step # 0, Loss Value = 8.609376907348633
# Epoch # 2, Time Step # 1, Loss Value = 8.673430442810059
# Epoch # 2, Time Step # 2, Loss Value = 8.679829597473145
# Epoch # 2, Time Step # 3, Loss Value = 8.652502059936523
# Epoch # 2, Time Step # 4, Loss Value = 8.661039352416992
# Epoch # 2, Time Step # 5, Loss Value = 8.64681625366211
# Epoch # 2, Time Step # 6, Loss Value = 8.672804832458496
# Epoch # 2, Time Step # 7, Loss Value = 8.634822845458984
# Epoch # 2, Time Step # 8, Loss Value = 8.677456855773926
# Epoch # 2, Time Step # 9, Loss Value = 8.658961296081543
# Epoch # 2, Time Step # 10, Loss Value = 8.687702178955078
# Epoch # 2, Time Step # 11, Loss Value = 8.665413856506348
# Epoch # 2, Time Step # 12, Loss Value = 8.650879859924316
# Epoch # 2, Time Step # 13, Loss Value = 8.675110816955566
# Epoch # 2, Time Step # 14, Loss Value = 8.652815818786621
# Epoch # 2, Time Step # 15, Loss Value = 8.666326522827148
# Epoch # 2, Time Step # 16, Loss Value = 8.668952941894531
# Epoch # 2, Time Step # 17, Loss Value = 8.688770294189453
# Epoch # 2, Time Step # 18, Loss Value = 8.664687156677246
# Epoch # 2, Time Step # 19, Loss Value = 8.679149627685547
# Epoch # 2, Time Step # 20, Loss Value = 8.685518264770508
# Epoch # 2, Time Step # 21, Loss Value = 8.668488502502441
# Epoch # 2, Time Step # 22, Loss Value = 8.7135009765625
# Epoch # 2, Time Step # 23, Loss Value = 8.673409461975098
# Epoch # 2, Time Step # 24, Loss Value = 8.677040100097656
# Epoch # 2, Time Step # 25, Loss Value = 8.6420316696167
# Epoch # 2, Time Step # 26, Loss Value = 8.666244506835938
# Epoch # 2, Time Step # 27, Loss Value = 8.658557891845703
# Epoch # 2, Time Step # 28, Loss Value = 8.65040111541748
# Epoch # 2, Time Step # 29, Loss Value = 8.647042274475098
# Epoch # 2, Time Step # 30, Loss Value = 8.610398292541504
# Epoch # 2, Time Step # 31, Loss Value = 8.613210678100586
# Epoch # 2, Time Step # 32, Loss Value = 8.600484848022461
# Epoch # 2, Time Step # 33, Loss Value = 8.604783058166504
# Epoch # 2, Time Step # 34, Loss Value = 8.67358112335205
# Epoch # 2, Time Step # 35, Loss Value = 8.680044174194336
# Epoch # 2, Time Step # 36, Loss Value = 8.656322479248047
# Epoch # 2, Time Step # 37, Loss Value = 8.671873092651367
# Epoch # 2, Time Step # 38, Loss Value = 8.676101684570312
# Epoch # 2, Time Step # 39, Loss Value = 8.65499496459961
# Epoch # 2, Time Step # 40, Loss Value = 8.661900520324707
# Epoch # 2, Time Step # 41, Loss Value = 8.64540958404541
# Epoch # 2, Time Step # 42, Loss Value = 8.641361236572266
# Epoch # 2, Time Step # 43, Loss Value = 8.655511856079102
# Epoch # 2, Time Step # 44, Loss Value = 8.645864486694336
# Epoch # 2, Time Step # 45, Loss Value = 8.64254093170166
# Epoch # 2, Time Step # 46, Loss Value = 8.66246223449707
# Epoch # 2, Time Step # 47, Loss Value = 8.656196594238281
# Epoch # 2, Time Step # 48, Loss Value = 8.655048370361328
# Epoch # 2, Time Step # 49, Loss Value = 8.656460762023926
# Epoch # 2, Time Step # 50, Loss Value = 8.64631175994873
# Epoch # 2, Time Step # 51, Loss Value = 8.65294361114502
# Epoch # 2, Time Step # 52, Loss Value = 8.6594820022583
# Epoch # 2, Time Step # 53, Loss Value = 8.655056953430176
# Epoch # 2, Time Step # 54, Loss Value = 8.655298233032227
# Epoch # 2, Time Step # 55, Loss Value = 8.66341781616211
# Epoch # 2, Time Step # 56, Loss Value = 8.647071838378906
# Epoch # 2, Time Step # 57, Loss Value = 8.659819602966309
# Epoch # 2, Time Step # 58, Loss Value = 8.633852005004883
# Epoch # 2, Time Step # 59, Loss Value = 8.599737167358398
# Epoch # 2, Time Step # 60, Loss Value = 8.617997169494629
# Epoch # 2, Time Step # 61, Loss Value = 8.629510879516602
# Epoch # 2, Time Step # 62, Loss Value = 8.658193588256836
# Epoch # 2, Time Step # 63, Loss Value = 8.694066047668457
# Epoch # 2, Time Step # 64, Loss Value = 8.619585037231445
# Epoch # 2, Time Step # 65, Loss Value = 8.638211250305176
# Epoch # 2, Time Step # 66, Loss Value = 8.664430618286133
# Epoch # 2, Time Step # 67, Loss Value = 8.66338062286377
# Epoch # 2, Time Step # 68, Loss Value = 8.634361267089844
# Epoch # 2, Time Step # 69, Loss Value = 8.663758277893066
# Epoch # 2, Time Step # 70, Loss Value = 8.651115417480469
# Epoch # 2, Time Step # 71, Loss Value = 8.672836303710938
# Epoch # 2, Time Step # 72, Loss Value = 8.638992309570312
# Epoch # 2, Time Step # 73, Loss Value = 8.658428192138672
# Epoch # 2, Time Step # 74, Loss Value = 8.659452438354492
# Epoch # 2, Time Step # 75, Loss Value = 8.646879196166992
# Epoch # 2, Time Step # 76, Loss Value = 8.641947746276855
# Epoch # 2, Time Step # 77, Loss Value = 8.631176948547363
# Epoch # 2, Time Step # 78, Loss Value = 8.628151893615723
# Epoch # 2, Time Step # 79, Loss Value = 8.659624099731445
# Epoch # 2, Time Step # 80, Loss Value = 8.623249053955078
# Epoch # 2, Time Step # 81, Loss Value = 8.641572952270508
# Epoch # 2, Time Step # 82, Loss Value = 8.583393096923828
# Epoch # 2, Time Step # 83, Loss Value = 8.633522033691406
# Epoch # 2, Time Step # 84, Loss Value = 8.619630813598633
# Epoch # 2, Time Step # 85, Loss Value = 8.548747062683105
# Epoch # 2, Time Step # 86, Loss Value = 8.561667442321777
# Epoch # 2, Time Step # 87, Loss Value = 8.561187744140625
# Epoch # 2, Time Step # 88, Loss Value = 8.59805679321289
# Epoch # 2, Time Step # 89, Loss Value = 8.580018997192383
# Epoch # 2, Time Step # 90, Loss Value = 8.542145729064941
# Epoch # 2, Time Step # 91, Loss Value = 8.494548797607422
# Epoch # 2, Time Step # 92, Loss Value = 8.648494720458984
# Epoch # 2, Time Step # 93, Loss Value = 8.655487060546875
# Epoch # 2, Time Step # 94, Loss Value = 8.653152465820312
# Epoch # 2, Time Step # 95, Loss Value = 8.720122337341309
# Epoch # 2, Time Step # 96, Loss Value = 8.747417449951172
# Epoch # 2, Time Step # 97, Loss Value = 8.6430025100708
# Epoch # 2, Time Step # 98, Loss Value = 8.61478042602539
# Epoch # 2, Time Step # 99, Loss Value = 8.619192123413086
# Epoch # 2, Time Step # 100, Loss Value = 8.640198707580566
# Epoch # 2, Time Step # 101, Loss Value = 8.586090087890625
# Epoch # 2, Time Step # 102, Loss Value = 8.575756072998047
# Epoch # 2, Time Step # 103, Loss Value = 8.642162322998047
# Epoch # 2, Time Step # 104, Loss Value = 8.615405082702637
# Epoch # 2, Time Step # 105, Loss Value = 8.617162704467773
# Epoch # 2, Time Step # 106, Loss Value = 8.617574691772461
# Epoch # 2, Time Step # 107, Loss Value = 8.604876518249512
# Epoch # 2, Time Step # 108, Loss Value = 8.581171035766602
# Epoch # 2, Time Step # 109, Loss Value = 8.612189292907715
# Epoch # 2, Time Step # 110, Loss Value = 8.637035369873047
# Epoch # 2, Time Step # 111, Loss Value = 8.689726829528809
# Epoch # 2, Time Step # 112, Loss Value = 8.67365837097168
# Epoch # 2, Time Step # 113, Loss Value = 8.636682510375977
# Epoch # 2, Time Step # 114, Loss Value = 8.610610961914062
# Epoch # 2, Time Step # 115, Loss Value = 8.628507614135742
# Epoch # 2, Time Step # 116, Loss Value = 8.652039527893066
# Epoch # 2, Time Step # 117, Loss Value = 8.62879467010498
# Epoch # 2, Time Step # 118, Loss Value = 8.591656684875488
# Epoch # 2, Time Step # 119, Loss Value = 8.605688095092773
# Epoch # 2, Time Step # 120, Loss Value = 8.683148384094238
# Epoch # 2, Time Step # 121, Loss Value = 8.613306999206543
# Epoch # 2, Time Step # 122, Loss Value = 8.629827499389648
# Epoch # 2, Time Step # 123, Loss Value = 8.634340286254883
# Epoch # 2, Time Step # 124, Loss Value = 8.594541549682617
# Epoch # 2, Time Step # 125, Loss Value = 8.633965492248535
# Epoch # 2, Time Step # 126, Loss Value = 8.605020523071289
# Epoch # 2, Time Step # 127, Loss Value = 8.534292221069336
# Epoch # 2, Time Step # 128, Loss Value = 8.648910522460938
# Epoch # 2, Time Step # 129, Loss Value = 8.665660858154297
# Epoch # 2, Time Step # 130, Loss Value = 8.666831016540527
# Epoch # 2, Time Step # 131, Loss Value = 8.639105796813965
# Epoch # 2, Time Step # 132, Loss Value = 8.60785961151123
# Epoch # 2, Time Step # 133, Loss Value = 8.613795280456543
# Epoch # 2, Time Step # 134, Loss Value = 8.611133575439453
# Epoch # 2, Time Step # 135, Loss Value = 8.61894416809082
# Epoch # 2, Time Step # 136, Loss Value = 8.649283409118652
# Epoch # 2, Time Step # 137, Loss Value = 8.630263328552246
# Epoch # 2, Time Step # 138, Loss Value = 8.59785270690918
# Epoch # 2, Time Step # 139, Loss Value = 8.655747413635254
# Epoch # 2, Time Step # 140, Loss Value = 8.633269309997559
# Epoch # 2, Time Step # 141, Loss Value = 8.564347267150879
# Epoch # 2, Time Step # 142, Loss Value = 8.596650123596191
# Epoch # 2, Time Step # 143, Loss Value = 8.619483947753906
# Epoch # 2, Time Step # 144, Loss Value = 8.586106300354004
# Epoch # 2, Time Step # 145, Loss Value = 8.642094612121582
# Epoch # 2, Time Step # 146, Loss Value = 8.587691307067871
# Epoch # 2, Time Step # 147, Loss Value = 8.542740821838379
# Epoch # 2, Time Step # 148, Loss Value = 8.602521896362305
# Epoch # 2, Time Step # 149, Loss Value = 8.634668350219727
# Epoch # 2, Time Step # 150, Loss Value = 8.580787658691406
# Epoch # 2, Time Step # 151, Loss Value = 8.618696212768555
# Epoch # 2, Time Step # 152, Loss Value = 8.629474639892578
# Epoch # 2, Time Step # 153, Loss Value = 8.608036041259766
# Epoch # 2, Time Step # 154, Loss Value = 8.62535285949707
# Epoch # 2, Time Step # 155, Loss Value = 8.584548950195312
# Epoch # 2, Time Step # 156, Loss Value = 8.589117050170898
# Epoch # 2, Time Step # 157, Loss Value = 8.611526489257812
# Epoch # 2, Time Step # 158, Loss Value = 8.596048355102539
# Epoch # 2, Time Step # 159, Loss Value = 8.654132843017578
# Epoch # 2, Time Step # 160, Loss Value = 8.66536808013916
# Epoch # 2, Time Step # 161, Loss Value = 8.617098808288574
# Epoch # 2, Time Step # 162, Loss Value = 8.589140892028809
# Epoch # 2, Time Step # 163, Loss Value = 8.571476936340332
# Epoch # 2, Time Step # 164, Loss Value = 8.466523170471191
# Epoch # 2, Time Step # 165, Loss Value = 8.625396728515625
# Epoch # 2, Time Step # 166, Loss Value = 8.586457252502441
# Epoch # 2, Time Step # 167, Loss Value = 8.633710861206055
# Epoch # 2, Time Step # 168, Loss Value = 8.600105285644531
# Epoch # 2, Time Step # 169, Loss Value = 8.658700942993164
# Epoch # 2, Time Step # 170, Loss Value = 8.66985034942627
# Epoch # 2, Time Step # 171, Loss Value = 8.665529251098633
# Epoch # 2, Time Step # 172, Loss Value = 8.678909301757812
# Epoch # 2, Time Step # 173, Loss Value = 8.65551471710205
# Epoch # 2, Time Step # 174, Loss Value = 8.665950775146484
# Epoch # 2, Time Step # 175, Loss Value = 8.62121295928955
# Epoch # 2, Time Step # 176, Loss Value = 8.597321510314941
# Epoch # 2, Time Step # 177, Loss Value = 8.614814758300781
# Epoch # 2, Time Step # 178, Loss Value = 8.595626831054688
# Epoch # 2, Time Step # 179, Loss Value = 8.572755813598633
# Epoch # 2, Time Step # 180, Loss Value = 8.641075134277344
# Epoch # 2, Time Step # 181, Loss Value = 8.603631019592285
# Epoch # 2, Time Step # 182, Loss Value = 8.601412773132324
# Epoch # 2, Time Step # 183, Loss Value = 8.611740112304688
# Epoch # 2, Time Step # 184, Loss Value = 8.608569145202637
# Epoch # 2, Time Step # 185, Loss Value = 8.61284351348877
# Epoch # 2, Time Step # 186, Loss Value = 8.5772066116333
# Epoch # 2, Time Step # 187, Loss Value = 8.701273918151855
# Epoch # 2, Time Step # 188, Loss Value = 8.621149063110352
# Epoch # 2, Time Step # 189, Loss Value = 8.64866828918457
# Epoch # 2, Time Step # 190, Loss Value = 8.622739791870117
# Epoch # 2, Time Step # 191, Loss Value = 8.646443367004395
# Epoch # 2, Time Step # 192, Loss Value = 8.658623695373535
# Epoch # 2, Time Step # 193, Loss Value = 8.611444473266602
# Epoch # 2, Time Step # 194, Loss Value = 8.622069358825684
# Epoch # 2, Time Step # 195, Loss Value = 8.609387397766113
# Epoch # 2, Time Step # 196, Loss Value = 8.639317512512207
# Epoch # 2, Time Step # 197, Loss Value = 8.626401901245117
# Epoch # 2, Time Step # 198, Loss Value = 8.492916107177734
# Epoch # 2, Time Step # 199, Loss Value = 8.665517807006836
# Epoch # 3, Time Step # 0, Loss Value = 8.609129905700684
# Epoch # 3, Time Step # 1, Loss Value = 8.673104286193848
# Epoch # 3, Time Step # 2, Loss Value = 8.67969799041748
# Epoch # 3, Time Step # 3, Loss Value = 8.652368545532227
# Epoch # 3, Time Step # 4, Loss Value = 8.660675048828125
# Epoch # 3, Time Step # 5, Loss Value = 8.646602630615234
# Epoch # 3, Time Step # 6, Loss Value = 8.672698974609375
# Epoch # 3, Time Step # 7, Loss Value = 8.634679794311523
# Epoch # 3, Time Step # 8, Loss Value = 8.677347183227539
# Epoch # 3, Time Step # 9, Loss Value = 8.658838272094727
# Epoch # 3, Time Step # 10, Loss Value = 8.687591552734375
# Epoch # 3, Time Step # 11, Loss Value = 8.665279388427734
# Epoch # 3, Time Step # 12, Loss Value = 8.65058708190918
# Epoch # 3, Time Step # 13, Loss Value = 8.675030708312988
# Epoch # 3, Time Step # 14, Loss Value = 8.652674674987793
# Epoch # 3, Time Step # 15, Loss Value = 8.666207313537598
# Epoch # 3, Time Step # 16, Loss Value = 8.668497085571289
# Epoch # 3, Time Step # 17, Loss Value = 8.688677787780762
# Epoch # 3, Time Step # 18, Loss Value = 8.664589881896973
# Epoch # 3, Time Step # 19, Loss Value = 8.678977966308594
# Epoch # 3, Time Step # 20, Loss Value = 8.685409545898438
# Epoch # 3, Time Step # 21, Loss Value = 8.668386459350586
# Epoch # 3, Time Step # 22, Loss Value = 8.71341323852539
# Epoch # 3, Time Step # 23, Loss Value = 8.673087120056152
# Epoch # 3, Time Step # 24, Loss Value = 8.67676067352295
# Epoch # 3, Time Step # 25, Loss Value = 8.641888618469238
# Epoch # 3, Time Step # 26, Loss Value = 8.666163444519043
# Epoch # 3, Time Step # 27, Loss Value = 8.658390045166016
# Epoch # 3, Time Step # 28, Loss Value = 8.650073051452637
# Epoch # 3, Time Step # 29, Loss Value = 8.646941184997559
# Epoch # 3, Time Step # 30, Loss Value = 8.610276222229004
# Epoch # 3, Time Step # 31, Loss Value = 8.613089561462402
# Epoch # 3, Time Step # 32, Loss Value = 8.599770545959473
# Epoch # 3, Time Step # 33, Loss Value = 8.604644775390625
# Epoch # 3, Time Step # 34, Loss Value = 8.673479080200195
# Epoch # 3, Time Step # 35, Loss Value = 8.679935455322266
# Epoch # 3, Time Step # 36, Loss Value = 8.656207084655762
# Epoch # 3, Time Step # 37, Loss Value = 8.671754837036133
# Epoch # 3, Time Step # 38, Loss Value = 8.675995826721191
# Epoch # 3, Time Step # 39, Loss Value = 8.65488338470459
# Epoch # 3, Time Step # 40, Loss Value = 8.661813735961914
# Epoch # 3, Time Step # 41, Loss Value = 8.645306587219238
# Epoch # 3, Time Step # 42, Loss Value = 8.641260147094727
# Epoch # 3, Time Step # 43, Loss Value = 8.655403137207031
# Epoch # 3, Time Step # 44, Loss Value = 8.645767211914062
# Epoch # 3, Time Step # 45, Loss Value = 8.64242935180664
# Epoch # 3, Time Step # 46, Loss Value = 8.662363052368164
# Epoch # 3, Time Step # 47, Loss Value = 8.656111717224121
# Epoch # 3, Time Step # 48, Loss Value = 8.654953956604004
# Epoch # 3, Time Step # 49, Loss Value = 8.656368255615234
# Epoch # 3, Time Step # 50, Loss Value = 8.646207809448242
# Epoch # 3, Time Step # 51, Loss Value = 8.652861595153809
# Epoch # 3, Time Step # 52, Loss Value = 8.659401893615723
# Epoch # 3, Time Step # 53, Loss Value = 8.654961585998535
# Epoch # 3, Time Step # 54, Loss Value = 8.655191421508789
# Epoch # 3, Time Step # 55, Loss Value = 8.6627197265625
# Epoch # 3, Time Step # 56, Loss Value = 8.646781921386719
# Epoch # 3, Time Step # 57, Loss Value = 8.65919017791748
# Epoch # 3, Time Step # 58, Loss Value = 8.633682250976562
# Epoch # 3, Time Step # 59, Loss Value = 8.599560737609863
# Epoch # 3, Time Step # 60, Loss Value = 8.61784553527832
# Epoch # 3, Time Step # 61, Loss Value = 8.62945556640625
# Epoch # 3, Time Step # 62, Loss Value = 8.65804672241211
# Epoch # 3, Time Step # 63, Loss Value = 8.693970680236816
# Epoch # 3, Time Step # 64, Loss Value = 8.619465827941895
# Epoch # 3, Time Step # 65, Loss Value = 8.638071060180664
# Epoch # 3, Time Step # 66, Loss Value = 8.664278030395508
# Epoch # 3, Time Step # 67, Loss Value = 8.663296699523926
# Epoch # 3, Time Step # 68, Loss Value = 8.63332748413086
# Epoch # 3, Time Step # 69, Loss Value = 8.663658142089844
# Epoch # 3, Time Step # 70, Loss Value = 8.651018142700195
# Epoch # 3, Time Step # 71, Loss Value = 8.67275333404541
# Epoch # 3, Time Step # 72, Loss Value = 8.638862609863281
# Epoch # 3, Time Step # 73, Loss Value = 8.658308982849121
# Epoch # 3, Time Step # 74, Loss Value = 8.659346580505371
# Epoch # 3, Time Step # 75, Loss Value = 8.64678955078125
# Epoch # 3, Time Step # 76, Loss Value = 8.641846656799316
# Epoch # 3, Time Step # 77, Loss Value = 8.6309232711792
# Epoch # 3, Time Step # 78, Loss Value = 8.627073287963867
# Epoch # 3, Time Step # 79, Loss Value = 8.65954303741455
# Epoch # 3, Time Step # 80, Loss Value = 8.62311840057373
# Epoch # 3, Time Step # 81, Loss Value = 8.641448020935059
# Epoch # 3, Time Step # 82, Loss Value = 8.58328628540039
# Epoch # 3, Time Step # 83, Loss Value = 8.633395195007324
# Epoch # 3, Time Step # 84, Loss Value = 8.619511604309082
# Epoch # 3, Time Step # 85, Loss Value = 8.548593521118164
# Epoch # 3, Time Step # 86, Loss Value = 8.561551094055176
# Epoch # 3, Time Step # 87, Loss Value = 8.561058044433594
# Epoch # 3, Time Step # 88, Loss Value = 8.5979642868042
# Epoch # 3, Time Step # 89, Loss Value = 8.579907417297363
# Epoch # 3, Time Step # 90, Loss Value = 8.54202938079834
# Epoch # 3, Time Step # 91, Loss Value = 8.494389533996582
# Epoch # 3, Time Step # 92, Loss Value = 8.648393630981445
# Epoch # 3, Time Step # 93, Loss Value = 8.655396461486816
# Epoch # 3, Time Step # 94, Loss Value = 8.653085708618164
# Epoch # 3, Time Step # 95, Loss Value = 8.720069885253906
# Epoch # 3, Time Step # 96, Loss Value = 8.747381210327148
# Epoch # 3, Time Step # 97, Loss Value = 8.64272403717041
# Epoch # 3, Time Step # 98, Loss Value = 8.614330291748047
# Epoch # 3, Time Step # 99, Loss Value = 8.619099617004395
# Epoch # 3, Time Step # 100, Loss Value = 8.64008617401123
# Epoch # 3, Time Step # 101, Loss Value = 8.585997581481934
# Epoch # 3, Time Step # 102, Loss Value = 8.57563591003418
# Epoch # 3, Time Step # 103, Loss Value = 8.64206600189209
# Epoch # 3, Time Step # 104, Loss Value = 8.615303039550781
# Epoch # 3, Time Step # 105, Loss Value = 8.617081642150879
# Epoch # 3, Time Step # 106, Loss Value = 8.617496490478516
# Epoch # 3, Time Step # 107, Loss Value = 8.604774475097656
# Epoch # 3, Time Step # 108, Loss Value = 8.58043384552002
# Epoch # 3, Time Step # 109, Loss Value = 8.612105369567871
# Epoch # 3, Time Step # 110, Loss Value = 8.636956214904785
# Epoch # 3, Time Step # 111, Loss Value = 8.678595542907715
# Epoch # 3, Time Step # 112, Loss Value = 8.673598289489746
# Epoch # 3, Time Step # 113, Loss Value = 8.636608123779297
# Epoch # 3, Time Step # 114, Loss Value = 8.610523223876953
# Epoch # 3, Time Step # 115, Loss Value = 8.628351211547852
# Epoch # 3, Time Step # 116, Loss Value = 8.651972770690918
# Epoch # 3, Time Step # 117, Loss Value = 8.628742218017578
# Epoch # 3, Time Step # 118, Loss Value = 8.591568946838379
# Epoch # 3, Time Step # 119, Loss Value = 8.605302810668945
# Epoch # 3, Time Step # 120, Loss Value = 8.683090209960938
# Epoch # 3, Time Step # 121, Loss Value = 8.613228797912598
# Epoch # 3, Time Step # 122, Loss Value = 8.629734992980957
# Epoch # 3, Time Step # 123, Loss Value = 8.634247779846191
# Epoch # 3, Time Step # 124, Loss Value = 8.594182014465332
# Epoch # 3, Time Step # 125, Loss Value = 8.63383674621582
# Epoch # 3, Time Step # 126, Loss Value = 8.604947090148926
# Epoch # 3, Time Step # 127, Loss Value = 8.5341796875
# Epoch # 3, Time Step # 128, Loss Value = 8.648819923400879
# Epoch # 3, Time Step # 129, Loss Value = 8.665515899658203
# Epoch # 3, Time Step # 130, Loss Value = 8.666825294494629
# Epoch # 3, Time Step # 131, Loss Value = 8.639026641845703
# Epoch # 3, Time Step # 132, Loss Value = 8.607792854309082
# Epoch # 3, Time Step # 133, Loss Value = 8.613700866699219
# Epoch # 3, Time Step # 134, Loss Value = 8.61104965209961
# Epoch # 3, Time Step # 135, Loss Value = 8.618873596191406
# Epoch # 3, Time Step # 136, Loss Value = 8.649154663085938
# Epoch # 3, Time Step # 137, Loss Value = 8.629944801330566
# Epoch # 3, Time Step # 138, Loss Value = 8.59778118133545
# Epoch # 3, Time Step # 139, Loss Value = 8.655643463134766
# Epoch # 3, Time Step # 140, Loss Value = 8.633162498474121
# Epoch # 3, Time Step # 141, Loss Value = 8.564268112182617
# Epoch # 3, Time Step # 142, Loss Value = 8.596576690673828
# Epoch # 3, Time Step # 143, Loss Value = 8.619389533996582
# Epoch # 3, Time Step # 144, Loss Value = 8.586028099060059
# Epoch # 3, Time Step # 145, Loss Value = 8.6420259475708
# Epoch # 3, Time Step # 146, Loss Value = 8.587442398071289
# Epoch # 3, Time Step # 147, Loss Value = 8.542312622070312
# Epoch # 3, Time Step # 148, Loss Value = 8.601557731628418
# Epoch # 3, Time Step # 149, Loss Value = 8.634608268737793
# Epoch # 3, Time Step # 150, Loss Value = 8.58071231842041
# Epoch # 3, Time Step # 151, Loss Value = 8.618621826171875
# Epoch # 3, Time Step # 152, Loss Value = 8.62938117980957
# Epoch # 3, Time Step # 153, Loss Value = 8.60794448852539
# Epoch # 3, Time Step # 154, Loss Value = 8.625277519226074
# Epoch # 3, Time Step # 155, Loss Value = 8.584466934204102
# Epoch # 3, Time Step # 156, Loss Value = 8.589034080505371
# Epoch # 3, Time Step # 157, Loss Value = 8.610017776489258
# Epoch # 3, Time Step # 158, Loss Value = 8.59597110748291
# Epoch # 3, Time Step # 159, Loss Value = 8.654073715209961
# Epoch # 3, Time Step # 160, Loss Value = 8.665316581726074
# Epoch # 3, Time Step # 161, Loss Value = 8.617010116577148
# Epoch # 3, Time Step # 162, Loss Value = 8.588939666748047
# Epoch # 3, Time Step # 163, Loss Value = 8.571386337280273
# Epoch # 3, Time Step # 164, Loss Value = 8.466653823852539
# Epoch # 3, Time Step # 165, Loss Value = 8.625368118286133
# Epoch # 3, Time Step # 166, Loss Value = 8.586292266845703
# Epoch # 3, Time Step # 167, Loss Value = 8.633637428283691
# Epoch # 3, Time Step # 168, Loss Value = 8.599968910217285
# Epoch # 3, Time Step # 169, Loss Value = 8.658642768859863
# Epoch # 3, Time Step # 170, Loss Value = 8.66979694366455
# Epoch # 3, Time Step # 171, Loss Value = 8.665458679199219
# Epoch # 3, Time Step # 172, Loss Value = 8.678581237792969
# Epoch # 3, Time Step # 173, Loss Value = 8.655203819274902
# Epoch # 3, Time Step # 174, Loss Value = 8.665858268737793
# Epoch # 3, Time Step # 175, Loss Value = 8.621102333068848
# Epoch # 3, Time Step # 176, Loss Value = 8.597245216369629
# Epoch # 3, Time Step # 177, Loss Value = 8.614744186401367
# Epoch # 3, Time Step # 178, Loss Value = 8.595560073852539
# Epoch # 3, Time Step # 179, Loss Value = 8.572684288024902
# Epoch # 3, Time Step # 180, Loss Value = 8.641002655029297
# Epoch # 3, Time Step # 181, Loss Value = 8.603559494018555
# Epoch # 3, Time Step # 182, Loss Value = 8.601337432861328
# Epoch # 3, Time Step # 183, Loss Value = 8.609798431396484
# Epoch # 3, Time Step # 184, Loss Value = 8.608495712280273
# Epoch # 3, Time Step # 185, Loss Value = 8.612756729125977
# Epoch # 3, Time Step # 186, Loss Value = 8.577129364013672
# Epoch # 3, Time Step # 187, Loss Value = 8.701231002807617
# Epoch # 3, Time Step # 188, Loss Value = 8.620767593383789
# Epoch # 3, Time Step # 189, Loss Value = 8.648601531982422
# Epoch # 3, Time Step # 190, Loss Value = 8.62267017364502
# Epoch # 3, Time Step # 191, Loss Value = 8.646385192871094
# Epoch # 3, Time Step # 192, Loss Value = 8.65857219696045
# Epoch # 3, Time Step # 193, Loss Value = 8.611387252807617
# Epoch # 3, Time Step # 194, Loss Value = 8.622005462646484
# Epoch # 3, Time Step # 195, Loss Value = 8.608803749084473
# Epoch # 3, Time Step # 196, Loss Value = 8.639266967773438
# Epoch # 3, Time Step # 197, Loss Value = 8.62607479095459
# Epoch # 3, Time Step # 198, Loss Value = 8.490398406982422
# Epoch # 3, Time Step # 199, Loss Value = 8.665467262268066
# Epoch # 4, Time Step # 0, Loss Value = 8.609047889709473
# Epoch # 4, Time Step # 1, Loss Value = 8.672109603881836
# Epoch # 4, Time Step # 2, Loss Value = 8.679645538330078
# Epoch # 4, Time Step # 3, Loss Value = 8.652316093444824
# Epoch # 4, Time Step # 4, Loss Value = 8.65966796875
# Epoch # 4, Time Step # 5, Loss Value = 8.646490097045898
# Epoch # 4, Time Step # 6, Loss Value = 8.67265796661377
# Epoch # 4, Time Step # 7, Loss Value = 8.634618759155273
# Epoch # 4, Time Step # 8, Loss Value = 8.6773042678833
# Epoch # 4, Time Step # 9, Loss Value = 8.65877914428711
# Epoch # 4, Time Step # 10, Loss Value = 8.687501907348633
# Epoch # 4, Time Step # 11, Loss Value = 8.664913177490234
# Epoch # 4, Time Step # 12, Loss Value = 8.65048885345459
# Epoch # 4, Time Step # 13, Loss Value = 8.674138069152832
# Epoch # 4, Time Step # 14, Loss Value = 8.652613639831543
# Epoch # 4, Time Step # 15, Loss Value = 8.666152954101562
# Epoch # 4, Time Step # 16, Loss Value = 8.668091773986816
# Epoch # 4, Time Step # 17, Loss Value = 8.688634872436523
# Epoch # 4, Time Step # 18, Loss Value = 8.66454792022705
# Epoch # 4, Time Step # 19, Loss Value = 8.678914070129395
# Epoch # 4, Time Step # 20, Loss Value = 8.68536376953125
# Epoch # 4, Time Step # 21, Loss Value = 8.668341636657715
# Epoch # 4, Time Step # 22, Loss Value = 8.713369369506836
# Epoch # 4, Time Step # 23, Loss Value = 8.672943115234375
# ...
# Epoch # 23, Time Step # 131, Loss Value = 8.587125778198242
# Epoch # 23, Time Step # 132, Loss Value = 8.539251327514648
# Epoch # 23, Time Step # 133, Loss Value = 8.563115119934082
# Epoch # 23, Time Step # 134, Loss Value = 8.52652359008789
# Epoch # 23, Time Step # 135, Loss Value = 8.55128288269043
# Epoch # 23, Time Step # 136, Loss Value = 8.610641479492188
# Epoch # 23, Time Step # 137, Loss Value = 8.60252571105957
# Epoch # 23, Time Step # 138, Loss Value = 8.54267406463623
# Epoch # 23, Time Step # 139, Loss Value = 8.61292552947998
# Epoch # 23, Time Step # 140, Loss Value = 8.581276893615723
# Epoch # 23, Time Step # 141, Loss Value = 8.483603477478027
# Epoch # 23, Time Step # 142, Loss Value = 8.561470031738281
# Epoch # 23, Time Step # 143, Loss Value = 8.536317825317383
# Epoch # 23, Time Step # 144, Loss Value = 8.498929977416992
# Epoch # 23, Time Step # 145, Loss Value = 8.588866233825684
# Epoch # 23, Time Step # 146, Loss Value = 8.543352127075195
# Epoch # 23, Time Step # 147, Loss Value = 8.507417678833008
# Epoch # 23, Time Step # 148, Loss Value = 8.505931854248047
# Epoch # 23, Time Step # 149, Loss Value = 8.52066707611084
# Epoch # 23, Time Step # 150, Loss Value = 8.52415943145752
# Epoch # 23, Time Step # 151, Loss Value = 8.540812492370605
# Epoch # 23, Time Step # 152, Loss Value = 8.593464851379395
# Epoch # 23, Time Step # 153, Loss Value = 8.577899932861328
# Epoch # 23, Time Step # 154, Loss Value = 8.550413131713867
# Epoch # 23, Time Step # 155, Loss Value = 8.52309513092041
# Epoch # 23, Time Step # 156, Loss Value = 8.4930419921875
# Epoch # 23, Time Step # 157, Loss Value = 8.546714782714844
# Epoch # 23, Time Step # 158, Loss Value = 8.53104305267334
# Epoch # 23, Time Step # 159, Loss Value = 8.601090431213379
# Epoch # 23, Time Step # 160, Loss Value = 8.589156150817871
# Epoch # 23, Time Step # 161, Loss Value = 8.573807716369629
# Epoch # 23, Time Step # 162, Loss Value = 8.576780319213867
# Epoch # 23, Time Step # 163, Loss Value = 8.524025917053223
# Epoch # 23, Time Step # 164, Loss Value = 8.469183921813965
# Epoch # 23, Time Step # 165, Loss Value = 8.54304027557373
# Epoch # 23, Time Step # 166, Loss Value = 8.509800910949707
# Epoch # 23, Time Step # 167, Loss Value = 8.574442863464355
# Epoch # 23, Time Step # 168, Loss Value = 8.545519828796387
# Epoch # 23, Time Step # 169, Loss Value = 8.582368850708008
# Epoch # 23, Time Step # 170, Loss Value = 8.59708023071289
# Epoch # 23, Time Step # 171, Loss Value = 8.59462833404541
# Epoch # 23, Time Step # 172, Loss Value = 8.616019248962402
# Epoch # 23, Time Step # 173, Loss Value = 8.600032806396484
# Epoch # 23, Time Step # 174, Loss Value = 8.601316452026367
# Epoch # 23, Time Step # 175, Loss Value = 8.5664644241333
# Epoch # 23, Time Step # 176, Loss Value = 8.536280632019043
# Epoch # 23, Time Step # 177, Loss Value = 8.564484596252441
# Epoch # 23, Time Step # 178, Loss Value = 8.5246000289917
# Epoch # 23, Time Step # 179, Loss Value = 8.46813678741455
# Epoch # 23, Time Step # 180, Loss Value = 8.594585418701172
# Epoch # 23, Time Step # 181, Loss Value = 8.547638893127441
# Epoch # 23, Time Step # 182, Loss Value = 8.530193328857422
# Epoch # 23, Time Step # 183, Loss Value = 8.54148006439209
# Epoch # 23, Time Step # 184, Loss Value = 8.560150146484375
# Epoch # 23, Time Step # 185, Loss Value = 8.555615425109863
# Epoch # 23, Time Step # 186, Loss Value = 8.530550956726074
# Epoch # 23, Time Step # 187, Loss Value = 8.644430160522461
# Epoch # 23, Time Step # 188, Loss Value = 8.550301551818848
# Epoch # 23, Time Step # 189, Loss Value = 8.593303680419922
# Epoch # 23, Time Step # 190, Loss Value = 8.573677062988281
# Epoch # 23, Time Step # 191, Loss Value = 8.590538024902344
# Epoch # 23, Time Step # 192, Loss Value = 8.605048179626465
# Epoch # 23, Time Step # 193, Loss Value = 8.52078914642334
# Epoch # 23, Time Step # 194, Loss Value = 8.559006690979004
# Epoch # 23, Time Step # 195, Loss Value = 8.526156425476074
# Epoch # 23, Time Step # 196, Loss Value = 8.568266868591309
# Epoch # 23, Time Step # 197, Loss Value = 8.569653511047363
# Epoch # 23, Time Step # 198, Loss Value = 8.473746299743652
# Epoch # 23, Time Step # 199, Loss Value = 8.593270301818848
# Epoch # 24, Time Step # 0, Loss Value = 8.554109573364258
# Epoch # 24, Time Step # 1, Loss Value = 8.62505054473877
# Epoch # 24, Time Step # 2, Loss Value = 8.637801170349121
# Epoch # 24, Time Step # 3, Loss Value = 8.592734336853027
# Epoch # 24, Time Step # 4, Loss Value = 8.60575008392334
# Epoch # 24, Time Step # 5, Loss Value = 8.578819274902344
# Epoch # 24, Time Step # 6, Loss Value = 8.624112129211426
# Epoch # 24, Time Step # 7, Loss Value = 8.580848693847656
# Epoch # 24, Time Step # 8, Loss Value = 8.618841171264648
# Epoch # 24, Time Step # 9, Loss Value = 8.601273536682129
# Epoch # 24, Time Step # 10, Loss Value = 8.622862815856934
# Epoch # 24, Time Step # 11, Loss Value = 8.614594459533691
# Epoch # 24, Time Step # 12, Loss Value = 8.564774513244629
# Epoch # 24, Time Step # 13, Loss Value = 8.59415340423584
# Epoch # 24, Time Step # 14, Loss Value = 8.594379425048828
# Epoch # 24, Time Step # 15, Loss Value = 8.608638763427734
# Epoch # 24, Time Step # 16, Loss Value = 8.589176177978516
# Epoch # 24, Time Step # 17, Loss Value = 8.600471496582031
# Epoch # 24, Time Step # 18, Loss Value = 8.578228950500488
# Epoch # 24, Time Step # 19, Loss Value = 8.621074676513672
# Epoch # 24, Time Step # 20, Loss Value = 8.629661560058594
# Epoch # 24, Time Step # 21, Loss Value = 8.603163719177246
# Epoch # 24, Time Step # 22, Loss Value = 8.663548469543457
# Epoch # 24, Time Step # 23, Loss Value = 8.638078689575195
# Epoch # 24, Time Step # 24, Loss Value = 8.626303672790527
# Epoch # 24, Time Step # 25, Loss Value = 8.575122833251953
# Epoch # 24, Time Step # 26, Loss Value = 8.608128547668457
# Epoch # 24, Time Step # 27, Loss Value = 8.607242584228516
# Epoch # 24, Time Step # 28, Loss Value = 8.596501350402832
# Epoch # 24, Time Step # 29, Loss Value = 8.56456470489502
# Epoch # 24, Time Step # 30, Loss Value = 8.56232738494873
# Epoch # 24, Time Step # 31, Loss Value = 8.566197395324707
# Epoch # 24, Time Step # 32, Loss Value = 8.549230575561523
# Epoch # 24, Time Step # 33, Loss Value = 8.569231986999512
# Epoch # 24, Time Step # 34, Loss Value = 8.626359939575195
# Epoch # 24, Time Step # 35, Loss Value = 8.622774124145508
# Epoch # 24, Time Step # 36, Loss Value = 8.582621574401855
# Epoch # 24, Time Step # 37, Loss Value = 8.599749565124512
# Epoch # 24, Time Step # 38, Loss Value = 8.605695724487305
# Epoch # 24, Time Step # 39, Loss Value = 8.586958885192871
# Epoch # 24, Time Step # 40, Loss Value = 8.603458404541016
# Epoch # 24, Time Step # 41, Loss Value = 8.581113815307617
# Epoch # 24, Time Step # 42, Loss Value = 8.566214561462402
# Epoch # 24, Time Step # 43, Loss Value = 8.595071792602539
# Epoch # 24, Time Step # 44, Loss Value = 8.597994804382324
# Epoch # 24, Time Step # 45, Loss Value = 8.582691192626953
# Epoch # 24, Time Step # 46, Loss Value = 8.603248596191406
# Epoch # 24, Time Step # 47, Loss Value = 8.58829402923584
# Epoch # 24, Time Step # 48, Loss Value = 8.598082542419434
# Epoch # 24, Time Step # 49, Loss Value = 8.600279808044434
# Epoch # 24, Time Step # 50, Loss Value = 8.589365005493164
# Epoch # 24, Time Step # 51, Loss Value = 8.586858749389648
# Epoch # 24, Time Step # 52, Loss Value = 8.613285064697266
# Epoch # 24, Time Step # 53, Loss Value = 8.588494300842285
# Epoch # 24, Time Step # 54, Loss Value = 8.601407051086426
# Epoch # 24, Time Step # 55, Loss Value = 8.606125831604004
# Epoch # 24, Time Step # 56, Loss Value = 8.59332275390625
# Epoch # 24, Time Step # 57, Loss Value = 8.609713554382324
# Epoch # 24, Time Step # 58, Loss Value = 8.579241752624512
# Epoch # 24, Time Step # 59, Loss Value = 8.541132926940918
# Epoch # 24, Time Step # 60, Loss Value = 8.585596084594727
# Epoch # 24, Time Step # 61, Loss Value = 8.555047988891602
# Epoch # 24, Time Step # 62, Loss Value = 8.586797714233398
# Epoch # 24, Time Step # 63, Loss Value = 8.629316329956055
# Epoch # 24, Time Step # 64, Loss Value = 8.55894660949707
# Epoch # 24, Time Step # 65, Loss Value = 8.579466819763184
# Epoch # 24, Time Step # 66, Loss Value = 8.596714973449707
# Epoch # 24, Time Step # 67, Loss Value = 8.59104061126709
# Epoch # 24, Time Step # 68, Loss Value = 8.59077262878418
# Epoch # 24, Time Step # 69, Loss Value = 8.61984634399414
# Epoch # 24, Time Step # 70, Loss Value = 8.566544532775879
# Epoch # 24, Time Step # 71, Loss Value = 8.586986541748047
# Epoch # 24, Time Step # 72, Loss Value = 8.601667404174805
# Epoch # 24, Time Step # 73, Loss Value = 8.581838607788086
# Epoch # 24, Time Step # 74, Loss Value = 8.5967378616333
# Epoch # 24, Time Step # 75, Loss Value = 8.564345359802246
# Epoch # 24, Time Step # 76, Loss Value = 8.602270126342773
# Epoch # 24, Time Step # 77, Loss Value = 8.583417892456055
# Epoch # 24, Time Step # 78, Loss Value = 8.55324935913086
# Epoch # 24, Time Step # 79, Loss Value = 8.569091796875
# Epoch # 24, Time Step # 80, Loss Value = 8.565204620361328
# Epoch # 24, Time Step # 81, Loss Value = 8.594582557678223
# Epoch # 24, Time Step # 82, Loss Value = 8.546279907226562
# Epoch # 24, Time Step # 83, Loss Value = 8.607112884521484
# Epoch # 24, Time Step # 84, Loss Value = 8.5453462600708
# Epoch # 24, Time Step # 85, Loss Value = 8.512933731079102
# Epoch # 24, Time Step # 86, Loss Value = 8.505083084106445
# Epoch # 24, Time Step # 87, Loss Value = 8.495756149291992
# Epoch # 24, Time Step # 88, Loss Value = 8.552210807800293
# Epoch # 24, Time Step # 89, Loss Value = 8.530582427978516
# Epoch # 24, Time Step # 90, Loss Value = 8.474935531616211
# Epoch # 24, Time Step # 91, Loss Value = 8.454180717468262
# Epoch # 24, Time Step # 92, Loss Value = 8.605770111083984
# Epoch # 24, Time Step # 93, Loss Value = 8.56317138671875
# Epoch # 24, Time Step # 94, Loss Value = 8.573107719421387
# Epoch # 24, Time Step # 95, Loss Value = 8.665870666503906
# Epoch # 24, Time Step # 96, Loss Value = 8.688631057739258
# Epoch # 24, Time Step # 97, Loss Value = 8.578364372253418
# Epoch # 24, Time Step # 98, Loss Value = 8.547365188598633
# Epoch # 24, Time Step # 99, Loss Value = 8.548256874084473
# Epoch # 24, Time Step # 100, Loss Value = 8.569230079650879
# Epoch # 24, Time Step # 101, Loss Value = 8.530943870544434
# Epoch # 24, Time Step # 102, Loss Value = 8.501738548278809
# Epoch # 24, Time Step # 103, Loss Value = 8.55334186553955
# Epoch # 24, Time Step # 104, Loss Value = 8.569278717041016
# Epoch # 24, Time Step # 105, Loss Value = 8.555256843566895
# Epoch # 24, Time Step # 106, Loss Value = 8.576212882995605
# Epoch # 24, Time Step # 107, Loss Value = 8.529972076416016
# Epoch # 24, Time Step # 108, Loss Value = 8.509247779846191
# Epoch # 24, Time Step # 109, Loss Value = 8.497815132141113
# Epoch # 24, Time Step # 110, Loss Value = 8.550501823425293
# Epoch # 24, Time Step # 111, Loss Value = 8.576483726501465
# Epoch # 24, Time Step # 112, Loss Value = 8.600305557250977
# Epoch # 24, Time Step # 113, Loss Value = 8.558728218078613
# Epoch # 24, Time Step # 114, Loss Value = 8.540350914001465
# Epoch # 24, Time Step # 115, Loss Value = 8.5601167678833
# Epoch # 24, Time Step # 116, Loss Value = 8.601479530334473
# Epoch # 24, Time Step # 117, Loss Value = 8.564653396606445
# Epoch # 24, Time Step # 118, Loss Value = 8.514719009399414
# Epoch # 24, Time Step # 119, Loss Value = 8.501154899597168
# Epoch # 24, Time Step # 120, Loss Value = 8.596481323242188
# Epoch # 24, Time Step # 121, Loss Value = 8.53857421875
# Epoch # 24, Time Step # 122, Loss Value = 8.567818641662598
# Epoch # 24, Time Step # 123, Loss Value = 8.563087463378906
# Epoch # 24, Time Step # 124, Loss Value = 8.516542434692383
# Epoch # 24, Time Step # 125, Loss Value = 8.556195259094238
# Epoch # 24, Time Step # 126, Loss Value = 8.52731990814209
# Epoch # 24, Time Step # 127, Loss Value = 8.500368118286133
# Epoch # 24, Time Step # 128, Loss Value = 8.571566581726074
# Epoch # 24, Time Step # 129, Loss Value = 8.606718063354492
# Epoch # 24, Time Step # 130, Loss Value = 8.60444450378418
# Epoch # 24, Time Step # 131, Loss Value = 8.585365295410156
# Epoch # 24, Time Step # 132, Loss Value = 8.535567283630371
# Epoch # 24, Time Step # 133, Loss Value = 8.55805778503418
# Epoch # 24, Time Step # 134, Loss Value = 8.524273872375488
# Epoch # 24, Time Step # 135, Loss Value = 8.551514625549316
# Epoch # 24, Time Step # 136, Loss Value = 8.604911804199219
# Epoch # 24, Time Step # 137, Loss Value = 8.602193832397461
# Epoch # 24, Time Step # 138, Loss Value = 8.542074203491211
# Epoch # 24, Time Step # 139, Loss Value = 8.610698699951172
# Epoch # 24, Time Step # 140, Loss Value = 8.580011367797852
# Epoch # 24, Time Step # 141, Loss Value = 8.481963157653809
# Epoch # 24, Time Step # 142, Loss Value = 8.560858726501465
# Epoch # 24, Time Step # 143, Loss Value = 8.534995079040527
# Epoch # 24, Time Step # 144, Loss Value = 8.496110916137695
# Epoch # 24, Time Step # 145, Loss Value = 8.590676307678223
# Epoch # 24, Time Step # 146, Loss Value = 8.542051315307617
# Epoch # 24, Time Step # 147, Loss Value = 8.506060600280762
# Epoch # 24, Time Step # 148, Loss Value = 8.504322052001953
# Epoch # 24, Time Step # 149, Loss Value = 8.520130157470703
# Epoch # 24, Time Step # 150, Loss Value = 8.52099323272705
# Epoch # 24, Time Step # 151, Loss Value = 8.540550231933594
# Epoch # 24, Time Step # 152, Loss Value = 8.593223571777344
# Epoch # 24, Time Step # 153, Loss Value = 8.5779447555542
# Epoch # 24, Time Step # 154, Loss Value = 8.546043395996094
# Epoch # 24, Time Step # 155, Loss Value = 8.522273063659668
# Epoch # 24, Time Step # 156, Loss Value = 8.490002632141113
# Epoch # 24, Time Step # 157, Loss Value = 8.543508529663086
# Epoch # 24, Time Step # 158, Loss Value = 8.5276517868042
# Epoch # 24, Time Step # 159, Loss Value = 8.596903800964355
# Epoch # 24, Time Step # 160, Loss Value = 8.583879470825195
# Epoch # 24, Time Step # 161, Loss Value = 8.572997093200684
# Epoch # 24, Time Step # 162, Loss Value = 8.573831558227539
# Epoch # 24, Time Step # 163, Loss Value = 8.518743515014648
# Epoch # 24, Time Step # 164, Loss Value = 8.467290878295898
# Epoch # 24, Time Step # 165, Loss Value = 8.538817405700684
# Epoch # 24, Time Step # 166, Loss Value = 8.504626274108887
# Epoch # 24, Time Step # 167, Loss Value = 8.573995590209961
# Epoch # 24, Time Step # 168, Loss Value = 8.543230056762695
# Epoch # 24, Time Step # 169, Loss Value = 8.576062202453613
# Epoch # 24, Time Step # 170, Loss Value = 8.595340728759766
# Epoch # 24, Time Step # 171, Loss Value = 8.594749450683594
# Epoch # 24, Time Step # 172, Loss Value = 8.612035751342773
# Epoch # 24, Time Step # 173, Loss Value = 8.594661712646484
# Epoch # 24, Time Step # 174, Loss Value = 8.598289489746094
# Epoch # 24, Time Step # 175, Loss Value = 8.566691398620605
# Epoch # 24, Time Step # 176, Loss Value = 8.53228759765625
# Epoch # 24, Time Step # 177, Loss Value = 8.559893608093262
# Epoch # 24, Time Step # 178, Loss Value = 8.523127555847168
# Epoch # 24, Time Step # 179, Loss Value = 8.462364196777344
# Epoch # 24, Time Step # 180, Loss Value = 8.591876029968262
# Epoch # 24, Time Step # 181, Loss Value = 8.545690536499023
# Epoch # 24, Time Step # 182, Loss Value = 8.52774429321289
# Epoch # 24, Time Step # 183, Loss Value = 8.542030334472656
# Epoch # 24, Time Step # 184, Loss Value = 8.55745792388916
# Epoch # 24, Time Step # 185, Loss Value = 8.554365158081055
# Epoch # 24, Time Step # 186, Loss Value = 8.522709846496582
# Epoch # 24, Time Step # 187, Loss Value = 8.64171314239502
# Epoch # 24, Time Step # 188, Loss Value = 8.55031681060791
# Epoch # 24, Time Step # 189, Loss Value = 8.591288566589355
# Epoch # 24, Time Step # 190, Loss Value = 8.572787284851074
# Epoch # 24, Time Step # 191, Loss Value = 8.58392333984375
# Epoch # 24, Time Step # 192, Loss Value = 8.601725578308105
# Epoch # 24, Time Step # 193, Loss Value = 8.518800735473633
# Epoch # 24, Time Step # 194, Loss Value = 8.558713912963867
# Epoch # 24, Time Step # 195, Loss Value = 8.523091316223145
# Epoch # 24, Time Step # 196, Loss Value = 8.565866470336914
# Epoch # 24, Time Step # 197, Loss Value = 8.566842079162598
# Epoch # 24, Time Step # 198, Loss Value = 8.473831176757812
# Epoch # 24, Time Step # 199, Loss Value = 8.5956392288208

# %%
def generate_translation(eng_sentence):

    tokenized_eng_sentence=src_sent_tokenizer.tokenize(eng_sentence)
    token_ids=src_sent_tokenizer.convert_tokens_to_ids(tokenized_eng_sentence)
    token_ids_tensor=torch.tensor(token_ids)
    token_ids_tensor=torch.unsqueeze(token_ids_tensor,0)

    if torch.cuda.is_available():
        device=torch.device("cuda")
        token_ids_tensor=token_ids_tensor.to(device)

    encoder_output, (final_encoder_output,final_candidate_cell_state) = encoder(token_ids_tensor)
    decoder_first_time_step_input=torch.tensor([[0]])

# %%
src_sent_tokenizer
# Out:
# T5TokenizerFast(name_or_path='google-T5/T5-base', vocab_size=32100, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<pad>', 'additional_special_tokens': ['<extra_id_0>', '<extra_id_1>', '<extra_id_2>', '<extra_id_3>', '<extra_id_4>', '<extra_id_5>', '<extra_id_6>', '<extra_id_7>', '<extra_id_8>', '<extra_id_9>', '<extra_id_10>', '<extra_id_11>', '<extra_id_12>', '<extra_id_13>', '<extra_id_14>', '<extra_id_15>', '<extra_id_16>', '<extra_id_17>', '<extra_id_18>', '<extra_id_19>', '<extra_id_20>', '<extra_id_21>', '<extra_id_22>', '<extra_id_23>', '<extra_id_24>', '<extra_id_25>', '<extra_id_26>', '<extra_id_27>', '<extra_id_28>', '<extra_id_29>', '<extra_id_30>', '<extra_id_31>', '<extra_id_32>', '<extra_id_33>', '<extra_id_34>', '<extra_id_35>', '<extra_id_36>', '<extra_id_37>', '<extra_id_38>', '<extra_id_39>', '<extra_id_40>', '<extra_id_41>', '<extra_id_42>', '<extra_id_43>', '<extra_id_44>', '<extra_id_45>', '<extra_id_46>', '<extra_id_47>', '<extra_id_48>', '<extra_id_49>', '<extra_id_50>', '<extra_id_51>', '<extra_id_52>', '<extra_id_53>', '<extra_id_54>', '<extra_id_55>', '<extra_id_56>', '<extra_id_57>', '<extra_id_58>', '<extra_id_59>', '<extra_id_60>', '<extra_id_61>', '<extra_id_62>', '<extra_id_63>', '<extra_id_64>', '<extra_id_65>', '<extra_id_66>', '<extra_id_67>', '<extra_id_68>', '<extra_id_69>', '<extra_id_70>', '<extra_id_71>', '<extra_id_72>', '<extra_id_73>', '<extra_id_74>', '<extra_id_75>', '<extra_id_76>', '<extra_id_77>', '<extra_id_78>', '<extra_id_79>', '<extra_id_80>', '<extra_id_81>', '<extra_id_82>', '<extra_id_83>', '<extra_id_84>', '<extra_id_85>', '<extra_id_86>', '<extra_id_87>', '<extra_id_88>', '<extra_id_89>', '<extra_id_90>', '<extra_id_91>', '<extra_id_92>', '<extra_id_93>', '<extra_id_94>', '<extra_id_95>', '<extra_id_96>', '<extra_id_97>', '<extra_id_98>', '<extra_id_99>']}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	0: AddedToken("<pad>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32000: AddedToken("<extra_id_99>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32001: AddedToken("<extra_id_98>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32002: AddedToken("<extra_id_97>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32003: AddedToken("<extra_id_96>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32004: AddedToken("<extra_id_95>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32005: AddedToken("<extra_id_94>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32006: AddedToken("<extra_id_93>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32007: AddedToken("<extra_id_92>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32008: AddedToken("<extra_id_91>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32009: AddedToken("<extra_id_90>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32010: AddedToken("<extra_id_89>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32011: AddedToken("<extra_id_88>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32012: AddedToken("<extra_id_87>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32013: AddedToken("<extra_id_86>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32014: AddedToken("<extra_id_85>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32015: AddedToken("<extra_id_84>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32016: AddedToken("<extra_id_83>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32017: AddedToken("<extra_id_82>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32018: AddedToken("<extra_id_81>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32019: AddedToken("<extra_id_80>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32020: AddedToken("<extra_id_79>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32021: AddedToken("<extra_id_78>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32022: AddedToken("<extra_id_77>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32023: AddedToken("<extra_id_76>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32024: AddedToken("<extra_id_75>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32025: AddedToken("<extra_id_74>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32026: AddedToken("<extra_id_73>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32027: AddedToken("<extra_id_72>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32028: AddedToken("<extra_id_71>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32029: AddedToken("<extra_id_70>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32030: AddedToken("<extra_id_69>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32031: AddedToken("<extra_id_68>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32032: AddedToken("<extra_id_67>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32033: AddedToken("<extra_id_66>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32034: AddedToken("<extra_id_65>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32035: AddedToken("<extra_id_64>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32036: AddedToken("<extra_id_63>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32037: AddedToken("<extra_id_62>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32038: AddedToken("<extra_id_61>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32039: AddedToken("<extra_id_60>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32040: AddedToken("<extra_id_59>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32041: AddedToken("<extra_id_58>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32042: AddedToken("<extra_id_57>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32043: AddedToken("<extra_id_56>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32044: AddedToken("<extra_id_55>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32045: AddedToken("<extra_id_54>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32046: AddedToken("<extra_id_53>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32047: AddedToken("<extra_id_52>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32048: AddedToken("<extra_id_51>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32049: AddedToken("<extra_id_50>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32050: AddedToken("<extra_id_49>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32051: AddedToken("<extra_id_48>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32052: AddedToken("<extra_id_47>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32053: AddedToken("<extra_id_46>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32054: AddedToken("<extra_id_45>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32055: AddedToken("<extra_id_44>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32056: AddedToken("<extra_id_43>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32057: AddedToken("<extra_id_42>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32058: AddedToken("<extra_id_41>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32059: AddedToken("<extra_id_40>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32060: AddedToken("<extra_id_39>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32061: AddedToken("<extra_id_38>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32062: AddedToken("<extra_id_37>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32063: AddedToken("<extra_id_36>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32064: AddedToken("<extra_id_35>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32065: AddedToken("<extra_id_34>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32066: AddedToken("<extra_id_33>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32067: AddedToken("<extra_id_32>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32068: AddedToken("<extra_id_31>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32069: AddedToken("<extra_id_30>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32070: AddedToken("<extra_id_29>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32071: AddedToken("<extra_id_28>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32072: AddedToken("<extra_id_27>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32073: AddedToken("<extra_id_26>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32074: AddedToken("<extra_id_25>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32075: AddedToken("<extra_id_24>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32076: AddedToken("<extra_id_23>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32077: AddedToken("<extra_id_22>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32078: AddedToken("<extra_id_21>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32079: AddedToken("<extra_id_20>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32080: AddedToken("<extra_id_19>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32081: AddedToken("<extra_id_18>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32082: AddedToken("<extra_id_17>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32083: AddedToken("<extra_id_16>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32084: AddedToken("<extra_id_15>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32085: AddedToken("<extra_id_14>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32086: AddedToken("<extra_id_13>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32087: AddedToken("<extra_id_12>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32088: AddedToken("<extra_id_11>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32089: AddedToken("<extra_id_10>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32090: AddedToken("<extra_id_9>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32091: AddedToken("<extra_id_8>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32092: AddedToken("<extra_id_7>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32093: AddedToken("<extra_id_6>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32094: AddedToken("<extra_id_5>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32095: AddedToken("<extra_id_4>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32096: AddedToken("<extra_id_3>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32097: AddedToken("<extra_id_2>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32098: AddedToken("<extra_id_1>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32099: AddedToken("<extra_id_0>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }
# )
