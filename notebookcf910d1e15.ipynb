# %% [markdown]
# <a href="https://www.kaggle.com/code/princekalyan/notebook1?scriptVersionId=263266025" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !pip3 install indic-nlp-library
# Out:
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl.metadata (5.7 kB)
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.5.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.2.4)
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (8.2.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.32.4)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (25.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->indic-nlp-library) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2025.6.15)
# Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.2 MB/s eta 0:00:00
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Downloading sphinx_argparse-0.5.2-py3-none-any.whl (12 kB)
# Installing collected packages: morfessor, sphinx-argparse, indic-nlp-library
# Successfully installed indic-nlp-library-0.92 morfessor-2.0.6 sphinx-argparse-0.5.2

# %%
# !pip3 install indic-nlp-library
# Out:
# Requirement already satisfied: indic-nlp-library in /usr/local/lib/python3.11/dist-packages (0.92)
# Requirement already satisfied: sphinx-argparse in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.5.2)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.2.4)
# Requirement already satisfied: morfessor in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (8.2.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.32.4)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (25.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->indic-nlp-library) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2025.6.15)

# %%
import pandas as pd
import numpy as np
from transformers import AutoTokenizer
import torch
from indicnlp.tokenize import indic_tokenize

# %%
data = pd.read_csv("https://raw.githubusercontent.com/aimlrl/sample-dataset/refs/heads/master/Sentence%20pairs%20in%20English-Hindi%20-%202025-02-11.tsv",
                  sep="\t",header=None,names=["SrcSentID","SrcSent","DstSentID","DstSent"])

# %%
data.head()
# Out:
#    SrcSentID                                  SrcSent  DstSentID  \
# 0       1282                       Muiriel is 20 now.     485968
# 1       1282                       Muiriel is 20 now.    2060319
# 2       1294  Education in this world disappoints me.     485564
# 3       1302                       That won't happen.    2060320
# 4       1308                              I miss you.    2060321
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
data.drop(labels=[data.columns[0],data.columns[2]],axis=1,inplace=True)

# %%
data.head()
# Out:
#                                    SrcSent  \
# 0                       Muiriel is 20 now.
# 1                       Muiriel is 20 now.
# 2  Education in this world disappoints me.
# 3                       That won't happen.
# 4                              I miss you.
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
src_sent_tokenizer = AutoTokenizer.from_pretrained("google-T5/T5-base")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
data["SrcSent"] = data["SrcSent"].apply(lambda x: src_sent_tokenizer.tokenize(x))

# %%
data.head()
# Out:
#                                              SrcSent  \
# 0                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 1                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 2  [▁Education, ▁in, ▁this, ▁world, ▁disappoint, ...
# 3                    [▁That, ▁won, ', t, ▁happen, .]
# 4                               [▁I, ▁miss, ▁you, .]
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
data["DstSent"] = data["DstSent"].apply(lambda x: indic_tokenize.trivial_tokenize(x,lang="hi"))

# %%
data["SrcSent"] = data["SrcSent"].apply(src_sent_tokenizer.convert_tokens_to_ids)

# %%
Vs = src_sent_tokenizer.get_vocab()

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent
# 0        [म्यूरियल, अब, बीस, साल, की, हो, गई, है, ।]
# 1                [म्यूरियल, अब, बीस, साल, की, है, ।]
# 2  [मैं, इस, दुनिया, में, शिक्षा, पर, बहुत, निराश...
# 3                              [वैसा, नहीं, होगा, ।]
# 4              [मुझें, तुम्हारी, याद, आ, रही, है, ।]

# %%
hindi_vocab = set()

for tokenized_hindi_sent in data["DstSent"]:
    hindi_vocab.update(tokenized_hindi_sent)

# %%
Vd = dict()
for idx, token in enumerate(hindi_vocab):
    Vd[token] = idx + 3
Vd["<PAD>"] = 0
Vd["<SOS>"] = 1
Vd["<EOS>"] = 2

# %%
def convert_hindi_tokens_to_ids(hindi_sent):
    return [Vd[token] for token in hindi_sent]

# %%
data["DstSent"] = data["DstSent"].apply(lambda x: convert_hindi_tokens_to_ids(x))

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent
# 0  [1136, 2033, 4381, 1921, 3542, 2672, 3015, 130...
# 1         [1136, 2033, 4381, 1921, 3542, 1300, 1960]
# 2  [3606, 1775, 719, 2668, 316, 915, 4213, 3225, ...
# 3                           [6691, 1261, 6239, 1960]
# 4          [1246, 4973, 1017, 893, 2365, 1300, 1960]

# %%
def insert_sos_token_id(hindi_sent_token_ids):
    return [1] + hindi_sent_token_ids

# %%
data["DstSentInput"] = data["DstSent"].apply(lambda x: insert_sos_token_id(x))

# %%
def insert_eos_token_id(hindi_sent_token_ids):
    return hindi_sent_token_ids + [2]

# %%
data["DstSentLabel"] = data["DstSent"].apply(lambda x: insert_eos_token_id(x))

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent  \
# 0  [1136, 2033, 4381, 1921, 3542, 2672, 3015, 130...
# 1         [1136, 2033, 4381, 1921, 3542, 1300, 1960]
# 2  [3606, 1775, 719, 2668, 316, 915, 4213, 3225, ...
# 3                           [6691, 1261, 6239, 1960]
# 4          [1246, 4973, 1017, 893, 2365, 1300, 1960]
#
#                                         DstSentInput  \
# 0  [1, 1136, 2033, 4381, 1921, 3542, 2672, 3015, ...
# 1      [1, 1136, 2033, 4381, 1921, 3542, 1300, 1960]
# 2  [1, 3606, 1775, 719, 2668, 316, 915, 4213, 322...
# 3                        [1, 6691, 1261, 6239, 1960]
# 4       [1, 1246, 4973, 1017, 893, 2365, 1300, 1960]
#
#                                         DstSentLabel
# 0  [1136, 2033, 4381, 1921, 3542, 2672, 3015, 130...
# 1      [1136, 2033, 4381, 1921, 3542, 1300, 1960, 2]
# 2  [3606, 1775, 719, 2668, 316, 915, 4213, 3225, ...
# 3                        [6691, 1261, 6239, 1960, 2]
# 4       [1246, 4973, 1017, 893, 2365, 1300, 1960, 2]

# %%
data.drop(labels=[data.columns[1]],axis=1,inplace=True)

# %%
X = list(data["SrcSent"])
Y_input = list(data["DstSentInput"])
Y_label = list(data["DstSentLabel"])

# %%
X_tensor = [torch.tensor(tokenized_eng_sent_ids) for tokenized_eng_sent_ids in X]
Y_input_tensor = [torch.tensor(tokenized_hin_sent_ids) for tokenized_hin_sent_ids in Y_input]
Y_label_tensor = [torch.tensor(tokenized_hin_sent_ids) for tokenized_hin_sent_ids in Y_label]

# %%
X_padded = torch.nn.utils.rnn.pad_sequence(X_tensor,batch_first=True)
Y_padded_input = torch.nn.utils.rnn.pad_sequence(Y_input_tensor,batch_first=True)
Y_padded_label = torch.nn.utils.rnn.pad_sequence(Y_label_tensor,batch_first=True)

# %%
Ns = X_padded.shape[1]
Nd = Y_padded_label.shape[1]

# %%
class Encoder(torch.nn.Module):

    def __init__(self,src_lang_vocab_size,word_embedding_dim):
        super(Encoder,self).__init__()
        self.first_embedding_layer = torch.nn.Embedding(num_embeddings=src_lang_vocab_size,
                                                       embedding_dim=word_embedding_dim)
        self.second_lstm_layer = torch.nn.LSTM(input_size=word_embedding_dim,
                                               hidden_size=word_embedding_dim,
                                              batch_first=True)

    def forward(self,X_padded_mini_batch):

        first_embedding_layer_out = self.first_embedding_layer(X_padded_mini_batch)
        encoder_output, (final_encoder_output,final_cell_state) = self.second_lstm_layer(first_embedding_layer_out)

        return encoder_output, (final_encoder_output,final_cell_state)

# %%
class Decoder(torch.nn.Module):

    def __init__(self,dst_lang_vocab_size,word_embedding_dim):
        super(Decoder,self).__init__()

        self.first_embedding_layer = torch.nn.Embedding(num_embeddings=dst_lang_vocab_size,
                                                       embedding_dim=word_embedding_dim)
        self.second_lstm_layer = torch.nn.LSTM(input_size=word_embedding_dim,
                                               hidden_size=word_embedding_dim,
                                              batch_first=True)
        self.prediction_layer = torch.nn.Linear(in_features=word_embedding_dim,out_features=dst_lang_vocab_size)
        self.prediction_layer_activation = torch.nn.Softmax(dim=2)

    def forward(self,Y_padded_input_mini_batch,final_encoder_output,final_cell_state):

        first_embedding_layer_out = self.first_embedding_layer(Y_padded_input_mini_batch)
        decoder_lstm_layer_out, (final_decoder_lstm_layer_out, final_cell_state) = self.second_lstm_layer(first_embedding_layer_out,
                                                                                                         (final_encoder_output,
                                                                                                          final_cell_state))
        prediction = self.prediction_layer_activation(self.prediction_layer(decoder_lstm_layer_out))

        return prediction, (final_decoder_lstm_layer_out, final_cell_state)

# %%
class Seq2SeqEncDec(torch.nn.Module):

    def __init__(self,src_lang_vocab_size,dst_lang_vocab_size,word_embedding_dim):
        super(Seq2SeqEncDec,self).__init__()

        self.encoder = Encoder(src_lang_vocab_size,word_embedding_dim)
        self.decoder = Decoder(dst_lang_vocab_size,word_embedding_dim)

    def forward(self,X_padded_mini_batch,Y_padded_input_mini_batch):

        encoder_output, (final_encoder_output,final_cell_state) = self.encoder(X_padded_mini_batch)
        y_hat_mini_batch = self.decoder(Y_padded_input_mini_batch,
                                        final_encoder_output,final_cell_state)

        return y_hat_mini_batch

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print(device)
# Out:
# cpu

# %%
X_padded_train = X_padded[0:13000]
Y_padded_input_train = Y_padded_input[0:13000]
Y_padded_label_train = Y_padded_label[0:13000]

X_padded_test = X_padded[13000:]
Y_padded_input_test = Y_padded_input[13000:]
Y_padded_label_test = Y_padded_label[13000:]

# %%
network = Seq2SeqEncDec(len(Vs),len(Vd),128).to(device)
loss_fn = torch.nn.CrossEntropyLoss(ignore_index=0)
optimizer = torch.optim.Adam(network.parameters())
num_epochs = 25
mb_size = 65

for epoch in range(num_epochs):
    for i in range(X_padded_train.shape[0]//mb_size):

        X_train_mb = X_padded_train[i*mb_size:(i+1)*mb_size]
        Y_input_mb = Y_padded_input_train[i*mb_size:(i+1)*mb_size]
        Y_label_mb = Y_padded_label_train[i*mb_size:(i+1)*mb_size]
        Y_label_mb = Y_label_mb.reshape(Y_label_mb.shape[0]*Y_label_mb.shape[1],)

        X_train_mb, Y_input_mb, Y_label_mb = X_train_mb.to(device), Y_input_mb.to(device), Y_label_mb.to(device)

        y_hat_train_mb = network(X_train_mb,Y_input_mb)
        y_hat_train_mb = y_hat_train_mb[0]
        y_hat_train_mb = y_hat_train_mb.reshape(y_hat_train_mb.shape[0]*y_hat_train_mb.shape[1],
                                                y_hat_train_mb.shape[2])

        loss_fn_value = loss_fn(y_hat_train_mb,Y_label_mb)

        loss_fn_value.backward()
        torch.nn.utils.clip_grad_norm_(network.parameters(),max_norm=1.0)
        optimizer.step()
        optimizer.zero_grad()

        print("Epoch # {}, Time Step # {}, Loss Value = {}".format(epoch,i,loss_fn_value))
# Out:
# Epoch # 0, Time Step # 0, Loss Value = 8.863901138305664
# Epoch # 0, Time Step # 1, Loss Value = 8.863896369934082
# Epoch # 0, Time Step # 2, Loss Value = 8.8638916015625
# Epoch # 0, Time Step # 3, Loss Value = 8.863890647888184
# Epoch # 0, Time Step # 4, Loss Value = 8.863887786865234
# Epoch # 0, Time Step # 5, Loss Value = 8.863883018493652
# Epoch # 0, Time Step # 6, Loss Value = 8.86387825012207
# Epoch # 0, Time Step # 7, Loss Value = 8.863874435424805
# Epoch # 0, Time Step # 8, Loss Value = 8.863868713378906
# Epoch # 0, Time Step # 9, Loss Value = 8.86385726928711
# Epoch # 0, Time Step # 10, Loss Value = 8.863850593566895
# Epoch # 0, Time Step # 11, Loss Value = 8.863836288452148
# Epoch # 0, Time Step # 12, Loss Value = 8.863804817199707
# Epoch # 0, Time Step # 13, Loss Value = 8.863805770874023
# Epoch # 0, Time Step # 14, Loss Value = 8.863767623901367
# Epoch # 0, Time Step # 15, Loss Value = 8.863740921020508
# Epoch # 0, Time Step # 16, Loss Value = 8.863676071166992
# Epoch # 0, Time Step # 17, Loss Value = 8.863609313964844
# Epoch # 0, Time Step # 18, Loss Value = 8.863423347473145
# Epoch # 0, Time Step # 19, Loss Value = 8.863354682922363
# Epoch # 0, Time Step # 20, Loss Value = 8.863178253173828
# Epoch # 0, Time Step # 21, Loss Value = 8.862615585327148
# Epoch # 0, Time Step # 22, Loss Value = 8.862774848937988
# Epoch # 0, Time Step # 23, Loss Value = 8.861576080322266
# Epoch # 0, Time Step # 24, Loss Value = 8.86051082611084
# Epoch # 0, Time Step # 25, Loss Value = 8.857931137084961
# Epoch # 0, Time Step # 26, Loss Value = 8.855833053588867
# Epoch # 0, Time Step # 27, Loss Value = 8.85299301147461
# Epoch # 0, Time Step # 28, Loss Value = 8.84628963470459
# Epoch # 0, Time Step # 29, Loss Value = 8.8397855758667
# Epoch # 0, Time Step # 30, Loss Value = 8.831456184387207
# Epoch # 0, Time Step # 31, Loss Value = 8.822038650512695
# Epoch # 0, Time Step # 32, Loss Value = 8.810921669006348
# Epoch # 0, Time Step # 33, Loss Value = 8.802081108093262
# Epoch # 0, Time Step # 34, Loss Value = 8.801493644714355
# Epoch # 0, Time Step # 35, Loss Value = 8.796316146850586
# Epoch # 0, Time Step # 36, Loss Value = 8.77122688293457
# Epoch # 0, Time Step # 37, Loss Value = 8.772655487060547
# Epoch # 0, Time Step # 38, Loss Value = 8.765748023986816
# Epoch # 0, Time Step # 39, Loss Value = 8.745200157165527
# Epoch # 0, Time Step # 40, Loss Value = 8.743638038635254
# Epoch # 0, Time Step # 41, Loss Value = 8.726309776306152
# Epoch # 0, Time Step # 42, Loss Value = 8.70915412902832
# Epoch # 0, Time Step # 43, Loss Value = 8.7110595703125
# Epoch # 0, Time Step # 44, Loss Value = 8.695996284484863
# Epoch # 0, Time Step # 45, Loss Value = 8.6863431930542
# Epoch # 0, Time Step # 46, Loss Value = 8.695751190185547
# Epoch # 0, Time Step # 47, Loss Value = 8.6827392578125
# Epoch # 0, Time Step # 48, Loss Value = 8.683303833007812
# Epoch # 0, Time Step # 49, Loss Value = 8.686452865600586
# Epoch # 0, Time Step # 50, Loss Value = 8.664332389831543
# Epoch # 0, Time Step # 51, Loss Value = 8.66517448425293
# Epoch # 0, Time Step # 52, Loss Value = 8.676466941833496
# Epoch # 0, Time Step # 53, Loss Value = 8.69580078125
# Epoch # 0, Time Step # 54, Loss Value = 8.688149452209473
# Epoch # 0, Time Step # 55, Loss Value = 8.716493606567383
# Epoch # 0, Time Step # 56, Loss Value = 8.689569473266602
# Epoch # 0, Time Step # 57, Loss Value = 8.694053649902344
# Epoch # 0, Time Step # 58, Loss Value = 8.679207801818848
# Epoch # 0, Time Step # 59, Loss Value = 8.6504545211792
# Epoch # 0, Time Step # 60, Loss Value = 8.670523643493652
# Epoch # 0, Time Step # 61, Loss Value = 8.650911331176758
# Epoch # 0, Time Step # 62, Loss Value = 8.684606552124023
# Epoch # 0, Time Step # 63, Loss Value = 8.712875366210938
# Epoch # 0, Time Step # 64, Loss Value = 8.651215553283691
# Epoch # 0, Time Step # 65, Loss Value = 8.66835880279541
# Epoch # 0, Time Step # 66, Loss Value = 8.671164512634277
# Epoch # 0, Time Step # 67, Loss Value = 8.673583984375
# Epoch # 0, Time Step # 68, Loss Value = 8.665980339050293
# Epoch # 0, Time Step # 69, Loss Value = 8.67311954498291
# Epoch # 0, Time Step # 70, Loss Value = 8.671988487243652
# Epoch # 0, Time Step # 71, Loss Value = 8.683793067932129
# Epoch # 0, Time Step # 72, Loss Value = 8.664957046508789
# Epoch # 0, Time Step # 73, Loss Value = 8.681639671325684
# Epoch # 0, Time Step # 74, Loss Value = 8.668045997619629
# Epoch # 0, Time Step # 75, Loss Value = 8.657134056091309
# Epoch # 0, Time Step # 76, Loss Value = 8.652355194091797
# Epoch # 0, Time Step # 77, Loss Value = 8.648120880126953
# Epoch # 0, Time Step # 78, Loss Value = 8.64211654663086
# Epoch # 0, Time Step # 79, Loss Value = 8.664731979370117
# Epoch # 0, Time Step # 80, Loss Value = 8.636226654052734
# Epoch # 0, Time Step # 81, Loss Value = 8.650958061218262
# Epoch # 0, Time Step # 82, Loss Value = 8.592329978942871
# Epoch # 0, Time Step # 83, Loss Value = 8.644646644592285
# Epoch # 0, Time Step # 84, Loss Value = 8.632793426513672
# Epoch # 0, Time Step # 85, Loss Value = 8.569077491760254
# Epoch # 0, Time Step # 86, Loss Value = 8.56833553314209
# Epoch # 0, Time Step # 87, Loss Value = 8.569079399108887
# Epoch # 0, Time Step # 88, Loss Value = 8.603558540344238
# Epoch # 0, Time Step # 89, Loss Value = 8.589140892028809
# Epoch # 0, Time Step # 90, Loss Value = 8.550066947937012
# Epoch # 0, Time Step # 91, Loss Value = 8.502553939819336
# Epoch # 0, Time Step # 92, Loss Value = 8.652650833129883
# Epoch # 0, Time Step # 93, Loss Value = 8.65869426727295
# Epoch # 0, Time Step # 94, Loss Value = 8.655850410461426
# Epoch # 0, Time Step # 95, Loss Value = 8.72236156463623
# Epoch # 0, Time Step # 96, Loss Value = 8.748830795288086
# Epoch # 0, Time Step # 97, Loss Value = 8.648932456970215
# Epoch # 0, Time Step # 98, Loss Value = 8.616949081420898
# Epoch # 0, Time Step # 99, Loss Value = 8.622306823730469
# Epoch # 0, Time Step # 100, Loss Value = 8.645747184753418
# Epoch # 0, Time Step # 101, Loss Value = 8.589018821716309
# Epoch # 0, Time Step # 102, Loss Value = 8.582862854003906
# Epoch # 0, Time Step # 103, Loss Value = 8.645318984985352
# Epoch # 0, Time Step # 104, Loss Value = 8.623059272766113
# Epoch # 0, Time Step # 105, Loss Value = 8.61988639831543
# Epoch # 0, Time Step # 106, Loss Value = 8.619424819946289
# Epoch # 0, Time Step # 107, Loss Value = 8.607810974121094
# Epoch # 0, Time Step # 108, Loss Value = 8.585741996765137
# Epoch # 0, Time Step # 109, Loss Value = 8.614508628845215
# Epoch # 0, Time Step # 110, Loss Value = 8.639094352722168
# Epoch # 0, Time Step # 111, Loss Value = 8.691349983215332
# Epoch # 0, Time Step # 112, Loss Value = 8.675271987915039
# Epoch # 0, Time Step # 113, Loss Value = 8.638629913330078
# Epoch # 0, Time Step # 114, Loss Value = 8.613031387329102
# Epoch # 0, Time Step # 115, Loss Value = 8.631187438964844
# Epoch # 0, Time Step # 116, Loss Value = 8.65407657623291
# Epoch # 0, Time Step # 117, Loss Value = 8.631792068481445
# Epoch # 0, Time Step # 118, Loss Value = 8.594542503356934
# Epoch # 0, Time Step # 119, Loss Value = 8.607540130615234
# Epoch # 0, Time Step # 120, Loss Value = 8.683218002319336
# Epoch # 0, Time Step # 121, Loss Value = 8.615312576293945
# Epoch # 0, Time Step # 122, Loss Value = 8.632083892822266
# Epoch # 0, Time Step # 123, Loss Value = 8.637223243713379
# Epoch # 0, Time Step # 124, Loss Value = 8.597875595092773
# Epoch # 0, Time Step # 125, Loss Value = 8.637192726135254
# Epoch # 0, Time Step # 126, Loss Value = 8.606834411621094
# Epoch # 0, Time Step # 127, Loss Value = 8.538712501525879
# Epoch # 0, Time Step # 128, Loss Value = 8.65036678314209
# Epoch # 0, Time Step # 129, Loss Value = 8.667912483215332
# Epoch # 0, Time Step # 130, Loss Value = 8.669075965881348
# Epoch # 0, Time Step # 131, Loss Value = 8.640861511230469
# Epoch # 0, Time Step # 132, Loss Value = 8.609461784362793
# Epoch # 0, Time Step # 133, Loss Value = 8.615854263305664
# Epoch # 0, Time Step # 134, Loss Value = 8.614377975463867
# Epoch # 0, Time Step # 135, Loss Value = 8.621267318725586
# Epoch # 0, Time Step # 136, Loss Value = 8.650605201721191
# Epoch # 0, Time Step # 137, Loss Value = 8.635249137878418
# Epoch # 0, Time Step # 138, Loss Value = 8.599401473999023
# Epoch # 0, Time Step # 139, Loss Value = 8.65993595123291
# Epoch # 0, Time Step # 140, Loss Value = 8.637738227844238
# Epoch # 0, Time Step # 141, Loss Value = 8.566071510314941
# Epoch # 0, Time Step # 142, Loss Value = 8.598053932189941
# Epoch # 0, Time Step # 143, Loss Value = 8.621318817138672
# Epoch # 0, Time Step # 144, Loss Value = 8.587730407714844
# Epoch # 0, Time Step # 145, Loss Value = 8.643277168273926
# Epoch # 0, Time Step # 146, Loss Value = 8.596447944641113
# Epoch # 0, Time Step # 147, Loss Value = 8.561321258544922
# Epoch # 0, Time Step # 148, Loss Value = 8.606603622436523
# Epoch # 0, Time Step # 149, Loss Value = 8.635787963867188
# Epoch # 0, Time Step # 150, Loss Value = 8.582254409790039
# Epoch # 0, Time Step # 151, Loss Value = 8.62033462524414
# Epoch # 0, Time Step # 152, Loss Value = 8.63058853149414
# Epoch # 0, Time Step # 153, Loss Value = 8.609550476074219
# Epoch # 0, Time Step # 154, Loss Value = 8.62678337097168
# Epoch # 0, Time Step # 155, Loss Value = 8.58591365814209
# Epoch # 0, Time Step # 156, Loss Value = 8.590832710266113
# Epoch # 0, Time Step # 157, Loss Value = 8.613489151000977
# Epoch # 0, Time Step # 158, Loss Value = 8.598031997680664
# Epoch # 0, Time Step # 159, Loss Value = 8.65575885772705
# Epoch # 0, Time Step # 160, Loss Value = 8.666168212890625
# Epoch # 0, Time Step # 161, Loss Value = 8.622234344482422
# Epoch # 0, Time Step # 162, Loss Value = 8.593230247497559
# Epoch # 0, Time Step # 163, Loss Value = 8.57353401184082
# Epoch # 0, Time Step # 164, Loss Value = 8.47358226776123
# Epoch # 0, Time Step # 165, Loss Value = 8.627385139465332
# Epoch # 0, Time Step # 166, Loss Value = 8.587702751159668
# Epoch # 0, Time Step # 167, Loss Value = 8.63625717163086
# Epoch # 0, Time Step # 168, Loss Value = 8.60430908203125
# Epoch # 0, Time Step # 169, Loss Value = 8.659651756286621
# Epoch # 0, Time Step # 170, Loss Value = 8.670573234558105
# Epoch # 0, Time Step # 171, Loss Value = 8.673133850097656
# Epoch # 0, Time Step # 172, Loss Value = 8.680514335632324
# Epoch # 0, Time Step # 173, Loss Value = 8.65660572052002
# Epoch # 0, Time Step # 174, Loss Value = 8.667272567749023
# Epoch # 0, Time Step # 175, Loss Value = 8.622381210327148
# Epoch # 0, Time Step # 176, Loss Value = 8.598584175109863
# Epoch # 0, Time Step # 177, Loss Value = 8.61602783203125
# Epoch # 0, Time Step # 178, Loss Value = 8.596853256225586
# Epoch # 0, Time Step # 179, Loss Value = 8.573800086975098
# Epoch # 0, Time Step # 180, Loss Value = 8.645363807678223
# Epoch # 0, Time Step # 181, Loss Value = 8.6051025390625
# Epoch # 0, Time Step # 182, Loss Value = 8.602469444274902
# Epoch # 0, Time Step # 183, Loss Value = 8.614556312561035
# Epoch # 0, Time Step # 184, Loss Value = 8.609657287597656
# Epoch # 0, Time Step # 185, Loss Value = 8.614300727844238
# Epoch # 0, Time Step # 186, Loss Value = 8.578605651855469
# Epoch # 0, Time Step # 187, Loss Value = 8.702528953552246
# Epoch # 0, Time Step # 188, Loss Value = 8.6253662109375
# Epoch # 0, Time Step # 189, Loss Value = 8.64939022064209
# Epoch # 0, Time Step # 190, Loss Value = 8.623618125915527
# Epoch # 0, Time Step # 191, Loss Value = 8.647200584411621
# Epoch # 0, Time Step # 192, Loss Value = 8.659317016601562
# Epoch # 0, Time Step # 193, Loss Value = 8.612607955932617
# Epoch # 0, Time Step # 194, Loss Value = 8.622883796691895
# Epoch # 0, Time Step # 195, Loss Value = 8.609504699707031
# Epoch # 0, Time Step # 196, Loss Value = 8.639888763427734
# Epoch # 0, Time Step # 197, Loss Value = 8.630733489990234
# Epoch # 0, Time Step # 198, Loss Value = 8.491959571838379
# Epoch # 0, Time Step # 199, Loss Value = 8.666049003601074
# Epoch # 1, Time Step # 0, Loss Value = 8.610091209411621
# Epoch # 1, Time Step # 1, Loss Value = 8.675257682800293
# Epoch # 1, Time Step # 2, Loss Value = 8.679877281188965
# Epoch # 1, Time Step # 3, Loss Value = 8.653356552124023
# Epoch # 1, Time Step # 4, Loss Value = 8.661614418029785
# Epoch # 1, Time Step # 5, Loss Value = 8.657793998718262
# Epoch # 1, Time Step # 6, Loss Value = 8.673254013061523
# Epoch # 1, Time Step # 7, Loss Value = 8.635355949401855
# Epoch # 1, Time Step # 8, Loss Value = 8.677803993225098
# Epoch # 1, Time Step # 9, Loss Value = 8.65937614440918
# Epoch # 1, Time Step # 10, Loss Value = 8.68813419342041
# Epoch # 1, Time Step # 11, Loss Value = 8.667078018188477
# Epoch # 1, Time Step # 12, Loss Value = 8.651010513305664
# Epoch # 1, Time Step # 13, Loss Value = 8.675495147705078
# Epoch # 1, Time Step # 14, Loss Value = 8.653167724609375
# Epoch # 1, Time Step # 15, Loss Value = 8.66672134399414
# Epoch # 1, Time Step # 16, Loss Value = 8.670110702514648
# Epoch # 1, Time Step # 17, Loss Value = 8.689099311828613
# Epoch # 1, Time Step # 18, Loss Value = 8.665018081665039
# Epoch # 1, Time Step # 19, Loss Value = 8.680374145507812
# Epoch # 1, Time Step # 20, Loss Value = 8.685833930969238
# Epoch # 1, Time Step # 21, Loss Value = 8.669027328491211
# Epoch # 1, Time Step # 22, Loss Value = 8.714056968688965
# Epoch # 1, Time Step # 23, Loss Value = 8.676536560058594
# Epoch # 1, Time Step # 24, Loss Value = 8.679226875305176
# Epoch # 1, Time Step # 25, Loss Value = 8.642491340637207
# Epoch # 1, Time Step # 26, Loss Value = 8.666877746582031
# Epoch # 1, Time Step # 27, Loss Value = 8.66139030456543
# Epoch # 1, Time Step # 28, Loss Value = 8.65073299407959
# Epoch # 1, Time Step # 29, Loss Value = 8.647335052490234
# Epoch # 1, Time Step # 30, Loss Value = 8.610760688781738
# Epoch # 1, Time Step # 31, Loss Value = 8.61363410949707
# Epoch # 1, Time Step # 32, Loss Value = 8.600213050842285
# Epoch # 1, Time Step # 33, Loss Value = 8.605194091796875
# Epoch # 1, Time Step # 34, Loss Value = 8.673892974853516
# Epoch # 1, Time Step # 35, Loss Value = 8.680620193481445
# Epoch # 1, Time Step # 36, Loss Value = 8.65746784210205
# Epoch # 1, Time Step # 37, Loss Value = 8.672439575195312
# Epoch # 1, Time Step # 38, Loss Value = 8.677355766296387
# Epoch # 1, Time Step # 39, Loss Value = 8.655316352844238
# Epoch # 1, Time Step # 40, Loss Value = 8.662164688110352
# Epoch # 1, Time Step # 41, Loss Value = 8.645697593688965
# Epoch # 1, Time Step # 42, Loss Value = 8.641725540161133
# Epoch # 1, Time Step # 43, Loss Value = 8.65627670288086
# Epoch # 1, Time Step # 44, Loss Value = 8.64615535736084
# Epoch # 1, Time Step # 45, Loss Value = 8.642850875854492
# Epoch # 1, Time Step # 46, Loss Value = 8.662790298461914
# Epoch # 1, Time Step # 47, Loss Value = 8.656450271606445
# Epoch # 1, Time Step # 48, Loss Value = 8.655359268188477
# Epoch # 1, Time Step # 49, Loss Value = 8.6569242477417
# Epoch # 1, Time Step # 50, Loss Value = 8.646583557128906
# Epoch # 1, Time Step # 51, Loss Value = 8.65327262878418
# Epoch # 1, Time Step # 52, Loss Value = 8.659796714782715
# Epoch # 1, Time Step # 53, Loss Value = 8.654895782470703
# Epoch # 1, Time Step # 54, Loss Value = 8.655717849731445
# Epoch # 1, Time Step # 55, Loss Value = 8.665742874145508
# Epoch # 1, Time Step # 56, Loss Value = 8.648390769958496
# Epoch # 1, Time Step # 57, Loss Value = 8.658964157104492
# Epoch # 1, Time Step # 58, Loss Value = 8.636381149291992
# Epoch # 1, Time Step # 59, Loss Value = 8.602193832397461
# Epoch # 1, Time Step # 60, Loss Value = 8.618424415588379
# Epoch # 1, Time Step # 61, Loss Value = 8.628071784973145
# Epoch # 1, Time Step # 62, Loss Value = 8.66105842590332
# Epoch # 1, Time Step # 63, Loss Value = 8.69428825378418
# Epoch # 1, Time Step # 64, Loss Value = 8.61986255645752
# Epoch # 1, Time Step # 65, Loss Value = 8.638544082641602
# Epoch # 1, Time Step # 66, Loss Value = 8.665557861328125
# Epoch # 1, Time Step # 67, Loss Value = 8.663589477539062
# Epoch # 1, Time Step # 68, Loss Value = 8.633256912231445
# Epoch # 1, Time Step # 69, Loss Value = 8.6638765335083
# Epoch # 1, Time Step # 70, Loss Value = 8.650717735290527
# Epoch # 1, Time Step # 71, Loss Value = 8.673072814941406
# Epoch # 1, Time Step # 72, Loss Value = 8.63934326171875
# Epoch # 1, Time Step # 73, Loss Value = 8.658663749694824
# Epoch # 1, Time Step # 74, Loss Value = 8.6597261428833
# Epoch # 1, Time Step # 75, Loss Value = 8.647114753723145
# Epoch # 1, Time Step # 76, Loss Value = 8.641711235046387
# Epoch # 1, Time Step # 77, Loss Value = 8.63182544708252
# Epoch # 1, Time Step # 78, Loss Value = 8.628451347351074
# Epoch # 1, Time Step # 79, Loss Value = 8.659845352172852
# Epoch # 1, Time Step # 80, Loss Value = 8.623541831970215
# Epoch # 1, Time Step # 81, Loss Value = 8.643081665039062
# Epoch # 1, Time Step # 82, Loss Value = 8.583675384521484
# Epoch # 1, Time Step # 83, Loss Value = 8.633878707885742
# Epoch # 1, Time Step # 84, Loss Value = 8.620109558105469
# Epoch # 1, Time Step # 85, Loss Value = 8.549280166625977
# Epoch # 1, Time Step # 86, Loss Value = 8.561972618103027
# Epoch # 1, Time Step # 87, Loss Value = 8.561662673950195
# Epoch # 1, Time Step # 88, Loss Value = 8.59830379486084
# Epoch # 1, Time Step # 89, Loss Value = 8.580389976501465
# Epoch # 1, Time Step # 90, Loss Value = 8.542428970336914
# Epoch # 1, Time Step # 91, Loss Value = 8.495111465454102
# Epoch # 1, Time Step # 92, Loss Value = 8.648703575134277
# Epoch # 1, Time Step # 93, Loss Value = 8.655695915222168
# Epoch # 1, Time Step # 94, Loss Value = 8.653358459472656
# Epoch # 1, Time Step # 95, Loss Value = 8.720285415649414
# Epoch # 1, Time Step # 96, Loss Value = 8.747525215148926
# Epoch # 1, Time Step # 97, Loss Value = 8.645204544067383
# Epoch # 1, Time Step # 98, Loss Value = 8.614652633666992
# Epoch # 1, Time Step # 99, Loss Value = 8.618209838867188
# Epoch # 1, Time Step # 100, Loss Value = 8.640475273132324
# Epoch # 1, Time Step # 101, Loss Value = 8.586328506469727
# Epoch # 1, Time Step # 102, Loss Value = 8.576171875
# Epoch # 1, Time Step # 103, Loss Value = 8.642338752746582
# Epoch # 1, Time Step # 104, Loss Value = 8.615795135498047
# Epoch # 1, Time Step # 105, Loss Value = 8.617501258850098
# Epoch # 1, Time Step # 106, Loss Value = 8.616190910339355
# Epoch # 1, Time Step # 107, Loss Value = 8.605131149291992
# Epoch # 1, Time Step # 108, Loss Value = 8.580906867980957
# Epoch # 1, Time Step # 109, Loss Value = 8.61240005493164
# Epoch # 1, Time Step # 110, Loss Value = 8.637234687805176
# Epoch # 1, Time Step # 111, Loss Value = 8.689002990722656
# Epoch # 1, Time Step # 112, Loss Value = 8.673808097839355
# Epoch # 1, Time Step # 113, Loss Value = 8.636863708496094
# Epoch # 1, Time Step # 114, Loss Value = 8.610823631286621
# Epoch # 1, Time Step # 115, Loss Value = 8.629576683044434
# Epoch # 1, Time Step # 116, Loss Value = 8.652242660522461
# Epoch # 1, Time Step # 117, Loss Value = 8.62905216217041
# Epoch # 1, Time Step # 118, Loss Value = 8.59189224243164
# Epoch # 1, Time Step # 119, Loss Value = 8.604364395141602
# Epoch # 1, Time Step # 120, Loss Value = 8.666354179382324
# Epoch # 1, Time Step # 121, Loss Value = 8.6117582321167
# Epoch # 1, Time Step # 122, Loss Value = 8.630062103271484
# Epoch # 1, Time Step # 123, Loss Value = 8.634478569030762
# Epoch # 1, Time Step # 124, Loss Value = 8.59620475769043
# Epoch # 1, Time Step # 125, Loss Value = 8.622273445129395
# Epoch # 1, Time Step # 126, Loss Value = 8.60522747039795
# Epoch # 1, Time Step # 127, Loss Value = 8.5355224609375
# Epoch # 1, Time Step # 128, Loss Value = 8.6455659866333
# Epoch # 1, Time Step # 129, Loss Value = 8.664413452148438
# Epoch # 1, Time Step # 130, Loss Value = 8.667672157287598
# Epoch # 1, Time Step # 131, Loss Value = 8.639307975769043
# Epoch # 1, Time Step # 132, Loss Value = 8.608070373535156
# Epoch # 1, Time Step # 133, Loss Value = 8.614256858825684
# Epoch # 1, Time Step # 134, Loss Value = 8.612549781799316
# Epoch # 1, Time Step # 135, Loss Value = 8.61916732788086
# Epoch # 1, Time Step # 136, Loss Value = 8.649441719055176
# Epoch # 1, Time Step # 137, Loss Value = 8.631052017211914
# Epoch # 1, Time Step # 138, Loss Value = 8.598004341125488
# Epoch # 1, Time Step # 139, Loss Value = 8.65615463256836
# Epoch # 1, Time Step # 140, Loss Value = 8.63475513458252
# Epoch # 1, Time Step # 141, Loss Value = 8.56458568572998
# Epoch # 1, Time Step # 142, Loss Value = 8.596839904785156
# Epoch # 1, Time Step # 143, Loss Value = 8.619636535644531
# Epoch # 1, Time Step # 144, Loss Value = 8.586343765258789
# Epoch # 1, Time Step # 145, Loss Value = 8.642232894897461
# Epoch # 1, Time Step # 146, Loss Value = 8.591888427734375
# Epoch # 1, Time Step # 147, Loss Value = 8.549630165100098
# Epoch # 1, Time Step # 148, Loss Value = 8.60374641418457
# Epoch # 1, Time Step # 149, Loss Value = 8.634825706481934
# Epoch # 1, Time Step # 150, Loss Value = 8.580991744995117
# Epoch # 1, Time Step # 151, Loss Value = 8.618870735168457
# Epoch # 1, Time Step # 152, Loss Value = 8.629668235778809
# Epoch # 1, Time Step # 153, Loss Value = 8.608210563659668
# Epoch # 1, Time Step # 154, Loss Value = 8.625540733337402
# Epoch # 1, Time Step # 155, Loss Value = 8.584750175476074
# Epoch # 1, Time Step # 156, Loss Value = 8.589349746704102
# Epoch # 1, Time Step # 157, Loss Value = 8.612409591674805
# Epoch # 1, Time Step # 158, Loss Value = 8.596318244934082
# Epoch # 1, Time Step # 159, Loss Value = 8.65534496307373
# Epoch # 1, Time Step # 160, Loss Value = 8.665488243103027
# Epoch # 1, Time Step # 161, Loss Value = 8.619248390197754
# Epoch # 1, Time Step # 162, Loss Value = 8.589971542358398
# Epoch # 1, Time Step # 163, Loss Value = 8.571764945983887
# Epoch # 1, Time Step # 164, Loss Value = 8.466522216796875
# Epoch # 1, Time Step # 165, Loss Value = 8.62296199798584
# Epoch # 1, Time Step # 166, Loss Value = 8.586750984191895
# Epoch # 1, Time Step # 167, Loss Value = 8.635075569152832
# Epoch # 1, Time Step # 168, Loss Value = 8.602483749389648
# Epoch # 1, Time Step # 169, Loss Value = 8.658889770507812
# Epoch # 1, Time Step # 170, Loss Value = 8.669944763183594
# Epoch # 1, Time Step # 171, Loss Value = 8.669753074645996
# Epoch # 1, Time Step # 172, Loss Value = 8.679610252380371
# Epoch # 1, Time Step # 173, Loss Value = 8.655728340148926
# Epoch # 1, Time Step # 174, Loss Value = 8.666191101074219
# Epoch # 1, Time Step # 175, Loss Value = 8.621313095092773
# Epoch # 1, Time Step # 176, Loss Value = 8.597390174865723
# Epoch # 1, Time Step # 177, Loss Value = 8.61499309539795
# Epoch # 1, Time Step # 178, Loss Value = 8.595826148986816
# Epoch # 1, Time Step # 179, Loss Value = 8.57296371459961
# Epoch # 1, Time Step # 180, Loss Value = 8.64163589477539
# Epoch # 1, Time Step # 181, Loss Value = 8.603826522827148
# Epoch # 1, Time Step # 182, Loss Value = 8.601581573486328
# Epoch # 1, Time Step # 183, Loss Value = 8.613563537597656
# Epoch # 1, Time Step # 184, Loss Value = 8.608738899230957
# Epoch # 1, Time Step # 185, Loss Value = 8.613190650939941
# Epoch # 1, Time Step # 186, Loss Value = 8.57744312286377
# Epoch # 1, Time Step # 187, Loss Value = 8.701493263244629
# Epoch # 1, Time Step # 188, Loss Value = 8.624116897583008
# Epoch # 1, Time Step # 189, Loss Value = 8.648819923400879
# Epoch # 1, Time Step # 190, Loss Value = 8.622875213623047
# Epoch # 1, Time Step # 191, Loss Value = 8.646553039550781
# Epoch # 1, Time Step # 192, Loss Value = 8.658734321594238
# Epoch # 1, Time Step # 193, Loss Value = 8.61169719696045
# Epoch # 1, Time Step # 194, Loss Value = 8.622201919555664
# Epoch # 1, Time Step # 195, Loss Value = 8.60898494720459
# Epoch # 1, Time Step # 196, Loss Value = 8.639412879943848
# Epoch # 1, Time Step # 197, Loss Value = 8.628076553344727
# Epoch # 1, Time Step # 198, Loss Value = 8.492707252502441
# Epoch # 1, Time Step # 199, Loss Value = 8.66561222076416
# Epoch # 2, Time Step # 0, Loss Value = 8.60928726196289
# Epoch # 2, Time Step # 1, Loss Value = 8.674376487731934
# Epoch # 2, Time Step # 2, Loss Value = 8.678007125854492
# Epoch # 2, Time Step # 3, Loss Value = 8.65273666381836
# Epoch # 2, Time Step # 4, Loss Value = 8.661151885986328
# Epoch # 2, Time Step # 5, Loss Value = 8.64785099029541
# Epoch # 2, Time Step # 6, Loss Value = 8.672837257385254
# Epoch # 2, Time Step # 7, Loss Value = 8.634817123413086
# Epoch # 2, Time Step # 8, Loss Value = 8.677421569824219
# Epoch # 2, Time Step # 9, Loss Value = 8.658934593200684
# Epoch # 2, Time Step # 10, Loss Value = 8.687698364257812
# Epoch # 2, Time Step # 11, Loss Value = 8.665454864501953
# Epoch # 2, Time Step # 12, Loss Value = 8.65058422088623
# Epoch # 2, Time Step # 13, Loss Value = 8.67515754699707
# Epoch # 2, Time Step # 14, Loss Value = 8.65274715423584
# Epoch # 2, Time Step # 15, Loss Value = 8.666321754455566
# Epoch # 2, Time Step # 16, Loss Value = 8.669557571411133
# Epoch # 2, Time Step # 17, Loss Value = 8.688751220703125
# Epoch # 2, Time Step # 18, Loss Value = 8.664668083190918
# Epoch # 2, Time Step # 19, Loss Value = 8.679155349731445
# Epoch # 2, Time Step # 20, Loss Value = 8.685478210449219
# Epoch # 2, Time Step # 21, Loss Value = 8.66854476928711
# Epoch # 2, Time Step # 22, Loss Value = 8.713623046875
# Epoch # 2, Time Step # 23, Loss Value = 8.673505783081055
# Epoch # 2, Time Step # 24, Loss Value = 8.6782865524292
# Epoch # 2, Time Step # 25, Loss Value = 8.642003059387207
# Epoch # 2, Time Step # 26, Loss Value = 8.665964126586914
# Epoch # 2, Time Step # 27, Loss Value = 8.661256790161133
# Epoch # 2, Time Step # 28, Loss Value = 8.650676727294922
# Epoch # 2, Time Step # 29, Loss Value = 8.647022247314453
# Epoch # 2, Time Step # 30, Loss Value = 8.610400199890137
# Epoch # 2, Time Step # 31, Loss Value = 8.613234519958496
# Epoch # 2, Time Step # 32, Loss Value = 8.600136756896973
# Epoch # 2, Time Step # 33, Loss Value = 8.604763984680176
# Epoch # 2, Time Step # 34, Loss Value = 8.67355728149414
# Epoch # 2, Time Step # 35, Loss Value = 8.680068016052246
# Epoch # 2, Time Step # 36, Loss Value = 8.655780792236328
# Epoch # 2, Time Step # 37, Loss Value = 8.671899795532227
# Epoch # 2, Time Step # 38, Loss Value = 8.677018165588379
# Epoch # 2, Time Step # 39, Loss Value = 8.654964447021484
# Epoch # 2, Time Step # 40, Loss Value = 8.661883354187012
# Epoch # 2, Time Step # 41, Loss Value = 8.645380973815918
# Epoch # 2, Time Step # 42, Loss Value = 8.641379356384277
# Epoch # 2, Time Step # 43, Loss Value = 8.655669212341309
# Epoch # 2, Time Step # 44, Loss Value = 8.645844459533691
# Epoch # 2, Time Step # 45, Loss Value = 8.64251708984375
# Epoch # 2, Time Step # 46, Loss Value = 8.66246223449707
# Epoch # 2, Time Step # 47, Loss Value = 8.656176567077637
# Epoch # 2, Time Step # 48, Loss Value = 8.655035018920898
# Epoch # 2, Time Step # 49, Loss Value = 8.65656852722168
# Epoch # 2, Time Step # 50, Loss Value = 8.646268844604492
# Epoch # 2, Time Step # 51, Loss Value = 8.652953147888184
# Epoch # 2, Time Step # 52, Loss Value = 8.659496307373047
# Epoch # 2, Time Step # 53, Loss Value = 8.654627799987793
# Epoch # 2, Time Step # 54, Loss Value = 8.655280113220215
# Epoch # 2, Time Step # 55, Loss Value = 8.663376808166504
# Epoch # 2, Time Step # 56, Loss Value = 8.64677906036377
# Epoch # 2, Time Step # 57, Loss Value = 8.658655166625977
# Epoch # 2, Time Step # 58, Loss Value = 8.634452819824219
# Epoch # 2, Time Step # 59, Loss Value = 8.600152969360352
# Epoch # 2, Time Step # 60, Loss Value = 8.61794662475586
# Epoch # 2, Time Step # 61, Loss Value = 8.628564834594727
# Epoch # 2, Time Step # 62, Loss Value = 8.657018661499023
# Epoch # 2, Time Step # 63, Loss Value = 8.694029808044434
# Epoch # 2, Time Step # 64, Loss Value = 8.619547843933105
# Epoch # 2, Time Step # 65, Loss Value = 8.638163566589355
# Epoch # 2, Time Step # 66, Loss Value = 8.664397239685059
# Epoch # 2, Time Step # 67, Loss Value = 8.66335678100586
# Epoch # 2, Time Step # 68, Loss Value = 8.633038520812988
# Epoch # 2, Time Step # 69, Loss Value = 8.663569450378418
# Epoch # 2, Time Step # 70, Loss Value = 8.647517204284668
# Epoch # 2, Time Step # 71, Loss Value = 8.672825813293457
# Epoch # 2, Time Step # 72, Loss Value = 8.638959884643555
# Epoch # 2, Time Step # 73, Loss Value = 8.658369064331055
# Epoch # 2, Time Step # 74, Loss Value = 8.659439086914062
# Epoch # 2, Time Step # 75, Loss Value = 8.646859169006348
# Epoch # 2, Time Step # 76, Loss Value = 8.640088081359863
# Epoch # 2, Time Step # 77, Loss Value = 8.631291389465332
# Epoch # 2, Time Step # 78, Loss Value = 8.628138542175293
# Epoch # 2, Time Step # 79, Loss Value = 8.659608840942383
# Epoch # 2, Time Step # 80, Loss Value = 8.623217582702637
# Epoch # 2, Time Step # 81, Loss Value = 8.642817497253418
# Epoch # 2, Time Step # 82, Loss Value = 8.58337116241455
# Epoch # 2, Time Step # 83, Loss Value = 8.633493423461914
# Epoch # 2, Time Step # 84, Loss Value = 8.619637489318848
# Epoch # 2, Time Step # 85, Loss Value = 8.548733711242676
# Epoch # 2, Time Step # 86, Loss Value = 8.561636924743652
# Epoch # 2, Time Step # 87, Loss Value = 8.561209678649902
# Epoch # 2, Time Step # 88, Loss Value = 8.598039627075195
# Epoch # 2, Time Step # 89, Loss Value = 8.580016136169434
# Epoch # 2, Time Step # 90, Loss Value = 8.54212474822998
# Epoch # 2, Time Step # 91, Loss Value = 8.494549751281738
# Epoch # 2, Time Step # 92, Loss Value = 8.648307800292969
# Epoch # 2, Time Step # 93, Loss Value = 8.65545654296875
# Epoch # 2, Time Step # 94, Loss Value = 8.653149604797363
# Epoch # 2, Time Step # 95, Loss Value = 8.72011947631836
# Epoch # 2, Time Step # 96, Loss Value = 8.747414588928223
# Epoch # 2, Time Step # 97, Loss Value = 8.643843650817871
# Epoch # 2, Time Step # 98, Loss Value = 8.613483428955078
# Epoch # 2, Time Step # 99, Loss Value = 8.617073059082031
# Epoch # 2, Time Step # 100, Loss Value = 8.640156745910645
# Epoch # 2, Time Step # 101, Loss Value = 8.586064338684082
# Epoch # 2, Time Step # 102, Loss Value = 8.575738906860352
# Epoch # 2, Time Step # 103, Loss Value = 8.642101287841797
# Epoch # 2, Time Step # 104, Loss Value = 8.61539077758789
# Epoch # 2, Time Step # 105, Loss Value = 8.61678695678711
# Epoch # 2, Time Step # 106, Loss Value = 8.615949630737305
# Epoch # 2, Time Step # 107, Loss Value = 8.604854583740234
# Epoch # 2, Time Step # 108, Loss Value = 8.579805374145508
# Epoch # 2, Time Step # 109, Loss Value = 8.612173080444336
# Epoch # 2, Time Step # 110, Loss Value = 8.637033462524414
# Epoch # 2, Time Step # 111, Loss Value = 8.688454627990723
# Epoch # 2, Time Step # 112, Loss Value = 8.6736478805542
# Epoch # 2, Time Step # 113, Loss Value = 8.63666820526123
# Epoch # 2, Time Step # 114, Loss Value = 8.610583305358887
# Epoch # 2, Time Step # 115, Loss Value = 8.62890625
# Epoch # 2, Time Step # 116, Loss Value = 8.65202808380127
# Epoch # 2, Time Step # 117, Loss Value = 8.628745079040527
# Epoch # 2, Time Step # 118, Loss Value = 8.591625213623047
# Epoch # 2, Time Step # 119, Loss Value = 8.603965759277344
# Epoch # 2, Time Step # 120, Loss Value = 8.661255836486816
# Epoch # 2, Time Step # 121, Loss Value = 8.611245155334473
# Epoch # 2, Time Step # 122, Loss Value = 8.629810333251953
# Epoch # 2, Time Step # 123, Loss Value = 8.634281158447266
# Epoch # 2, Time Step # 124, Loss Value = 8.595850944519043
# Epoch # 2, Time Step # 125, Loss Value = 8.621686935424805
# Epoch # 2, Time Step # 126, Loss Value = 8.604995727539062
# Epoch # 2, Time Step # 127, Loss Value = 8.534514427185059
# Epoch # 2, Time Step # 128, Loss Value = 8.645209312438965
# Epoch # 2, Time Step # 129, Loss Value = 8.663116455078125
# Epoch # 2, Time Step # 130, Loss Value = 8.666815757751465
# Epoch # 2, Time Step # 131, Loss Value = 8.639079093933105
# Epoch # 2, Time Step # 132, Loss Value = 8.60784912109375
# Epoch # 2, Time Step # 133, Loss Value = 8.61380386352539
# Epoch # 2, Time Step # 134, Loss Value = 8.611180305480957
# Epoch # 2, Time Step # 135, Loss Value = 8.618895530700684
# Epoch # 2, Time Step # 136, Loss Value = 8.649256706237793
# Epoch # 2, Time Step # 137, Loss Value = 8.630305290222168
# Epoch # 2, Time Step # 138, Loss Value = 8.597801208496094
# Epoch # 2, Time Step # 139, Loss Value = 8.655715942382812
# Epoch # 2, Time Step # 140, Loss Value = 8.63323974609375
# Epoch # 2, Time Step # 141, Loss Value = 8.564343452453613
# Epoch # 2, Time Step # 142, Loss Value = 8.596622467041016
# Epoch # 2, Time Step # 143, Loss Value = 8.619423866271973
# Epoch # 2, Time Step # 144, Loss Value = 8.586106300354004
# Epoch # 2, Time Step # 145, Loss Value = 8.642075538635254
# Epoch # 2, Time Step # 146, Loss Value = 8.590075492858887
# Epoch # 2, Time Step # 147, Loss Value = 8.54390811920166
# Epoch # 2, Time Step # 148, Loss Value = 8.602794647216797
# Epoch # 2, Time Step # 149, Loss Value = 8.634665489196777
# Epoch # 2, Time Step # 150, Loss Value = 8.580780982971191
# Epoch # 2, Time Step # 151, Loss Value = 8.618677139282227
# Epoch # 2, Time Step # 152, Loss Value = 8.629476547241211
# Epoch # 2, Time Step # 153, Loss Value = 8.608003616333008
# Epoch # 2, Time Step # 154, Loss Value = 8.625345230102539
# Epoch # 2, Time Step # 155, Loss Value = 8.584524154663086
# Epoch # 2, Time Step # 156, Loss Value = 8.589117050170898
# Epoch # 2, Time Step # 157, Loss Value = 8.612187385559082
# Epoch # 2, Time Step # 158, Loss Value = 8.59601879119873
# Epoch # 2, Time Step # 159, Loss Value = 8.654149055480957
# Epoch # 2, Time Step # 160, Loss Value = 8.665326118469238
# Epoch # 2, Time Step # 161, Loss Value = 8.617932319641113
# Epoch # 2, Time Step # 162, Loss Value = 8.589141845703125
# Epoch # 2, Time Step # 163, Loss Value = 8.5714750289917
# Epoch # 2, Time Step # 164, Loss Value = 8.466024398803711
# Epoch # 2, Time Step # 165, Loss Value = 8.62270450592041
# Epoch # 2, Time Step # 166, Loss Value = 8.586447715759277
# Epoch # 2, Time Step # 167, Loss Value = 8.633764266967773
# Epoch # 2, Time Step # 168, Loss Value = 8.60227108001709
# Epoch # 2, Time Step # 169, Loss Value = 8.658695220947266
# Epoch # 2, Time Step # 170, Loss Value = 8.669815063476562
# Epoch # 2, Time Step # 171, Loss Value = 8.665894508361816
# Epoch # 2, Time Step # 172, Loss Value = 8.679384231567383
# Epoch # 2, Time Step # 173, Loss Value = 8.655488967895508
# Epoch # 2, Time Step # 174, Loss Value = 8.665885925292969
# Epoch # 2, Time Step # 175, Loss Value = 8.621115684509277
# Epoch # 2, Time Step # 176, Loss Value = 8.597126960754395
# Epoch # 2, Time Step # 177, Loss Value = 8.614794731140137
# Epoch # 2, Time Step # 178, Loss Value = 8.595630645751953
# Epoch # 2, Time Step # 179, Loss Value = 8.57275390625
# Epoch # 2, Time Step # 180, Loss Value = 8.641204833984375
# Epoch # 2, Time Step # 181, Loss Value = 8.603618621826172
# Epoch # 2, Time Step # 182, Loss Value = 8.601385116577148
# Epoch # 2, Time Step # 183, Loss Value = 8.613643646240234
# Epoch # 2, Time Step # 184, Loss Value = 8.608548164367676
# Epoch # 2, Time Step # 185, Loss Value = 8.612826347351074
# Epoch # 2, Time Step # 186, Loss Value = 8.577213287353516
# Epoch # 2, Time Step # 187, Loss Value = 8.70128345489502
# Epoch # 2, Time Step # 188, Loss Value = 8.623416900634766
# Epoch # 2, Time Step # 189, Loss Value = 8.648640632629395
# Epoch # 2, Time Step # 190, Loss Value = 8.622721672058105
# Epoch # 2, Time Step # 191, Loss Value = 8.646425247192383
# Epoch # 2, Time Step # 192, Loss Value = 8.658614158630371
# Epoch # 2, Time Step # 193, Loss Value = 8.61148452758789
# Epoch # 2, Time Step # 194, Loss Value = 8.622055053710938
# Epoch # 2, Time Step # 195, Loss Value = 8.60876178741455
# Epoch # 2, Time Step # 196, Loss Value = 8.639290809631348
# Epoch # 2, Time Step # 197, Loss Value = 8.62662410736084
# Epoch # 2, Time Step # 198, Loss Value = 8.486486434936523
# Epoch # 2, Time Step # 199, Loss Value = 8.665502548217773
# Epoch # 3, Time Step # 0, Loss Value = 8.609099388122559
# Epoch # 3, Time Step # 1, Loss Value = 8.673697471618652
# Epoch # 3, Time Step # 2, Loss Value = 8.677888870239258
# Epoch # 3, Time Step # 3, Loss Value = 8.652454376220703
# Epoch # 3, Time Step # 4, Loss Value = 8.66096305847168
# Epoch # 3, Time Step # 5, Loss Value = 8.646662712097168
# Epoch # 3, Time Step # 6, Loss Value = 8.672714233398438
# Epoch # 3, Time Step # 7, Loss Value = 8.634671211242676
# Epoch # 3, Time Step # 8, Loss Value = 8.67733383178711
# Epoch # 3, Time Step # 9, Loss Value = 8.658802032470703
# Epoch # 3, Time Step # 10, Loss Value = 8.687525749206543
# Epoch # 3, Time Step # 11, Loss Value = 8.664726257324219
# Epoch # 3, Time Step # 12, Loss Value = 8.650480270385742
# Epoch # 3, Time Step # 13, Loss Value = 8.674964904785156
# Epoch # 3, Time Step # 14, Loss Value = 8.652632713317871
# Epoch # 3, Time Step # 15, Loss Value = 8.66617202758789
# Epoch # 3, Time Step # 16, Loss Value = 8.668144226074219
# Epoch # 3, Time Step # 17, Loss Value = 8.688667297363281
# Epoch # 3, Time Step # 18, Loss Value = 8.664581298828125
# Epoch # 3, Time Step # 19, Loss Value = 8.67894458770752
# Epoch # 3, Time Step # 20, Loss Value = 8.685389518737793
# Epoch # 3, Time Step # 21, Loss Value = 8.668429374694824
# Epoch # 3, Time Step # 22, Loss Value = 8.713485717773438
# Epoch # 3, Time Step # 23, Loss Value = 8.67297649383545
# Epoch # 3, Time Step # 24, Loss Value = 8.677215576171875
# Epoch # 3, Time Step # 25, Loss Value = 8.641880989074707
# Epoch # 3, Time Step # 26, Loss Value = 8.664644241333008
# Epoch # 3, Time Step # 27, Loss Value = 8.65723705291748
# Epoch # 3, Time Step # 28, Loss Value = 8.649675369262695
# Epoch # 3, Time Step # 29, Loss Value = 8.646929740905762
# Epoch # 3, Time Step # 30, Loss Value = 8.610258102416992
# Epoch # 3, Time Step # 31, Loss Value = 8.613091468811035
# Epoch # 3, Time Step # 32, Loss Value = 8.599339485168457
# Epoch # 3, Time Step # 33, Loss Value = 8.604619979858398
# Epoch # 3, Time Step # 34, Loss Value = 8.673468589782715
# Epoch # 3, Time Step # 35, Loss Value = 8.679960250854492
# Epoch # 3, Time Step # 36, Loss Value = 8.65462875366211
# Epoch # 3, Time Step # 37, Loss Value = 8.671730041503906
# Epoch # 3, Time Step # 38, Loss Value = 8.67601203918457
# Epoch # 3, Time Step # 39, Loss Value = 8.654873847961426
# Epoch # 3, Time Step # 40, Loss Value = 8.661806106567383
# Epoch # 3, Time Step # 41, Loss Value = 8.645295143127441
# Epoch # 3, Time Step # 42, Loss Value = 8.641274452209473
# Epoch # 3, Time Step # 43, Loss Value = 8.655435562133789
# Epoch # 3, Time Step # 44, Loss Value = 8.645761489868164
# Epoch # 3, Time Step # 45, Loss Value = 8.642422676086426
# Epoch # 3, Time Step # 46, Loss Value = 8.662368774414062
# Epoch # 3, Time Step # 47, Loss Value = 8.656105041503906
# Epoch # 3, Time Step # 48, Loss Value = 8.654946327209473
# Epoch # 3, Time Step # 49, Loss Value = 8.65638256072998
# Epoch # 3, Time Step # 50, Loss Value = 8.646187782287598
# Epoch # 3, Time Step # 51, Loss Value = 8.652870178222656
# Epoch # 3, Time Step # 52, Loss Value = 8.659412384033203
# Epoch # 3, Time Step # 53, Loss Value = 8.653768539428711
# Epoch # 3, Time Step # 54, Loss Value = 8.65517807006836
# Epoch # 3, Time Step # 55, Loss Value = 8.662635803222656
# Epoch # 3, Time Step # 56, Loss Value = 8.646648406982422
# Epoch # 3, Time Step # 57, Loss Value = 8.65842342376709
# Epoch # 3, Time Step # 58, Loss Value = 8.633758544921875
# Epoch # 3, Time Step # 59, Loss Value = 8.599592208862305
# Epoch # 3, Time Step # 60, Loss Value = 8.617820739746094
# Epoch # 3, Time Step # 61, Loss Value = 8.62798023223877
# Epoch # 3, Time Step # 62, Loss Value = 8.656425476074219
# Epoch # 3, Time Step # 63, Loss Value = 8.69395923614502
# Epoch # 3, Time Step # 64, Loss Value = 8.619447708129883
# Epoch # 3, Time Step # 65, Loss Value = 8.638052940368652
# Epoch # 3, Time Step # 66, Loss Value = 8.664275169372559
# Epoch # 3, Time Step # 67, Loss Value = 8.663286209106445
# Epoch # 3, Time Step # 68, Loss Value = 8.632502555847168
# Epoch # 3, Time Step # 69, Loss Value = 8.663108825683594
# Epoch # 3, Time Step # 70, Loss Value = 8.647372245788574
# Epoch # 3, Time Step # 71, Loss Value = 8.672746658325195
# Epoch # 3, Time Step # 72, Loss Value = 8.638846397399902
# Epoch # 3, Time Step # 73, Loss Value = 8.658275604248047
# Epoch # 3, Time Step # 74, Loss Value = 8.659342765808105
# Epoch # 3, Time Step # 75, Loss Value = 8.646784782409668
# Epoch # 3, Time Step # 76, Loss Value = 8.639970779418945
# Epoch # 3, Time Step # 77, Loss Value = 8.6310453414917
# Epoch # 3, Time Step # 78, Loss Value = 8.628019332885742
# Epoch # 3, Time Step # 79, Loss Value = 8.659538269042969
# Epoch # 3, Time Step # 80, Loss Value = 8.623095512390137
# Epoch # 3, Time Step # 81, Loss Value = 8.642843246459961
# Epoch # 3, Time Step # 82, Loss Value = 8.583280563354492
# Epoch # 3, Time Step # 83, Loss Value = 8.63337230682373
# Epoch # 3, Time Step # 84, Loss Value = 8.619522094726562
# Epoch # 3, Time Step # 85, Loss Value = 8.548622131347656
# Epoch # 3, Time Step # 86, Loss Value = 8.561534881591797
# Epoch # 3, Time Step # 87, Loss Value = 8.561144828796387
# Epoch # 3, Time Step # 88, Loss Value = 8.597953796386719
# Epoch # 3, Time Step # 89, Loss Value = 8.579899787902832
# Epoch # 3, Time Step # 90, Loss Value = 8.542013168334961
# Epoch # 3, Time Step # 91, Loss Value = 8.494424819946289
# Epoch # 3, Time Step # 92, Loss Value = 8.646917343139648
# Epoch # 3, Time Step # 93, Loss Value = 8.65538215637207
# Epoch # 3, Time Step # 94, Loss Value = 8.653082847595215
# Epoch # 3, Time Step # 95, Loss Value = 8.72006893157959
# Epoch # 3, Time Step # 96, Loss Value = 8.747376441955566
# Epoch # 3, Time Step # 97, Loss Value = 8.643552780151367
# Epoch # 3, Time Step # 98, Loss Value = 8.613348960876465
# Epoch # 3, Time Step # 99, Loss Value = 8.615466117858887
# Epoch # 3, Time Step # 100, Loss Value = 8.640071868896484
# Epoch # 3, Time Step # 101, Loss Value = 8.585984230041504
# Epoch # 3, Time Step # 102, Loss Value = 8.575642585754395
# Epoch # 3, Time Step # 103, Loss Value = 8.641986846923828
# Epoch # 3, Time Step # 104, Loss Value = 8.61528491973877
# Epoch # 3, Time Step # 105, Loss Value = 8.614459991455078
# Epoch # 3, Time Step # 106, Loss Value = 8.615679740905762
# Epoch # 3, Time Step # 107, Loss Value = 8.604763984680176
# Epoch # 3, Time Step # 108, Loss Value = 8.578492164611816
# Epoch # 3, Time Step # 109, Loss Value = 8.61209487915039
# Epoch # 3, Time Step # 110, Loss Value = 8.636951446533203
# Epoch # 3, Time Step # 111, Loss Value = 8.688400268554688
# Epoch # 3, Time Step # 112, Loss Value = 8.673593521118164
# Epoch # 3, Time Step # 113, Loss Value = 8.636598587036133
# Epoch # 3, Time Step # 114, Loss Value = 8.61050033569336
# Epoch # 3, Time Step # 115, Loss Value = 8.628705978393555
# Epoch # 3, Time Step # 116, Loss Value = 8.651959419250488
# Epoch # 3, Time Step # 117, Loss Value = 8.62864875793457
# Epoch # 3, Time Step # 118, Loss Value = 8.591541290283203
# Epoch # 3, Time Step # 119, Loss Value = 8.60378360748291
# Epoch # 3, Time Step # 120, Loss Value = 8.661062240600586
# Epoch # 3, Time Step # 121, Loss Value = 8.611152648925781
# Epoch # 3, Time Step # 122, Loss Value = 8.629714012145996
# Epoch # 3, Time Step # 123, Loss Value = 8.634202003479004
# Epoch # 3, Time Step # 124, Loss Value = 8.595454216003418
# Epoch # 3, Time Step # 125, Loss Value = 8.621525764465332
# Epoch # 3, Time Step # 126, Loss Value = 8.604921340942383
# Epoch # 3, Time Step # 127, Loss Value = 8.534363746643066
# Epoch # 3, Time Step # 128, Loss Value = 8.645120620727539
# Epoch # 3, Time Step # 129, Loss Value = 8.6626558303833
# Epoch # 3, Time Step # 130, Loss Value = 8.666749954223633
# Epoch # 3, Time Step # 131, Loss Value = 8.639004707336426
# Epoch # 3, Time Step # 132, Loss Value = 8.607782363891602
# Epoch # 3, Time Step # 133, Loss Value = 8.613739967346191
# Epoch # 3, Time Step # 134, Loss Value = 8.611013412475586
# Epoch # 3, Time Step # 135, Loss Value = 8.618817329406738
# Epoch # 3, Time Step # 136, Loss Value = 8.649205207824707
# Epoch # 3, Time Step # 137, Loss Value = 8.62997055053711
# Epoch # 3, Time Step # 138, Loss Value = 8.59773063659668
# Epoch # 3, Time Step # 139, Loss Value = 8.655624389648438
# Epoch # 3, Time Step # 140, Loss Value = 8.6331205368042
# Epoch # 3, Time Step # 141, Loss Value = 8.564261436462402
# Epoch # 3, Time Step # 142, Loss Value = 8.596550941467285
# Epoch # 3, Time Step # 143, Loss Value = 8.619348526000977
# Epoch # 3, Time Step # 144, Loss Value = 8.58602523803711
# Epoch # 3, Time Step # 145, Loss Value = 8.642013549804688
# Epoch # 3, Time Step # 146, Loss Value = 8.587638854980469
# Epoch # 3, Time Step # 147, Loss Value = 8.542396545410156
# Epoch # 3, Time Step # 148, Loss Value = 8.602510452270508
# Epoch # 3, Time Step # 149, Loss Value = 8.634603500366211
# Epoch # 3, Time Step # 150, Loss Value = 8.580704689025879
# Epoch # 3, Time Step # 151, Loss Value = 8.618608474731445
# Epoch # 3, Time Step # 152, Loss Value = 8.62940502166748
# Epoch # 3, Time Step # 153, Loss Value = 8.60792350769043
# Epoch # 3, Time Step # 154, Loss Value = 8.625417709350586
# Epoch # 3, Time Step # 155, Loss Value = 8.584444046020508
# Epoch # 3, Time Step # 156, Loss Value = 8.58903694152832
# Epoch # 3, Time Step # 157, Loss Value = 8.612113952636719
# Epoch # 3, Time Step # 158, Loss Value = 8.59593391418457
# Epoch # 3, Time Step # 159, Loss Value = 8.654064178466797
# Epoch # 3, Time Step # 160, Loss Value = 8.665275573730469
# Epoch # 3, Time Step # 161, Loss Value = 8.617809295654297
# Epoch # 3, Time Step # 162, Loss Value = 8.588932037353516
# Epoch # 3, Time Step # 163, Loss Value = 8.571375846862793
# Epoch # 3, Time Step # 164, Loss Value = 8.465909004211426
# Epoch # 3, Time Step # 165, Loss Value = 8.622806549072266
# Epoch # 3, Time Step # 166, Loss Value = 8.586366653442383
# Epoch # 3, Time Step # 167, Loss Value = 8.633630752563477
# Epoch # 3, Time Step # 168, Loss Value = 8.602197647094727
# Epoch # 3, Time Step # 169, Loss Value = 8.658634185791016
# Epoch # 3, Time Step # 170, Loss Value = 8.669767379760742
# Epoch # 3, Time Step # 171, Loss Value = 8.66551685333252
# Epoch # 3, Time Step # 172, Loss Value = 8.679265022277832
# Epoch # 3, Time Step # 173, Loss Value = 8.655430793762207
# Epoch # 3, Time Step # 174, Loss Value = 8.665816307067871
# Epoch # 3, Time Step # 175, Loss Value = 8.62104606628418
# Epoch # 3, Time Step # 176, Loss Value = 8.597053527832031
# Epoch # 3, Time Step # 177, Loss Value = 8.614725112915039
# Epoch # 3, Time Step # 178, Loss Value = 8.595561981201172
# Epoch # 3, Time Step # 179, Loss Value = 8.572685241699219
# Epoch # 3, Time Step # 180, Loss Value = 8.641034126281738
# Epoch # 3, Time Step # 181, Loss Value = 8.603545188903809
# Epoch # 3, Time Step # 182, Loss Value = 8.60131549835205
# Epoch # 3, Time Step # 183, Loss Value = 8.613489151000977
# Epoch # 3, Time Step # 184, Loss Value = 8.608478546142578
# Epoch # 3, Time Step # 185, Loss Value = 8.612749099731445
# Epoch # 3, Time Step # 186, Loss Value = 8.57712173461914
# Epoch # 3, Time Step # 187, Loss Value = 8.701234817504883
# Epoch # 3, Time Step # 188, Loss Value = 8.620861053466797
# Epoch # 3, Time Step # 189, Loss Value = 8.648581504821777
# Epoch # 3, Time Step # 190, Loss Value = 8.622658729553223
# Epoch # 3, Time Step # 191, Loss Value = 8.646369934082031
# Epoch # 3, Time Step # 192, Loss Value = 8.658563613891602
# Epoch # 3, Time Step # 193, Loss Value = 8.611403465270996
# Epoch # 3, Time Step # 194, Loss Value = 8.621993064880371
# Epoch # 3, Time Step # 195, Loss Value = 8.608704566955566
# Epoch # 3, Time Step # 196, Loss Value = 8.638636589050293
# Epoch # 3, Time Step # 197, Loss Value = 8.62600040435791
# Epoch # 3, Time Step # 198, Loss Value = 8.48614501953125
# Epoch # 3, Time Step # 199, Loss Value = 8.665458679199219
# Epoch # 4, Time Step # 0, Loss Value = 8.609025955200195
# Epoch # 4, Time Step # 1, Loss Value = 8.672578811645508
# Epoch # 4, Time Step # 2, Loss Value = 8.677841186523438
# Epoch # 4, Time Step # 3, Loss Value = 8.652353286743164
# Epoch # 4, Time Step # 4, Loss Value = 8.660735130310059
# Epoch # 4, Time Step # 5, Loss Value = 8.64653491973877
# Epoch # 4, Time Step # 6, Loss Value = 8.672662734985352
# Epoch # 4, Time Step # 7, Loss Value = 8.634614944458008
# Epoch # 4, Time Step # 8, Loss Value = 8.677294731140137
# Epoch # 4, Time Step # 9, Loss Value = 8.658129692077637
# Epoch # 4, Time Step # 10, Loss Value = 8.68610668182373
# Epoch # 4, Time Step # 11, Loss Value = 8.663775444030762
# Epoch # 4, Time Step # 12, Loss Value = 8.650432586669922
# Epoch # 4, Time Step # 13, Loss Value = 8.674641609191895
# Epoch # 4, Time Step # 14, Loss Value = 8.652583122253418
# Epoch # 4, Time Step # 15, Loss Value = 8.665205955505371
# Epoch # 4, Time Step # 16, Loss Value = 8.66807746887207
# Epoch # 4, Time Step # 17, Loss Value = 8.688631057739258
# Epoch # 4, Time Step # 18, Loss Value = 8.664544105529785
# Epoch # 4, Time Step # 19, Loss Value = 8.678901672363281
# Epoch # 4, Time Step # 20, Loss Value = 8.685365676879883
# Epoch # 4, Time Step # 21, Loss Value = 8.668366432189941
# Epoch # 4, Time Step # 22, Loss Value = 8.713425636291504
# Epoch # 4, Time Step # 23, Loss Value = 8.672886848449707
# Epoch # 4, Time Step # 24, Loss Value = 8.677712440490723
# ...
# Epoch # 23, Time Step # 131, Loss Value = 8.600111961364746
# Epoch # 23, Time Step # 132, Loss Value = 8.55078411102295
# Epoch # 23, Time Step # 133, Loss Value = 8.580558776855469
# Epoch # 23, Time Step # 134, Loss Value = 8.534855842590332
# Epoch # 23, Time Step # 135, Loss Value = 8.576220512390137
# Epoch # 23, Time Step # 136, Loss Value = 8.61514949798584
# Epoch # 23, Time Step # 137, Loss Value = 8.608565330505371
# Epoch # 23, Time Step # 138, Loss Value = 8.540050506591797
# Epoch # 23, Time Step # 139, Loss Value = 8.61538028717041
# Epoch # 23, Time Step # 140, Loss Value = 8.584644317626953
# Epoch # 23, Time Step # 141, Loss Value = 8.506471633911133
# Epoch # 23, Time Step # 142, Loss Value = 8.571855545043945
# Epoch # 23, Time Step # 143, Loss Value = 8.544010162353516
# Epoch # 23, Time Step # 144, Loss Value = 8.520970344543457
# Epoch # 23, Time Step # 145, Loss Value = 8.5872220993042
# Epoch # 23, Time Step # 146, Loss Value = 8.558674812316895
# Epoch # 23, Time Step # 147, Loss Value = 8.508872032165527
# Epoch # 23, Time Step # 148, Loss Value = 8.504311561584473
# Epoch # 23, Time Step # 149, Loss Value = 8.547293663024902
# Epoch # 23, Time Step # 150, Loss Value = 8.525482177734375
# Epoch # 23, Time Step # 151, Loss Value = 8.56789779663086
# Epoch # 23, Time Step # 152, Loss Value = 8.59382438659668
# Epoch # 23, Time Step # 153, Loss Value = 8.568818092346191
# Epoch # 23, Time Step # 154, Loss Value = 8.553451538085938
# Epoch # 23, Time Step # 155, Loss Value = 8.538389205932617
# Epoch # 23, Time Step # 156, Loss Value = 8.502610206604004
# Epoch # 23, Time Step # 157, Loss Value = 8.549283981323242
# Epoch # 23, Time Step # 158, Loss Value = 8.53118896484375
# Epoch # 23, Time Step # 159, Loss Value = 8.60977554321289
# Epoch # 23, Time Step # 160, Loss Value = 8.596799850463867
# Epoch # 23, Time Step # 161, Loss Value = 8.583906173706055
# Epoch # 23, Time Step # 162, Loss Value = 8.573960304260254
# Epoch # 23, Time Step # 163, Loss Value = 8.525527000427246
# Epoch # 23, Time Step # 164, Loss Value = 8.469259262084961
# Epoch # 23, Time Step # 165, Loss Value = 8.544304847717285
# Epoch # 23, Time Step # 166, Loss Value = 8.518754959106445
# Epoch # 23, Time Step # 167, Loss Value = 8.586917877197266
# Epoch # 23, Time Step # 168, Loss Value = 8.548620223999023
# Epoch # 23, Time Step # 169, Loss Value = 8.599263191223145
# Epoch # 23, Time Step # 170, Loss Value = 8.601567268371582
# Epoch # 23, Time Step # 171, Loss Value = 8.60268783569336
# Epoch # 23, Time Step # 172, Loss Value = 8.634568214416504
# Epoch # 23, Time Step # 173, Loss Value = 8.607977867126465
# Epoch # 23, Time Step # 174, Loss Value = 8.607043266296387
# Epoch # 23, Time Step # 175, Loss Value = 8.567248344421387
# Epoch # 23, Time Step # 176, Loss Value = 8.543898582458496
# Epoch # 23, Time Step # 177, Loss Value = 8.56812858581543
# Epoch # 23, Time Step # 178, Loss Value = 8.539698600769043
# Epoch # 23, Time Step # 179, Loss Value = 8.474617004394531
# Epoch # 23, Time Step # 180, Loss Value = 8.601649284362793
# Epoch # 23, Time Step # 181, Loss Value = 8.545412063598633
# Epoch # 23, Time Step # 182, Loss Value = 8.545463562011719
# Epoch # 23, Time Step # 183, Loss Value = 8.546379089355469
# Epoch # 23, Time Step # 184, Loss Value = 8.559540748596191
# Epoch # 23, Time Step # 185, Loss Value = 8.555895805358887
# Epoch # 23, Time Step # 186, Loss Value = 8.526223182678223
# Epoch # 23, Time Step # 187, Loss Value = 8.661776542663574
# Epoch # 23, Time Step # 188, Loss Value = 8.558494567871094
# Epoch # 23, Time Step # 189, Loss Value = 8.606006622314453
# Epoch # 23, Time Step # 190, Loss Value = 8.567207336425781
# Epoch # 23, Time Step # 191, Loss Value = 8.609481811523438
# Epoch # 23, Time Step # 192, Loss Value = 8.605088233947754
# Epoch # 23, Time Step # 193, Loss Value = 8.527904510498047
# Epoch # 23, Time Step # 194, Loss Value = 8.569514274597168
# Epoch # 23, Time Step # 195, Loss Value = 8.533180236816406
# Epoch # 23, Time Step # 196, Loss Value = 8.576681137084961
# Epoch # 23, Time Step # 197, Loss Value = 8.582315444946289
# Epoch # 23, Time Step # 198, Loss Value = 8.476541519165039
# Epoch # 23, Time Step # 199, Loss Value = 8.615532875061035
# Epoch # 24, Time Step # 0, Loss Value = 8.556059837341309
# Epoch # 24, Time Step # 1, Loss Value = 8.633868217468262
# Epoch # 24, Time Step # 2, Loss Value = 8.643393516540527
# Epoch # 24, Time Step # 3, Loss Value = 8.611680030822754
# Epoch # 24, Time Step # 4, Loss Value = 8.615480422973633
# Epoch # 24, Time Step # 5, Loss Value = 8.600071907043457
# Epoch # 24, Time Step # 6, Loss Value = 8.622905731201172
# Epoch # 24, Time Step # 7, Loss Value = 8.591080665588379
# Epoch # 24, Time Step # 8, Loss Value = 8.622249603271484
# Epoch # 24, Time Step # 9, Loss Value = 8.600038528442383
# Epoch # 24, Time Step # 10, Loss Value = 8.636656761169434
# Epoch # 24, Time Step # 11, Loss Value = 8.614836692810059
# Epoch # 24, Time Step # 12, Loss Value = 8.573223114013672
# Epoch # 24, Time Step # 13, Loss Value = 8.614213943481445
# Epoch # 24, Time Step # 14, Loss Value = 8.608868598937988
# Epoch # 24, Time Step # 15, Loss Value = 8.615621566772461
# Epoch # 24, Time Step # 16, Loss Value = 8.598591804504395
# Epoch # 24, Time Step # 17, Loss Value = 8.616886138916016
# Epoch # 24, Time Step # 18, Loss Value = 8.58896541595459
# Epoch # 24, Time Step # 19, Loss Value = 8.624582290649414
# Epoch # 24, Time Step # 20, Loss Value = 8.636103630065918
# Epoch # 24, Time Step # 21, Loss Value = 8.60527229309082
# Epoch # 24, Time Step # 22, Loss Value = 8.662764549255371
# Epoch # 24, Time Step # 23, Loss Value = 8.627724647521973
# Epoch # 24, Time Step # 24, Loss Value = 8.641254425048828
# Epoch # 24, Time Step # 25, Loss Value = 8.597978591918945
# Epoch # 24, Time Step # 26, Loss Value = 8.622111320495605
# Epoch # 24, Time Step # 27, Loss Value = 8.612825393676758
# Epoch # 24, Time Step # 28, Loss Value = 8.608044624328613
# Epoch # 24, Time Step # 29, Loss Value = 8.574045181274414
# Epoch # 24, Time Step # 30, Loss Value = 8.570083618164062
# Epoch # 24, Time Step # 31, Loss Value = 8.575883865356445
# Epoch # 24, Time Step # 32, Loss Value = 8.56609058380127
# Epoch # 24, Time Step # 33, Loss Value = 8.576988220214844
# Epoch # 24, Time Step # 34, Loss Value = 8.635331153869629
# Epoch # 24, Time Step # 35, Loss Value = 8.637297630310059
# Epoch # 24, Time Step # 36, Loss Value = 8.597848892211914
# Epoch # 24, Time Step # 37, Loss Value = 8.612687110900879
# Epoch # 24, Time Step # 38, Loss Value = 8.617894172668457
# Epoch # 24, Time Step # 39, Loss Value = 8.604877471923828
# Epoch # 24, Time Step # 40, Loss Value = 8.611385345458984
# Epoch # 24, Time Step # 41, Loss Value = 8.592642784118652
# Epoch # 24, Time Step # 42, Loss Value = 8.58519458770752
# Epoch # 24, Time Step # 43, Loss Value = 8.600240707397461
# Epoch # 24, Time Step # 44, Loss Value = 8.603075981140137
# Epoch # 24, Time Step # 45, Loss Value = 8.592938423156738
# Epoch # 24, Time Step # 46, Loss Value = 8.622194290161133
# Epoch # 24, Time Step # 47, Loss Value = 8.593683242797852
# Epoch # 24, Time Step # 48, Loss Value = 8.618082046508789
# Epoch # 24, Time Step # 49, Loss Value = 8.605902671813965
# Epoch # 24, Time Step # 50, Loss Value = 8.589422225952148
# Epoch # 24, Time Step # 51, Loss Value = 8.592255592346191
# Epoch # 24, Time Step # 52, Loss Value = 8.618403434753418
# Epoch # 24, Time Step # 53, Loss Value = 8.595760345458984
# Epoch # 24, Time Step # 54, Loss Value = 8.609662055969238
# Epoch # 24, Time Step # 55, Loss Value = 8.601865768432617
# Epoch # 24, Time Step # 56, Loss Value = 8.593303680419922
# Epoch # 24, Time Step # 57, Loss Value = 8.616211891174316
# Epoch # 24, Time Step # 58, Loss Value = 8.58922290802002
# Epoch # 24, Time Step # 59, Loss Value = 8.54243278503418
# Epoch # 24, Time Step # 60, Loss Value = 8.591410636901855
# Epoch # 24, Time Step # 61, Loss Value = 8.555718421936035
# Epoch # 24, Time Step # 62, Loss Value = 8.591275215148926
# Epoch # 24, Time Step # 63, Loss Value = 8.637194633483887
# Epoch # 24, Time Step # 64, Loss Value = 8.565695762634277
# Epoch # 24, Time Step # 65, Loss Value = 8.593989372253418
# Epoch # 24, Time Step # 66, Loss Value = 8.606563568115234
# Epoch # 24, Time Step # 67, Loss Value = 8.603621482849121
# Epoch # 24, Time Step # 68, Loss Value = 8.596297264099121
# Epoch # 24, Time Step # 69, Loss Value = 8.634651184082031
# Epoch # 24, Time Step # 70, Loss Value = 8.581467628479004
# Epoch # 24, Time Step # 71, Loss Value = 8.604692459106445
# Epoch # 24, Time Step # 72, Loss Value = 8.61346435546875
# Epoch # 24, Time Step # 73, Loss Value = 8.58984661102295
# Epoch # 24, Time Step # 74, Loss Value = 8.600598335266113
# Epoch # 24, Time Step # 75, Loss Value = 8.582194328308105
# Epoch # 24, Time Step # 76, Loss Value = 8.60266399383545
# Epoch # 24, Time Step # 77, Loss Value = 8.595208168029785
# Epoch # 24, Time Step # 78, Loss Value = 8.571436882019043
# Epoch # 24, Time Step # 79, Loss Value = 8.574692726135254
# Epoch # 24, Time Step # 80, Loss Value = 8.582680702209473
# Epoch # 24, Time Step # 81, Loss Value = 8.60418701171875
# Epoch # 24, Time Step # 82, Loss Value = 8.553511619567871
# Epoch # 24, Time Step # 83, Loss Value = 8.604718208312988
# Epoch # 24, Time Step # 84, Loss Value = 8.561281204223633
# Epoch # 24, Time Step # 85, Loss Value = 8.523039817810059
# Epoch # 24, Time Step # 86, Loss Value = 8.525971412658691
# Epoch # 24, Time Step # 87, Loss Value = 8.515303611755371
# Epoch # 24, Time Step # 88, Loss Value = 8.557024955749512
# Epoch # 24, Time Step # 89, Loss Value = 8.5467529296875
# Epoch # 24, Time Step # 90, Loss Value = 8.504180908203125
# Epoch # 24, Time Step # 91, Loss Value = 8.448131561279297
# Epoch # 24, Time Step # 92, Loss Value = 8.608213424682617
# Epoch # 24, Time Step # 93, Loss Value = 8.566118240356445
# Epoch # 24, Time Step # 94, Loss Value = 8.57784652709961
# Epoch # 24, Time Step # 95, Loss Value = 8.678678512573242
# Epoch # 24, Time Step # 96, Loss Value = 8.688518524169922
# Epoch # 24, Time Step # 97, Loss Value = 8.602375030517578
# Epoch # 24, Time Step # 98, Loss Value = 8.532835006713867
# Epoch # 24, Time Step # 99, Loss Value = 8.5591402053833
# Epoch # 24, Time Step # 100, Loss Value = 8.580269813537598
# Epoch # 24, Time Step # 101, Loss Value = 8.530320167541504
# Epoch # 24, Time Step # 102, Loss Value = 8.520843505859375
# Epoch # 24, Time Step # 103, Loss Value = 8.609846115112305
# Epoch # 24, Time Step # 104, Loss Value = 8.583185195922852
# Epoch # 24, Time Step # 105, Loss Value = 8.567193031311035
# Epoch # 24, Time Step # 106, Loss Value = 8.578035354614258
# Epoch # 24, Time Step # 107, Loss Value = 8.539093017578125
# Epoch # 24, Time Step # 108, Loss Value = 8.513501167297363
# Epoch # 24, Time Step # 109, Loss Value = 8.50253963470459
# Epoch # 24, Time Step # 110, Loss Value = 8.582219123840332
# Epoch # 24, Time Step # 111, Loss Value = 8.594571113586426
# Epoch # 24, Time Step # 112, Loss Value = 8.610756874084473
# Epoch # 24, Time Step # 113, Loss Value = 8.562216758728027
# Epoch # 24, Time Step # 114, Loss Value = 8.557984352111816
# Epoch # 24, Time Step # 115, Loss Value = 8.560137748718262
# Epoch # 24, Time Step # 116, Loss Value = 8.612847328186035
# Epoch # 24, Time Step # 117, Loss Value = 8.579853057861328
# Epoch # 24, Time Step # 118, Loss Value = 8.51083755493164
# Epoch # 24, Time Step # 119, Loss Value = 8.503241539001465
# Epoch # 24, Time Step # 120, Loss Value = 8.597439765930176
# Epoch # 24, Time Step # 121, Loss Value = 8.543535232543945
# Epoch # 24, Time Step # 122, Loss Value = 8.567657470703125
# Epoch # 24, Time Step # 123, Loss Value = 8.566091537475586
# Epoch # 24, Time Step # 124, Loss Value = 8.519563674926758
# Epoch # 24, Time Step # 125, Loss Value = 8.562413215637207
# Epoch # 24, Time Step # 126, Loss Value = 8.524709701538086
# Epoch # 24, Time Step # 127, Loss Value = 8.504541397094727
# Epoch # 24, Time Step # 128, Loss Value = 8.582215309143066
# Epoch # 24, Time Step # 129, Loss Value = 8.603370666503906
# Epoch # 24, Time Step # 130, Loss Value = 8.608698844909668
# Epoch # 24, Time Step # 131, Loss Value = 8.589951515197754
# Epoch # 24, Time Step # 132, Loss Value = 8.547211647033691
# Epoch # 24, Time Step # 133, Loss Value = 8.572126388549805
# Epoch # 24, Time Step # 134, Loss Value = 8.531991004943848
# Epoch # 24, Time Step # 135, Loss Value = 8.56399154663086
# Epoch # 24, Time Step # 136, Loss Value = 8.612288475036621
# Epoch # 24, Time Step # 137, Loss Value = 8.608163833618164
# Epoch # 24, Time Step # 138, Loss Value = 8.538915634155273
# Epoch # 24, Time Step # 139, Loss Value = 8.614710807800293
# Epoch # 24, Time Step # 140, Loss Value = 8.586684226989746
# Epoch # 24, Time Step # 141, Loss Value = 8.496105194091797
# Epoch # 24, Time Step # 142, Loss Value = 8.570667266845703
# Epoch # 24, Time Step # 143, Loss Value = 8.535748481750488
# Epoch # 24, Time Step # 144, Loss Value = 8.518763542175293
# Epoch # 24, Time Step # 145, Loss Value = 8.586953163146973
# Epoch # 24, Time Step # 146, Loss Value = 8.557015419006348
# Epoch # 24, Time Step # 147, Loss Value = 8.510496139526367
# Epoch # 24, Time Step # 148, Loss Value = 8.498427391052246
# Epoch # 24, Time Step # 149, Loss Value = 8.525558471679688
# Epoch # 24, Time Step # 150, Loss Value = 8.526276588439941
# Epoch # 24, Time Step # 151, Loss Value = 8.551876068115234
# Epoch # 24, Time Step # 152, Loss Value = 8.59229850769043
# Epoch # 24, Time Step # 153, Loss Value = 8.567270278930664
# Epoch # 24, Time Step # 154, Loss Value = 8.54565143585205
# Epoch # 24, Time Step # 155, Loss Value = 8.529336929321289
# Epoch # 24, Time Step # 156, Loss Value = 8.497438430786133
# Epoch # 24, Time Step # 157, Loss Value = 8.54549503326416
# Epoch # 24, Time Step # 158, Loss Value = 8.52854061126709
# Epoch # 24, Time Step # 159, Loss Value = 8.60625171661377
# Epoch # 24, Time Step # 160, Loss Value = 8.59451961517334
# Epoch # 24, Time Step # 161, Loss Value = 8.5807466506958
# Epoch # 24, Time Step # 162, Loss Value = 8.573468208312988
# Epoch # 24, Time Step # 163, Loss Value = 8.52176284790039
# Epoch # 24, Time Step # 164, Loss Value = 8.46631145477295
# Epoch # 24, Time Step # 165, Loss Value = 8.539543151855469
# Epoch # 24, Time Step # 166, Loss Value = 8.515815734863281
# Epoch # 24, Time Step # 167, Loss Value = 8.583962440490723
# Epoch # 24, Time Step # 168, Loss Value = 8.542191505432129
# Epoch # 24, Time Step # 169, Loss Value = 8.596529006958008
# Epoch # 24, Time Step # 170, Loss Value = 8.599151611328125
# Epoch # 24, Time Step # 171, Loss Value = 8.599750518798828
# Epoch # 24, Time Step # 172, Loss Value = 8.629673957824707
# Epoch # 24, Time Step # 173, Loss Value = 8.603549003601074
# Epoch # 24, Time Step # 174, Loss Value = 8.602428436279297
# Epoch # 24, Time Step # 175, Loss Value = 8.565811157226562
# Epoch # 24, Time Step # 176, Loss Value = 8.545448303222656
# Epoch # 24, Time Step # 177, Loss Value = 8.566970825195312
# Epoch # 24, Time Step # 178, Loss Value = 8.539721488952637
# Epoch # 24, Time Step # 179, Loss Value = 8.4727783203125
# Epoch # 24, Time Step # 180, Loss Value = 8.600300788879395
# Epoch # 24, Time Step # 181, Loss Value = 8.545522689819336
# Epoch # 24, Time Step # 182, Loss Value = 8.54074764251709
# Epoch # 24, Time Step # 183, Loss Value = 8.539575576782227
# Epoch # 24, Time Step # 184, Loss Value = 8.555582046508789
# Epoch # 24, Time Step # 185, Loss Value = 8.554702758789062
# Epoch # 24, Time Step # 186, Loss Value = 8.524604797363281
# Epoch # 24, Time Step # 187, Loss Value = 8.657824516296387
# Epoch # 24, Time Step # 188, Loss Value = 8.555030822753906
# Epoch # 24, Time Step # 189, Loss Value = 8.601053237915039
# Epoch # 24, Time Step # 190, Loss Value = 8.562975883483887
# Epoch # 24, Time Step # 191, Loss Value = 8.595030784606934
# Epoch # 24, Time Step # 192, Loss Value = 8.600669860839844
# Epoch # 24, Time Step # 193, Loss Value = 8.520816802978516
# Epoch # 24, Time Step # 194, Loss Value = 8.56197738647461
# Epoch # 24, Time Step # 195, Loss Value = 8.531962394714355
# Epoch # 24, Time Step # 196, Loss Value = 8.57314395904541
# Epoch # 24, Time Step # 197, Loss Value = 8.576915740966797
# Epoch # 24, Time Step # 198, Loss Value = 8.471439361572266
# Epoch # 24, Time Step # 199, Loss Value = 8.614100456237793

# %%
def generate_translation(eng_sentence):

    tokenized_eng_sentence=src_sent_tokenizer.tokenize(eng_sentence)
    token_ids=src_sent_tokenizer.convert_tokens_to_ids(tokenized_eng_sentence)
    token_ids_tensor=torch.tensor(token_ids)
    token_ids_tensor=torch.unsqueeze(token_ids_tensor,0)

    if torch.cuda.is_available():
        device=torch.device("cuda")
        token_ids_tensor=token_ids_tensor.to(device)

    encoder_output, (final_encoder_output,final_candidate_cell_state) = encoder(token_ids_tensor)
    decoder_first_time_step_input=torch.tensor([[0]])

# %%
src_sent_tokenizer
# Out:
# T5TokenizerFast(name_or_path='google-T5/T5-base', vocab_size=32100, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<pad>', 'additional_special_tokens': ['<extra_id_0>', '<extra_id_1>', '<extra_id_2>', '<extra_id_3>', '<extra_id_4>', '<extra_id_5>', '<extra_id_6>', '<extra_id_7>', '<extra_id_8>', '<extra_id_9>', '<extra_id_10>', '<extra_id_11>', '<extra_id_12>', '<extra_id_13>', '<extra_id_14>', '<extra_id_15>', '<extra_id_16>', '<extra_id_17>', '<extra_id_18>', '<extra_id_19>', '<extra_id_20>', '<extra_id_21>', '<extra_id_22>', '<extra_id_23>', '<extra_id_24>', '<extra_id_25>', '<extra_id_26>', '<extra_id_27>', '<extra_id_28>', '<extra_id_29>', '<extra_id_30>', '<extra_id_31>', '<extra_id_32>', '<extra_id_33>', '<extra_id_34>', '<extra_id_35>', '<extra_id_36>', '<extra_id_37>', '<extra_id_38>', '<extra_id_39>', '<extra_id_40>', '<extra_id_41>', '<extra_id_42>', '<extra_id_43>', '<extra_id_44>', '<extra_id_45>', '<extra_id_46>', '<extra_id_47>', '<extra_id_48>', '<extra_id_49>', '<extra_id_50>', '<extra_id_51>', '<extra_id_52>', '<extra_id_53>', '<extra_id_54>', '<extra_id_55>', '<extra_id_56>', '<extra_id_57>', '<extra_id_58>', '<extra_id_59>', '<extra_id_60>', '<extra_id_61>', '<extra_id_62>', '<extra_id_63>', '<extra_id_64>', '<extra_id_65>', '<extra_id_66>', '<extra_id_67>', '<extra_id_68>', '<extra_id_69>', '<extra_id_70>', '<extra_id_71>', '<extra_id_72>', '<extra_id_73>', '<extra_id_74>', '<extra_id_75>', '<extra_id_76>', '<extra_id_77>', '<extra_id_78>', '<extra_id_79>', '<extra_id_80>', '<extra_id_81>', '<extra_id_82>', '<extra_id_83>', '<extra_id_84>', '<extra_id_85>', '<extra_id_86>', '<extra_id_87>', '<extra_id_88>', '<extra_id_89>', '<extra_id_90>', '<extra_id_91>', '<extra_id_92>', '<extra_id_93>', '<extra_id_94>', '<extra_id_95>', '<extra_id_96>', '<extra_id_97>', '<extra_id_98>', '<extra_id_99>']}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	0: AddedToken("<pad>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32000: AddedToken("<extra_id_99>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32001: AddedToken("<extra_id_98>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32002: AddedToken("<extra_id_97>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32003: AddedToken("<extra_id_96>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32004: AddedToken("<extra_id_95>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32005: AddedToken("<extra_id_94>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32006: AddedToken("<extra_id_93>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32007: AddedToken("<extra_id_92>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32008: AddedToken("<extra_id_91>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32009: AddedToken("<extra_id_90>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32010: AddedToken("<extra_id_89>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32011: AddedToken("<extra_id_88>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32012: AddedToken("<extra_id_87>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32013: AddedToken("<extra_id_86>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32014: AddedToken("<extra_id_85>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32015: AddedToken("<extra_id_84>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32016: AddedToken("<extra_id_83>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32017: AddedToken("<extra_id_82>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32018: AddedToken("<extra_id_81>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32019: AddedToken("<extra_id_80>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32020: AddedToken("<extra_id_79>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32021: AddedToken("<extra_id_78>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32022: AddedToken("<extra_id_77>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32023: AddedToken("<extra_id_76>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32024: AddedToken("<extra_id_75>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32025: AddedToken("<extra_id_74>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32026: AddedToken("<extra_id_73>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32027: AddedToken("<extra_id_72>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32028: AddedToken("<extra_id_71>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32029: AddedToken("<extra_id_70>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32030: AddedToken("<extra_id_69>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32031: AddedToken("<extra_id_68>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32032: AddedToken("<extra_id_67>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32033: AddedToken("<extra_id_66>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32034: AddedToken("<extra_id_65>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32035: AddedToken("<extra_id_64>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32036: AddedToken("<extra_id_63>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32037: AddedToken("<extra_id_62>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32038: AddedToken("<extra_id_61>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32039: AddedToken("<extra_id_60>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32040: AddedToken("<extra_id_59>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32041: AddedToken("<extra_id_58>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32042: AddedToken("<extra_id_57>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32043: AddedToken("<extra_id_56>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32044: AddedToken("<extra_id_55>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32045: AddedToken("<extra_id_54>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32046: AddedToken("<extra_id_53>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32047: AddedToken("<extra_id_52>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32048: AddedToken("<extra_id_51>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32049: AddedToken("<extra_id_50>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32050: AddedToken("<extra_id_49>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32051: AddedToken("<extra_id_48>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32052: AddedToken("<extra_id_47>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32053: AddedToken("<extra_id_46>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32054: AddedToken("<extra_id_45>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32055: AddedToken("<extra_id_44>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32056: AddedToken("<extra_id_43>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32057: AddedToken("<extra_id_42>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32058: AddedToken("<extra_id_41>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32059: AddedToken("<extra_id_40>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32060: AddedToken("<extra_id_39>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32061: AddedToken("<extra_id_38>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32062: AddedToken("<extra_id_37>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32063: AddedToken("<extra_id_36>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32064: AddedToken("<extra_id_35>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32065: AddedToken("<extra_id_34>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32066: AddedToken("<extra_id_33>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32067: AddedToken("<extra_id_32>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32068: AddedToken("<extra_id_31>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32069: AddedToken("<extra_id_30>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32070: AddedToken("<extra_id_29>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32071: AddedToken("<extra_id_28>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32072: AddedToken("<extra_id_27>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32073: AddedToken("<extra_id_26>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32074: AddedToken("<extra_id_25>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32075: AddedToken("<extra_id_24>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32076: AddedToken("<extra_id_23>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32077: AddedToken("<extra_id_22>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32078: AddedToken("<extra_id_21>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32079: AddedToken("<extra_id_20>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32080: AddedToken("<extra_id_19>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32081: AddedToken("<extra_id_18>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32082: AddedToken("<extra_id_17>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32083: AddedToken("<extra_id_16>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32084: AddedToken("<extra_id_15>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32085: AddedToken("<extra_id_14>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32086: AddedToken("<extra_id_13>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32087: AddedToken("<extra_id_12>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32088: AddedToken("<extra_id_11>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32089: AddedToken("<extra_id_10>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32090: AddedToken("<extra_id_9>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32091: AddedToken("<extra_id_8>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32092: AddedToken("<extra_id_7>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32093: AddedToken("<extra_id_6>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32094: AddedToken("<extra_id_5>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32095: AddedToken("<extra_id_4>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32096: AddedToken("<extra_id_3>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32097: AddedToken("<extra_id_2>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32098: AddedToken("<extra_id_1>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	32099: AddedToken("<extra_id_0>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }
# )
